# %% [markdown]
# # Manipulating a dataset structure
# Applying some operations to change DataFrame strucutre and filtering content

# %%
import pandas as pd
import numpy as np
tb_veic = pd.read_csv('data/dados_veiculos.csv')

# %% [markdown]
# Como podemos ver abaixo, a tabela contém 15 colunas, sendo 9 numéricas e 6 de objetos. Além disso todas as linhas parecem ter todas as variáveis preenchidas.

# %%
tb_veic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
#  14  Fuel Cost/Year           35952 non-null  int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 4.1+ MB

# %% [markdown]
# Como podemos verificar o que as colunas com tipo 'object' contém?

# %% [markdown]
# ## Check DataFrame Column Names

# %% [markdown]
# Rename all columns at once:
# - `data.columns` is an **attribute** of the DataFrame which results in a list-like of the column names
#     - You can substitute it by another list containing the names you want
#     - Note you have to substitute the whole set of column names at once
#
# - `data.rename()` is a **method** of a DataFrame, in which you can rename one column at once
#     - You just need to pass a dictionary containing {'old_name':'new_name'}
#     - By default, it changes names of a **index** (`axis=0`), you can specify `axis=1` to change **column** names
#     - the `inplace` argument

# %%
print(tb_veic.columns)
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
print(tb_veic.columns[2])
# Out:
# Year

# %%
coluna_0 = tb_veic[tb_veic.columns[0]]

# %%
tipo_coluna_0 = coluna_0.dtypes.type
print(tipo_coluna_0)
# Out:
# <class 'numpy.object_'>

# %%
tipo_coluna_0 == np.object_
# Out:
# True

# %%
tb_veic.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'id'],
#       dtype='object')

# %%
for column in tb_veic.columns:
    if tb_veic[column].dtypes.type == np.object_:
        print(tb_veic[column].describe())
# Out:
# count         35952
# unique          127
# top       Chevrolet
# freq           3643
# Name: Make, dtype: object
# count               35952
# unique               3608
# top       F150 Pickup 2WD
# freq                  197
# Name: Model, dtype: object
# count               35952
# unique                 45
# top       Automatic 4-spd
# freq                10585
# Name: Transmission, dtype: object
# count                 35952
# unique                    8
# top       Front-Wheel Drive
# freq                  13044
# Name: Drivetrain, dtype: object
# count            35952
# unique              34
# top       Compact Cars
# freq              5185
# Name: Vehicle Class, dtype: object
# count       35952
# unique         13
# top       Regular
# freq        23587
# Name: Fuel Type, dtype: object

# %%
tb_veic.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# min        6.000000      9.000000      7.000000                37.000000
# 25%       15.000000     20.000000     16.000000               395.000000
# 50%       17.000000     24.000000     19.000000               467.736842
# 75%       20.000000     27.000000     23.000000               555.437500
# max       58.000000     61.000000     56.000000              1269.571429
#
#        Fuel Cost/Year
# count    35952.000000
# mean      1892.598465
# std        506.958627
# min        600.000000
# 25%       1500.000000
# 50%       1850.000000
# 75%       2200.000000
# max       5800.000000

# %%
tb_veic['id'] = tb_veic['Make'] + tb_veic['Model'] + tb_veic['Year'].astype('str')

# %%
tb_veic['id'].value_counts()
# Out:
# JeepCherokee/Wagoneer1985               23
# GMCC15 Pickup 2WD1984                   17
# ChevroletS10 Pickup 2WD1984             17
# ChevroletC10 Pickup 2WD1984             17
# GMCS15 Pickup 2WD1984                   17
#                                         ..
# InfinitiQX4 4WD1998                      1
# ChevroletVan 1500 AWD Conversion2003     1
# GMCYukon XL 2500 2WD2013                 1
# Mercedes-BenzC63 AMG2009                 1
# VolvoS80 FWD2006                         1
# Name: id, Length: 16664, dtype: int64

# %% [markdown]
# ### Substituting `.columns` attribute

# %%
print(tb_veic.columns)
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'id'],
#       dtype='object')

# %%
old_column_names = list(tb_veic.columns)

# %%
print(old_column_names)
# Out:
# ['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders', 'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type', 'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG', 'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'id']

# %%
print([column.lower().replace(' ', '_') for column in list(tb_veic.columns)])
# Out:
# ['make', 'model', 'year', 'engine_displacement', 'cylinders', 'transmission', 'drivetrain', 'vehicle_class', 'fuel_type', 'fuel_barrels/year', 'city_mpg', 'highway_mpg', 'combined_mpg', 'co2_emission_grams/mile', 'fuel_cost/year', 'id']

# %%
tb_veic.columns = [column.lower().replace(' ', '_') for column in tb_veic.columns]

# %%
tb_veic
# Out:
#                    make                model  year  engine_displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        cylinders     transmission        drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      vehicle_class fuel_type  fuel_barrels/year  city_mpg  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        highway_mpg  combined_mpg  co2_emission_grams/mile  fuel_cost/year  \
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
#                                       id
# 0        AM GeneralDJ Po Vehicle 2WD1984
# 1         AM GeneralFJ8c Post Office1984
# 2      AM GeneralPost Office DJ5 2WD1985
# 3      AM GeneralPost Office DJ8 2WD1985
# 4                ASC IncorporatedGNX1987
# ...                                  ...
# 35947              smartfortwo coupe2013
# 35948              smartfortwo coupe2014
# 35949              smartfortwo coupe2015
# 35950              smartfortwo coupe2016
# 35951              smartfortwo coupe2016
#
# [35952 rows x 16 columns]

# %%
tb_veic.columns = old_column_names
print(tb_veic.columns)
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'id'],
#       dtype='object')

# %% [markdown]
# ### Using `.rename() method`

# %% [markdown]
# `.rename({'old_column':'new_column'})`

# %%
dict_nomes = dict()
dict_nomes['Year'] = 'model_year'
dict_nomes['year'] = 'model_year'
tb_veic = tb_veic.rename(dict_nomes, axis = 1)
print(tb_veic.columns)
# Out:
# Index(['Make', 'Model', 'model_year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'id'],
#       dtype='object')

# %%
tb_veic.columns = old_column_names
print(tb_veic.columns)
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'id'],
#       dtype='object')

# %%
tb_veic = tb_veic.rename({'Year' : 'model_year'}, axis = 1)
print(tb_veic.columns)
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'id'],
#       dtype='object')

# %%
tb_veic.rename({'Year' : 'model_year'}, axis = 1)
print(tb_veic.columns)
# Out:
# Index(['Make', 'Model', 'model_year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'id'],
#       dtype='object')

# %%
dict_rename = {column : column.lower().replace(' ', '_').replace('/', '_by_') for column in tb_veic.columns}
# Out:
# {'Make': 'make',
#  'Model': 'model',
#  'model_year': 'model_year',
#  'Engine Displacement': 'engine_displacement',
#  'Cylinders': 'cylinders',
#  'Transmission': 'transmission',
#  'Drivetrain': 'drivetrain',
#  'Vehicle Class': 'vehicle_class',
#  'Fuel Type': 'fuel_type',
#  'Fuel Barrels/Year': 'fuel_barrels_by_year',
#  'City MPG': 'city_mpg',
#  'Highway MPG': 'highway_mpg',
#  'Combined MPG': 'combined_mpg',
#  'CO2 Emission Grams/Mile': 'co2_emission_grams_by_mile',
#  'Fuel Cost/Year': 'fuel_cost_by_year',
#  'id': 'id'}

# %%
tb_veic = tb_veic.rename(dict_rename, axis = 1) #tb_veic.rename(dict_rename, axis = 1, inplace = True)
print(tb_veic.columns)
# Out:
# Index(['make', 'model', 'model_year', 'engine_displacement', 'cylinders',
#        'transmission', 'drivetrain', 'vehicle_class', 'fuel_type',
#        'fuel_barrels_by_year', 'city_mpg', 'highway_mpg', 'combined_mpg',
#        'co2_emission_grams_by_mile', 'fuel_cost_by_year', 'id'],
#       dtype='object')

# %% [markdown]
# So, we have two options:
# > 1. store it again on the variable `data`:
#
#     data = data.rename(columns={'Make':'Manufacturer', 'Year':'ANO'})
# > 2. Use the inplace argument `inplace =  True` to change the values within the dataframe automatically
#
#     data.rename(columns={'Make':'Manufacturer', 'Year':'ANO'}, inplace=True)
#
# O parâmetro 'inplace' será deprecado e seu uso é considerado má prática.

# %% [markdown]
# ## Reorder columns in a dataframe
#
# Remember: You always pass a list of columns to access a dataframe

# %%
print(tb_veic.columns)
# Out:
# Index(['make', 'model', 'model_year', 'engine_displacement', 'cylinders',
#        'transmission', 'drivetrain', 'vehicle_class', 'fuel_type',
#        'fuel_barrels_by_year', 'city_mpg', 'highway_mpg', 'combined_mpg',
#        'co2_emission_grams_by_mile', 'fuel_cost_by_year', 'id'],
#       dtype='object')

# %%
tb_veic['model']
# Out:
# 0          DJ Po Vehicle 2WD
# 1           FJ8c Post Office
# 2        Post Office DJ5 2WD
# 3        Post Office DJ8 2WD
# 4                        GNX
#                 ...
# 35947           fortwo coupe
# 35948           fortwo coupe
# 35949           fortwo coupe
# 35950           fortwo coupe
# 35951           fortwo coupe
# Name: model, Length: 35952, dtype: object

# %%
tb_veic[['make', 'model']]
# Out:
#                    make                model
# 0            AM General    DJ Po Vehicle 2WD
# 1            AM General     FJ8c Post Office
# 2            AM General  Post Office DJ5 2WD
# 3            AM General  Post Office DJ8 2WD
# 4      ASC Incorporated                  GNX
# ...                 ...                  ...
# 35947             smart         fortwo coupe
# 35948             smart         fortwo coupe
# 35949             smart         fortwo coupe
# 35950             smart         fortwo coupe
# 35951             smart         fortwo coupe
#
# [35952 rows x 2 columns]

# %%
lista_colunas = list(tb_veic.columns)
lista_colunas.sort()
print(lista_colunas)
# Out:
# ['city_mpg', 'co2_emission_grams_by_mile', 'combined_mpg', 'cylinders', 'drivetrain', 'engine_displacement', 'fuel_barrels_by_year', 'fuel_cost_by_year', 'fuel_type', 'highway_mpg', 'id', 'make', 'model', 'model_year', 'transmission', 'vehicle_class']

# %%
tb_veic = tb_veic[lista_colunas]
# Out:
#        city_mpg  co2_emission_grams_by_mile  combined_mpg  cylinders  \
# 0            18                  522.764706            17        4.0
# 1            13                  683.615385            13        6.0
# 2            16                  555.437500            16        4.0
# 3            13                  683.615385            13        6.0
# 4            14                  555.437500            16        6.0
# ...         ...                         ...           ...        ...
# 35947        34                  244.000000            36        3.0
# 35948        34                  243.000000            36        3.0
# 35949        34                  244.000000            36        3.0
# 35950        34                  246.000000            36        3.0
# 35951        32                  255.000000            35        3.0
#
#              drivetrain  engine_displacement  fuel_barrels_by_year  \
# 0         2-Wheel Drive                  2.5             19.388824
# 1         2-Wheel Drive                  4.2             25.354615
# 2      Rear-Wheel Drive                  2.5             20.600625
# 3      Rear-Wheel Drive                  4.2             25.354615
# 4      Rear-Wheel Drive                  3.8             20.600625
# ...                 ...                  ...                   ...
# 35947  Rear-Wheel Drive                  1.0              9.155833
# 35948  Rear-Wheel Drive                  1.0              9.155833
# 35949  Rear-Wheel Drive                  1.0              9.155833
# 35950  Rear-Wheel Drive                  0.9              9.155833
# 35951  Rear-Wheel Drive                  0.9              9.417429
#
#        fuel_cost_by_year fuel_type  highway_mpg  \
# 0                   1950   Regular           17
# 1                   2550   Regular           13
# 2                   2100   Regular           17
# 3                   2550   Regular           13
# 4                   2550   Premium           21
# ...                  ...       ...          ...
# 35947               1100   Premium           38
# 35948               1100   Premium           38
# 35949               1100   Premium           38
# 35950               1100   Premium           39
# 35951               1150   Premium           39
#
#                                       id              make  \
# 0        AM GeneralDJ Po Vehicle 2WD1984        AM General
# 1         AM GeneralFJ8c Post Office1984        AM General
# 2      AM GeneralPost Office DJ5 2WD1985        AM General
# 3      AM GeneralPost Office DJ8 2WD1985        AM General
# 4                ASC IncorporatedGNX1987  ASC Incorporated
# ...                                  ...               ...
# 35947              smartfortwo coupe2013             smart
# 35948              smartfortwo coupe2014             smart
# 35949              smartfortwo coupe2015             smart
# 35950              smartfortwo coupe2016             smart
# 35951              smartfortwo coupe2016             smart
#
#                      model  model_year     transmission  \
# 0        DJ Po Vehicle 2WD        1984  Automatic 3-spd
# 1         FJ8c Post Office        1984  Automatic 3-spd
# 2      Post Office DJ5 2WD        1985  Automatic 3-spd
# 3      Post Office DJ8 2WD        1985  Automatic 3-spd
# 4                      GNX        1987  Automatic 4-spd
# ...                    ...         ...              ...
# 35947         fortwo coupe        2013        Auto(AM5)
# 35948         fortwo coupe        2014        Auto(AM5)
# 35949         fortwo coupe        2015        Auto(AM5)
# 35950         fortwo coupe        2016        Auto(AM6)
# 35951         fortwo coupe        2016     Manual 5-spd
#
#                      vehicle_class
# 0      Special Purpose Vehicle 2WD
# 1      Special Purpose Vehicle 2WD
# 2      Special Purpose Vehicle 2WD
# 3      Special Purpose Vehicle 2WD
# 4                     Midsize Cars
# ...                            ...
# 35947                  Two Seaters
# 35948                  Two Seaters
# 35949                  Two Seaters
# 35950                  Two Seaters
# 35951                  Two Seaters
#
# [35952 rows x 16 columns]

# %% [markdown]
# ## Remove column (or row)
#
# - The `.drop()` method
# - By default, `.drop()` drops a row given its index.

# %%
tb_veic.drop('make', axis = 1)
# Out:
#                      model  model_year  engine_displacement  cylinders  \
# 0        DJ Po Vehicle 2WD        1984                  2.5        4.0
# 1         FJ8c Post Office        1984                  4.2        6.0
# 2      Post Office DJ5 2WD        1985                  2.5        4.0
# 3      Post Office DJ8 2WD        1985                  4.2        6.0
# 4                      GNX        1987                  3.8        6.0
# ...                    ...         ...                  ...        ...
# 35947         fortwo coupe        2013                  1.0        3.0
# 35948         fortwo coupe        2014                  1.0        3.0
# 35949         fortwo coupe        2015                  1.0        3.0
# 35950         fortwo coupe        2016                  0.9        3.0
# 35951         fortwo coupe        2016                  0.9        3.0
#
#           transmission        drivetrain                vehicle_class  \
# 0      Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1      Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2      Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3      Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4      Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
# ...                ...               ...                          ...
# 35947        Auto(AM5)  Rear-Wheel Drive                  Two Seaters
# 35948        Auto(AM5)  Rear-Wheel Drive                  Two Seaters
# 35949        Auto(AM5)  Rear-Wheel Drive                  Two Seaters
# 35950        Auto(AM6)  Rear-Wheel Drive                  Two Seaters
# 35951     Manual 5-spd  Rear-Wheel Drive                  Two Seaters
#
#       fuel_type  fuel_barrels_by_year  city_mpg  highway_mpg  combined_mpg  \
# 0       Regular             19.388824        18           17            17
# 1       Regular             25.354615        13           13            13
# 2       Regular             20.600625        16           17            16
# 3       Regular             25.354615        13           13            13
# 4       Premium             20.600625        14           21            16
# ...         ...                   ...       ...          ...           ...
# 35947   Premium              9.155833        34           38            36
# 35948   Premium              9.155833        34           38            36
# 35949   Premium              9.155833        34           38            36
# 35950   Premium              9.155833        34           39            36
# 35951   Premium              9.417429        32           39            35
#
#        co2_emission_grams_by_mile  fuel_cost_by_year  \
# 0                      522.764706               1950
# 1                      683.615385               2550
# 2                      555.437500               2100
# 3                      683.615385               2550
# 4                      555.437500               2550
# ...                           ...                ...
# 35947                  244.000000               1100
# 35948                  243.000000               1100
# 35949                  244.000000               1100
# 35950                  246.000000               1100
# 35951                  255.000000               1150
#
#                                       id
# 0        AM GeneralDJ Po Vehicle 2WD1984
# 1         AM GeneralFJ8c Post Office1984
# 2      AM GeneralPost Office DJ5 2WD1985
# 3      AM GeneralPost Office DJ8 2WD1985
# 4                ASC IncorporatedGNX1987
# ...                                  ...
# 35947              smartfortwo coupe2013
# 35948              smartfortwo coupe2014
# 35949              smartfortwo coupe2015
# 35950              smartfortwo coupe2016
# 35951              smartfortwo coupe2016
#
# [35952 rows x 15 columns]

# %%
tb_veic.drop(['make', 'model_year'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-45139aa52fe3> in <module>
# ----> 1 tb_veic.drop(['make', 'model_year'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['make' 'model_year'] not found in axis"

# %% [markdown]
# ## Deep vs Shallow copy on pandas

# %%
copia_tb_veic = tb_veic
copy_tb_veic = tb_veic.copy(deep = False)
deepcopy_tb_veic = tb_veic.copy(deep = True) # comportamento padrão do método

# %%
a = [1, 2, 3]
b = [1, 2, 3]

# %%
a is b
a == b
# Out:
# True

# %%
c = b
print(c)
# Out:
# [1, 2, 3]

# %%
c is b
# Out:
# True

# %%
a = 1
b = 1
a is b
# Out:
# True

# %%
tb_veic_2 = tb_veic
tb_veic_2 is tb_veic
# Out:
# True

# %%
tb_veic_2 = tb_veic.copy()
tb_veic_2 is tb_veic
# Out:
# False

# %% [markdown]
# ## Sort Values in a DatFrame

# %%
tb_veic = tb_veic.sort_values('model_year')
tb_veic
# Out:
#              make                           model  model_year  \
# 0      AM General               DJ Po Vehicle 2WD        1984
# 16337         GMC            T15 (S15) Pickup 4WD        1984
# 16336         GMC            T15 (S15) Pickup 4WD        1984
# 5636    Chevrolet            El Camino Pickup 2WD        1984
# 5637    Chevrolet            El Camino Pickup 2WD        1984
# ...           ...                             ...         ...
# 1968          BMW                     340i xDrive        2017
# 3137      Bentley                  Continental GT        2017
# 1965          BMW                            340i        2017
# 21091  Land Rover  Range Rover Evoque Convertible        2017
# 20450         Kia                         Forte 5        2017
#
#        engine_displacement  cylinders     transmission  \
# 0                      2.5        4.0  Automatic 3-spd
# 16337                  2.8        6.0     Manual 4-spd
# 16336                  2.8        6.0     Manual 5-spd
# 5636                   3.8        6.0  Automatic 3-spd
# 5637                   3.8        6.0  Automatic 4-spd
# ...                    ...        ...              ...
# 1968                   3.0        6.0   Automatic (S8)
# 3137                   4.0        8.0   Automatic (S8)
# 1965                   3.0        6.0     Manual 6-spd
# 21091                  2.0        4.0   Automatic (S9)
# 20450                  1.6        4.0     Manual 6-spd
#
#                        drivetrain                    vehicle_class fuel_type  \
# 0                   2-Wheel Drive      Special Purpose Vehicle 2WD   Regular
# 16337  4-Wheel or All-Wheel Drive       Standard Pickup Trucks 4WD   Regular
# 16336  4-Wheel or All-Wheel Drive       Standard Pickup Trucks 4WD   Regular
# 5636                2-Wheel Drive       Standard Pickup Trucks 2WD   Regular
# 5637                2-Wheel Drive       Standard Pickup Trucks 2WD   Regular
# ...                           ...                              ...       ...
# 1968              All-Wheel Drive                     Compact Cars   Premium
# 3137              All-Wheel Drive                     Compact Cars   Premium
# 1965             Rear-Wheel Drive                     Compact Cars   Premium
# 21091               4-Wheel Drive  Small Sport Utility Vehicle 4WD   Premium
# 20450           Front-Wheel Drive                       Large Cars   Regular
#
#        fuel_barrels_by_year  city_mpg  highway_mpg  combined_mpg  \
# 0                 19.388824        18           17            17
# 16337             19.388824        15           21            17
# 16336             18.311667        15           22            18
# 5636              19.388824        15           19            17
# 5637              18.311667        15           22            18
# ...                     ...       ...          ...           ...
# 1968              13.184400        21           31            25
# 3137              17.347895        15           25            19
# 1965              14.330870        19           29            23
# 21091             14.330870        20           28            23
# 20450             13.184400        23           29            25
#
#        co2_emission_grams_by_mile  fuel_cost_by_year  \
# 0                      522.764706               1950
# 16337                  522.764706               1950
# 16336                  493.722222               1850
# 5636                   522.764706               1950
# 5637                   493.722222               1850
# ...                           ...                ...
# 1968                   357.000000               1600
# 3137                   475.000000               2150
# 1965                   395.000000               1750
# 21091                  391.000000               1750
# 20450                  353.000000               1350
#
#                                                  id
# 0                   AM GeneralDJ Po Vehicle 2WD1984
# 16337                   GMCT15 (S15) Pickup 4WD1984
# 16336                   GMCT15 (S15) Pickup 4WD1984
# 5636              ChevroletEl Camino Pickup 2WD1984
# 5637              ChevroletEl Camino Pickup 2WD1984
# ...                                             ...
# 1968                             BMW340i xDrive2017
# 3137                      BentleyContinental GT2017
# 1965                                    BMW340i2017
# 21091  Land RoverRange Rover Evoque Convertible2017
# 20450                                KiaForte 52017
#
# [35952 rows x 16 columns]

# %%
tb_veic = tb_veic.sort_values('model_year', ascending = False)
tb_veic
# Out:
#        index        make              model  model_year  engine_displacement  \
# 0      20450         Kia            Forte 5        2017                  1.6
# 563    29264     Porsche       911 Targa 4S        2017                  3.0
# 565      140       Acura            MDX AWD        2017                  3.5
# 566     3895    Cadillac            CTS AWD        2017                  2.0
# 567    20480         Kia         Forte Koup        2017                  1.6
# ...      ...         ...                ...         ...                  ...
# 35522  13777        Ford  Ranger Pickup 2WD        1984                  2.8
# 35523  31003      Subaru           Brat 4WD        1984                  1.8
# 35524  31002      Subaru           Brat 4WD        1984                  1.8
# 35525  26752      Nissan         Pickup 2WD        1984                  2.0
# 35951      0  AM General  DJ Po Vehicle 2WD        1984                  2.5
#
#        cylinders     transmission                  drivetrain  \
# 0            4.0     Manual 6-spd           Front-Wheel Drive
# 563          6.0     Manual 7-spd               4-Wheel Drive
# 565          6.0   Automatic (S9)             All-Wheel Drive
# 566          4.0   Automatic (S8)             All-Wheel Drive
# 567          4.0        Auto(AM7)           Front-Wheel Drive
# ...          ...              ...                         ...
# 35522        6.0     Manual 5-spd               2-Wheel Drive
# 35523        4.0     Manual 4-spd  4-Wheel or All-Wheel Drive
# 35524        4.0  Automatic 3-spd  4-Wheel or All-Wheel Drive
# 35525        4.0     Manual 5-spd               2-Wheel Drive
# 35951        4.0  Automatic 3-spd               2-Wheel Drive
#
#                          vehicle_class fuel_type  fuel_barrels_by_year  \
# 0                           Large Cars   Regular             13.184400
# 563                   Minicompact Cars   Premium             14.982273
# 565    Small Sport Utility Vehicle 4WD   Premium             14.982273
# 566                       Midsize Cars   Premium             13.733750
# 567                       Compact Cars   Regular             12.207778
# ...                                ...       ...                   ...
# 35522          Small Pickup Trucks 2WD   Regular             18.311667
# 35523      Special Purpose Vehicle 4WD   Regular             13.733750
# 35524      Special Purpose Vehicle 4WD   Regular             15.695714
# 35525          Small Pickup Trucks 2WD   Regular             12.207778
# 35951      Special Purpose Vehicle 2WD   Regular             19.388824
#
#        city_mpg  highway_mpg  combined_mpg  co2_emission_grams_by_mile  \
# 0            23           29            25                  353.000000
# 563          19           28            22                  396.000000
# 565          19           26            22                  404.000000
# 566          21           29            24                  368.000000
# 567          25           32            27                  328.000000
# ...         ...          ...           ...                         ...
# 35522        16           22            18                  493.722222
# 35523        22           27            24                  370.291667
# 35524        20           23            21                  423.190476
# 35525        24           31            27                  329.148148
# 35951        18           17            17                  522.764706
#
#        fuel_cost_by_year                               id
# 0                   1350                   KiaForte 52017
# 563                 1850          Porsche911 Targa 4S2017
# 565                 1850                 AcuraMDX AWD2017
# 566                 1700              CadillacCTS AWD2017
# 567                 1250                KiaForte Koup2017
# ...                  ...                              ...
# 35522               1850        FordRanger Pickup 2WD1984
# 35523               1400               SubaruBrat 4WD1984
# 35524               1600               SubaruBrat 4WD1984
# 35525               1250             NissanPickup 2WD1984
# 35951               1950  AM GeneralDJ Po Vehicle 2WD1984
#
# [35952 rows x 17 columns]

# %%
tb_veic = tb_veic.sort_values(['model_year', 'engine_displacement'], ascending = [False, True])
tb_veic
# Out:
#        index        make             model  model_year  engine_displacement  \
# 626    35939       smart  fortwo cabriolet        2017                  0.9
# 627    35938       smart  fortwo cabriolet        2017                  0.9
# 336    25667  Mitsubishi         Mirage G4        2017                  1.2
# 337    25666  Mitsubishi         Mirage G4        2017                  1.2
# 338    25665  Mitsubishi            Mirage        2017                  1.2
# ...      ...         ...               ...         ...                  ...
# 35498  14493         GMC    C25 Pickup 2WD        1984                  6.2
# 35488  14476         GMC  C15 Suburban 2WD        1984                  6.2
# 35502  14490         GMC    C25 Pickup 2WD        1984                  6.2
# 35486  14477         GMC  C15 Suburban 2WD        1984                  6.2
# 35532   6174   Chevrolet    K10 Pickup 4WD        1984                  6.2
#
#        cylinders                      transmission  \
# 626          3.0                      Manual 5-spd
# 627          3.0                         Auto(AM6)
# 336          3.0  Automatic (variable gear ratios)
# 337          3.0                      Manual 5-spd
# 338          3.0  Automatic (variable gear ratios)
# ...          ...                               ...
# 35498        8.0                      Manual 4-spd
# 35488        8.0                   Automatic 4-spd
# 35502        8.0                      Manual 4-spd
# 35486        8.0                   Automatic 4-spd
# 35532        8.0                   Automatic 4-spd
#
#                        drivetrain                vehicle_class fuel_type  \
# 626              Rear-Wheel Drive                  Two Seaters   Premium
# 627              Rear-Wheel Drive                  Two Seaters   Premium
# 336             Front-Wheel Drive                 Compact Cars   Regular
# 337             Front-Wheel Drive                 Compact Cars   Regular
# 338             Front-Wheel Drive                 Compact Cars   Regular
# ...                           ...                          ...       ...
# 35498               2-Wheel Drive   Standard Pickup Trucks 2WD    Diesel
# 35488               2-Wheel Drive  Special Purpose Vehicle 2WD    Diesel
# 35502               2-Wheel Drive   Standard Pickup Trucks 2WD    Diesel
# 35486               2-Wheel Drive  Special Purpose Vehicle 2WD    Diesel
# 35532  4-Wheel or All-Wheel Drive   Standard Pickup Trucks 4WD    Diesel
#
#        fuel_barrels_by_year  city_mpg  highway_mpg  combined_mpg  \
# 626                9.694412        31           38            34
# 627                9.417429        33           38            35
# 336                8.908378        35           42            37
# 337                9.417429        33           40            35
# 338                8.451538        37           43            39
# ...                     ...       ...          ...           ...
# 35498             20.115000        18           22            19
# 35488             21.232500        16           22            18
# 35502             19.109250        18           22            20
# 35486             22.481471        15           19            17
# 35532             21.232500        16           20            18
#
#        co2_emission_grams_by_mile  fuel_cost_by_year  \
# 626                    258.000000               1200
# 627                    251.000000               1150
# 336                    237.000000                900
# 337                    249.000000                950
# 338                    226.000000                850
# ...                           ...                ...
# 35498                  535.789474               1900
# 35488                  565.555556               2000
# 35502                  509.000000               1800
# 35486                  598.823529               2150
# 35532                  565.555556               2000
#
#                                 id
# 626      smartfortwo cabriolet2017
# 627      smartfortwo cabriolet2017
# 336        MitsubishiMirage G42017
# 337        MitsubishiMirage G42017
# 338           MitsubishiMirage2017
# ...                            ...
# 35498        GMCC25 Pickup 2WD1984
# 35488      GMCC15 Suburban 2WD1984
# 35502        GMCC25 Pickup 2WD1984
# 35486      GMCC15 Suburban 2WD1984
# 35532  ChevroletK10 Pickup 4WD1984
#
# [35952 rows x 17 columns]

# %%
tb_veic = tb_veic.sort_values(['model_year', 'engine_displacement', 'make'], ascending = False)
tb_veic
# Out:
#        index                           make                   model  \
# 670    10889                          Dodge                   Viper
# 227     3191                        Bentley                Mulsanne
# 464    30043                    Rolls-Royce           Phantom Coupe
# 69     30064                    Rolls-Royce             Phantom EWB
# 350    30053                    Rolls-Royce  Phantom Drophead Coupe
# ...      ...                            ...                     ...
# 35363  16887                  Grumman Olson                  Kubvan
# 35308  31980                         Suzuki              SJ 410 4WD
# 35349  31982                         Suzuki             SJ 410V 4WD
# 35360  31984                         Suzuki          SJ410K P/U 4WD
# 35359  18408  Import Foreign Auto Sales Inc                1fas 410
#
#        model_year  engine_displacement  cylinders     transmission  \
# 670          2017                  8.4       10.0     Manual 6-spd
# 227          2017                  6.8        8.0   Automatic (S8)
# 464          2017                  6.7       12.0   Automatic (S8)
# 69           2017                  6.7       12.0   Automatic (S8)
# 350          2017                  6.7       12.0   Automatic (S8)
# ...           ...                  ...        ...              ...
# 35363        1984                  1.6        4.0  Automatic 3-spd
# 35308        1984                  1.0        4.0     Manual 4-spd
# 35349        1984                  1.0        4.0     Manual 4-spd
# 35360        1984                  1.0        4.0     Manual 4-spd
# 35359        1984                  1.0        4.0     Manual 4-spd
#
#                        drivetrain                vehicle_class fuel_type  \
# 670              Rear-Wheel Drive                  Two Seaters   Premium
# 227              Rear-Wheel Drive                 Midsize Cars   Premium
# 464              Rear-Wheel Drive                 Compact Cars   Premium
# 69               Rear-Wheel Drive                   Large Cars   Premium
# 350              Rear-Wheel Drive                 Compact Cars   Premium
# ...                           ...                          ...       ...
# 35363               2-Wheel Drive  Special Purpose Vehicle 2WD    Diesel
# 35308  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD   Regular
# 35349  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD   Regular
# 35360  4-Wheel or All-Wheel Drive      Small Pickup Trucks 4WD   Regular
# 35359  4-Wheel or All-Wheel Drive      Small Pickup Trucks 4WD   Regular
#
#        fuel_barrels_by_year  city_mpg  highway_mpg  combined_mpg  \
# 670               23.543571        12           19            14
# 227               23.543571        11           18            14
# 464               23.543571        11           19            14
# 69                23.543571        11           19            14
# 350               23.543571        11           19            14
# ...                     ...       ...          ...           ...
# 35363             14.155000        27           27            27
# 35308             14.982273        22           22            22
# 35349             14.982273        22           22            22
# 35360             14.982273        22           22            22
# 35359             17.347895        18           20            19
#
#        co2_emission_grams_by_mile  fuel_cost_by_year  \
# 670                    623.000000               2900
# 227                    652.000000               2900
# 464                    638.000000               2900
# 69                     637.000000               2900
# 350                    637.000000               2900
# ...                           ...                ...
# 35363                  377.037037               1350
# 35308                  403.954545               1500
# 35349                  403.954545               1500
# 35360                  403.954545               1500
# 35359                  467.736842               1750
#
#                                               id
# 670                               DodgeViper2017
# 227                          BentleyMulsanne2017
# 464                 Rolls-RoycePhantom Coupe2017
# 69                    Rolls-RoycePhantom EWB2017
# 350        Rolls-RoycePhantom Drophead Coupe2017
# ...                                          ...
# 35363                    Grumman OlsonKubvan1984
# 35308                       SuzukiSJ 410 4WD1984
# 35349                      SuzukiSJ 410V 4WD1984
# 35360                   SuzukiSJ410K P/U 4WD1984
# 35359  Import Foreign Auto Sales Inc1fas 4101984
#
# [35952 rows x 17 columns]

# %% [markdown]
# # Filter records
# >    - `mask` concept
# >    - `.query()` method
#
# This is really important for data wrangling.

# %% [markdown]
# ## Simple Example: Starting with a numpy array. How can I filter the values of a list?

# %%
meu_array = np.array(range(1,10,2))
print(meu_array)
# Out:
# [1 3 5 7 9]

# %% [markdown]
# The results of `my_array > 5` is what is called **a mask**. A result containing the `True` and `False` results of an operation.

# %%
print(meu_array > 5)
# Out:
# [False False False  True  True]

# %% [markdown]
# Masks can be used as an index to select data!

# %%
print(meu_array[meu_array > 5])
# Out:
# [7 9]

# %% [markdown]
# After selecting, you can do anything with it, for example assigning it. This operation is called a `vectorial` operation. It is done all at once.

# %%
meu_array_filtrado = meu_array[meu_array > 5]
print(meu_array_filtrado)
# Out:
# [7 9]

# %% [markdown]
# You can also save the condition

# %%
num_gt5 = meu_array > 5
print(num_gt5)
# Out:
# [False False False  True  True]

# %% [markdown]
# ## Bitwise logical operators - Combining conditions
#
# To make more than one condition together, you can use
# - `&` - analogous to `and`
# - `|` - analogous to `or`

# %% [markdown]
# For example, get all numbers from my_array that are greater than 3 and smaller than 8

# %% [markdown]
# Let's do it in steps:
# - get values greater than 3

# %%
num_gt3 = meu_array > 3
print(meu_array)
print(num_gt3)
print(meu_array[num_gt3])
# Out:
# [1 3 5 7 9]
# [False False  True  True  True]
# [5 7 9]

# %% [markdown]
# - get values smaller than 8

# %%
num_st8 = meu_array < 8
print(meu_array)
print(num_st8)
print(meu_array[num_st8])
# Out:
# [1 3 5 7 9]
# [ True  True  True  True False]
# [1 3 5 7]

# %% [markdown]
# - get values greater than 3 AND smaller than 8

# %%
num_3a8 = num_st8 & num_gt3
print(meu_array)
print(num_3a8)
print(meu_array[num_3a8])
# Out:
# [1 3 5 7 9]
# [False False  True  True False]
# [5 7]

# %% [markdown]
# - get values greater than 3 OR smaller than 8

# %%
num_3a8 = num_st8 | num_gt3
print(meu_array)
print(num_3a8)
# Out:
# [1 3 5 7 9]
# [ True  True  True  True  True]

# %% [markdown]
# ## Now in a DataFrame

# %% [markdown]
# Let's find the rows in which the Cylinders values are exactly 6.

# %%
cyl_6 = tb_veic['cylinders'] == 6
print(cyl_6)
sum(cyl_6)
# Out:
# 670      False
# 227      False
# 464      False
# 69       False
# 350      False
#          ...
# 35363    False
# 35308    False
# 35349    False
# 35360    False
# 35359    False
# Name: cylinders, Length: 35952, dtype: bool
# 12765

# %%
#tb_veic_cyl6 = tb_veic[cyl_6] 
# mais abreviado seria:
tb_veic_cyl6 = tb_veic[tb_veic['cylinders'] == 6]
tb_veic_cyl6
# Out:
#        index       make                 model  model_year  \
# 65     16088        GMC        Sierra C15 2WD        2017
# 240    16168        GMC        Sierra K15 4WD        2017
# 58      7207  Chevrolet     Silverado K15 4WD        2017
# 63      7131  Chevrolet     Silverado C15 2WD        2017
# 619    29301    Porsche   911 Turbo Cabriolet        2017
# ...      ...        ...                   ...         ...
# 35861   7457  Chevrolet  T10 (S10) Blazer 4WD        1984
# 35858   7455  Chevrolet  T10 (S10) Blazer 4WD        1984
# 35859   7456  Chevrolet  T10 (S10) Blazer 4WD        1984
# 35853   6772  Chevrolet   S10 Cab Chassis 2WD        1984
# 35586   6947  Chevrolet  S10 Utility Body 2WD        1984
#
#        engine_displacement  cylinders     transmission  \
# 65                     4.3        6.0  Automatic 6-spd
# 240                    4.3        6.0  Automatic 6-spd
# 58                     4.3        6.0  Automatic 6-spd
# 63                     4.3        6.0  Automatic 6-spd
# 619                    3.8        6.0      Auto(AM-S7)
# ...                    ...        ...              ...
# 35861                  2.8        6.0     Manual 5-spd
# 35858                  2.8        6.0  Automatic 4-spd
# 35859                  2.8        6.0     Manual 4-spd
# 35853                  2.8        6.0  Automatic 4-spd
# 35586                  2.8        6.0  Automatic 4-spd
#
#                        drivetrain                vehicle_class  \
# 65               Rear-Wheel Drive   Standard Pickup Trucks 2WD
# 240                 4-Wheel Drive   Standard Pickup Trucks 4WD
# 58                  4-Wheel Drive   Standard Pickup Trucks 4WD
# 63               Rear-Wheel Drive   Standard Pickup Trucks 2WD
# 619               All-Wheel Drive             Minicompact Cars
# ...                           ...                          ...
# 35861  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD
# 35858  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD
# 35859  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD
# 35853               2-Wheel Drive     Special Purpose Vehicles
# 35586               2-Wheel Drive  Special Purpose Vehicle 2WD
#
#              fuel_type  fuel_barrels_by_year  city_mpg  highway_mpg  \
# 65     Gasoline or E85             16.480500        18           24
# 240    Gasoline or E85             17.347895        17           22
# 58     Gasoline or E85             17.347895        17           22
# 63     Gasoline or E85             16.480500        18           24
# 619            Premium             15.695714        19           24
# ...                ...                   ...       ...          ...
# 35861          Regular             19.388824        15           22
# 35858          Regular             18.311667        15           22
# 35859          Regular             19.388824        15           20
# 35853          Regular             25.354615        13           13
# 35586          Regular             18.311667        16           22
#
#        combined_mpg  co2_emission_grams_by_mile  fuel_cost_by_year  \
# 65               20                  448.000000               1650
# 240              19                  474.000000               1750
# 58               19                  473.000000               1750
# 63               20                  448.000000               1650
# 619              21                  430.000000               1950
# ...             ...                         ...                ...
# 35861            17                  522.764706               1950
# 35858            18                  493.722222               1850
# 35859            17                  522.764706               1950
# 35853            13                  683.615385               2550
# 35586            18                  493.722222               1850
#
#                                       id
# 65                 GMCSierra C15 2WD2017
# 240                GMCSierra K15 4WD2017
# 58        ChevroletSilverado K15 4WD2017
# 63        ChevroletSilverado C15 2WD2017
# 619       Porsche911 Turbo Cabriolet2017
# ...                                  ...
# 35861  ChevroletT10 (S10) Blazer 4WD1984
# 35858  ChevroletT10 (S10) Blazer 4WD1984
# 35859  ChevroletT10 (S10) Blazer 4WD1984
# 35853   ChevroletS10 Cab Chassis 2WD1984
# 35586  ChevroletS10 Utility Body 2WD1984
#
# [12765 rows x 17 columns]

# %%
tb_veic_cyl6.describe()
# Out:
#               index    model_year  engine_displacement  cylinders  \
# count  12765.000000  12765.000000         12765.000000    12765.0
# mean   16781.892754   2001.294242             3.439342        6.0
# std    10303.764189      9.575349             0.549034        0.0
# min        1.000000   1984.000000             1.800000        6.0
# 25%     7698.000000   1993.000000             3.000000        6.0
# 50%    16366.000000   2002.000000             3.500000        6.0
# 75%    25901.000000   2009.000000             3.800000        6.0
# max    35904.000000   2017.000000             5.300000        6.0
#
#        fuel_barrels_by_year      city_mpg   highway_mpg  combined_mpg  \
# count          12765.000000  12765.000000  12765.000000  12765.000000
# mean              18.086572     16.328946     22.661261     18.606189
# std                2.579958      2.130492      3.747362      2.603443
# min                0.109412      9.000000     10.000000     10.000000
# 25%               16.480500     15.000000     20.000000     17.000000
# 50%               17.347895     16.000000     23.000000     19.000000
# 75%               19.388824     18.000000     25.000000     20.000000
# max               32.961000     32.000000     38.000000     31.000000
#
#        co2_emission_grams_by_mile  fuel_cost_by_year
# count                12765.000000       12765.000000
# mean                   487.609906        1943.196240
# std                     69.240664         274.865226
# min                    206.000000        1200.000000
# 25%                    444.350000        1750.000000
# 50%                    467.736842        1950.000000
# 75%                    522.764706        2150.000000
# max                    888.700000        3400.000000

# %% [markdown]
# ### You can combine conditions

# %% [markdown]
# Cars from `Ford` and 6 `Cylinders`

# %%
print(tb_veic.columns)
# Out:
# Index(['index', 'make', 'model', 'model_year', 'engine_displacement',
#        'cylinders', 'transmission', 'drivetrain', 'vehicle_class', 'fuel_type',
#        'fuel_barrels_by_year', 'city_mpg', 'highway_mpg', 'combined_mpg',
#        'co2_emission_grams_by_mile', 'fuel_cost_by_year', 'id'],
#       dtype='object')

# %%
print(tb_veic['make'].unique())
# Out:
# ['Dodge' 'Bentley' 'Rolls-Royce' 'Lamborghini' 'Jeep' 'Ferrari' 'GMC'
#  'Chevrolet' 'Cadillac' 'Mercedes-Benz' 'Aston Martin' 'Toyota' 'Ram'
#  'Lexus' 'Nissan' 'Ford' 'Audi' 'Kia' 'Jaguar' 'Genesis' 'Porsche'
#  'Maserati' 'BMW' 'McLaren Automotive' 'Lincoln' 'Infiniti' 'Volkswagen'
#  'Subaru' 'Chrysler' 'Buick' 'Lotus' 'Honda' 'Acura' 'Hyundai' 'Mazda'
#  'Mitsubishi' 'Volvo' 'MINI' 'Land Rover' 'Fiat' 'smart' 'Pagani'
#  'Roush Performance' 'Scion' 'Alfa Romeo' 'Bugatti' 'SRT'
#  'Mobility Ventures LLC' 'VPG' 'Suzuki' 'Maybach' 'Saab' 'Fisker'
#  'Mercury' 'Spyker' 'Mahindra' 'Hummer' 'Saturn' 'Pontiac'
#  'Saleen Performance' 'Isuzu' 'Tecstar, LP' 'Shelby' 'BMW Alpina'
#  'Oldsmobile' 'Daewoo' 'Morgan' 'London Taxi' 'Plymouth' 'Qvale'
#  'Quantum Technologies' 'Eagle' 'Vector' 'Geo' 'Saleen' 'Federal Coach'
#  'Dabryan Coach Builders Inc' 'Panoz Auto-Development' 'Panos'
#  'J.K. Motors' 'Autokraft Limited' 'PAS, Inc' 'CX Automotive'
#  'Wallace Environmental' 'PAS Inc - GMC' 'Isis Imports Ltd'
#  'Import Trade Services' 'Peugeot' 'Consulier Industries Inc' 'Daihatsu'
#  'Evans Automobiles' 'Sterling' 'Goldacre' 'Laforza Automobile Inc' 'Yugo'
#  'General Motors' 'Merkur' 'Environmental Rsch and Devp Corp' 'Bertone'
#  'CCC Engineering' 'Aurora Cars Ltd' 'Ruf Automobile Gmbh'
#  'JBA Motorcars, Inc.' 'Grumman Allied Industries'
#  'Panther Car Company Limited' 'Mcevoy Motors' 'Red Shift Ltd.' 'Dacia'
#  'Excalibur Autos' 'American Motors Corporation' 'Bitter Gmbh and Co. Kg'
#  'ASC Incorporated' 'Renault' 'Texas Coach Company'
#  'Lambda Control Systems' 'TVR Engineering Ltd' 'Vixen Motor Company'
#  'London Coach Co Inc' 'Volga Associated Automobile' 'AM General'
#  'E. P. Dutton, Inc.' 'Bill Dovell Motor Car Company' 'Pininfarina'
#  'Grumman Olson' 'Superior Coaches Div E.p. Dutton'
#  'S and S Coach Company  E.p. Dutton' 'Import Foreign Auto Sales Inc']

# %%
True and False
# Out:
# False

# %%
print(tb_veic['make'] == 'Ford')
# Out:
# 670      False
# 227      False
# 464      False
# 69       False
# 350      False
#          ...
# 35363    False
# 35308    False
# 35349    False
# 35360    False
# 35359    False
# Name: make, Length: 35952, dtype: bool

# %%
cond_ford_6 = ((tb_veic['make'] == 'Ford') & (tb_veic['cylinders'] == 6)) | ((tb_veic['make'] == 'Bentley') & (tb_veic['cylinders'] == 6))

print(cond_ford_6)
sum(cond_ford_6)
# Out:
# 670      False
# 227      False
# 464      False
# 69       False
# 350      False
#          ...
# 35363    False
# 35308    False
# 35349    False
# 35360    False
# 35359    False
# Length: 35952, dtype: bool
# 1293

# %%
tb_ford_cyl6 = tb_veic[cond_ford_6]
tb_ford_cyl6
# Out:
#        index  make                   model  model_year  engine_displacement  \
# 474    14355  Ford  Transit T150 Wagon FFV        2017                  3.7
# 785    13680  Ford                 Mustang        2017                  3.7
# 816    13681  Ford                 Mustang        2017                  3.7
# 516    14352  Ford      Transit T150 Wagon        2017                  3.5
# 146    12359  Ford          Expedition 4WD        2017                  3.5
# ...      ...   ...                     ...         ...                  ...
# 35516  13771  Ford       Ranger Pickup 2WD        1984                  2.8
# 35519  13772  Ford       Ranger Pickup 2WD        1984                  2.8
# 35520  13775  Ford       Ranger Pickup 2WD        1984                  2.8
# 35521  13776  Ford       Ranger Pickup 2WD        1984                  2.8
# 35522  13777  Ford       Ranger Pickup 2WD        1984                  2.8
#
#        cylinders     transmission               drivetrain  \
# 474          6.0   Automatic (S6)         Rear-Wheel Drive
# 785          6.0   Automatic (S6)         Rear-Wheel Drive
# 816          6.0     Manual 6-spd         Rear-Wheel Drive
# 516          6.0   Automatic (S6)         Rear-Wheel Drive
# 146          6.0   Automatic (S6)  Part-time 4-Wheel Drive
# ...          ...              ...                      ...
# 35516        6.0  Automatic 3-spd            2-Wheel Drive
# 35519        6.0     Manual 4-spd            2-Wheel Drive
# 35520        6.0  Automatic 3-spd            2-Wheel Drive
# 35521        6.0     Manual 4-spd            2-Wheel Drive
# 35522        6.0     Manual 5-spd            2-Wheel Drive
#
#                             vehicle_class        fuel_type  \
# 474                  Vans, Passenger Type  Gasoline or E85
# 785                       Subcompact Cars          Regular
# 816                       Subcompact Cars          Regular
# 516                  Vans, Passenger Type          Regular
# 146    Standard Sport Utility Vehicle 4WD          Regular
# ...                                   ...              ...
# 35516             Small Pickup Trucks 2WD          Regular
# 35519             Small Pickup Trucks 2WD          Regular
# 35520             Small Pickup Trucks 2WD          Regular
# 35521             Small Pickup Trucks 2WD          Regular
# 35522             Small Pickup Trucks 2WD          Regular
#
#        fuel_barrels_by_year  city_mpg  highway_mpg  combined_mpg  \
# 474               20.600625        14           18            16
# 785               15.695714        18           27            21
# 816               15.695714        18           27            21
# 516               20.600625        15           19            16
# 146               19.388824        15           20            17
# ...                     ...       ...          ...           ...
# 35516             18.311667        16           21            18
# 35519             16.480500        18           23            20
# 35520             19.388824        15           19            17
# 35521             17.347895        17           22            19
# 35522             18.311667        16           22            18
#
#        co2_emission_grams_by_mile  fuel_cost_by_year  \
# 474                    570.000000               2100
# 785                    423.000000               1600
# 816                    428.000000               1600
# 516                    552.000000               2100
# 146                    537.000000               1950
# ...                           ...                ...
# 35516                  493.722222               1850
# 35519                  444.350000               1650
# 35520                  522.764706               1950
# 35521                  467.736842               1750
# 35522                  493.722222               1850
#
#                                    id
# 474    FordTransit T150 Wagon FFV2017
# 785                   FordMustang2017
# 816                   FordMustang2017
# 516        FordTransit T150 Wagon2017
# 146            FordExpedition 4WD2017
# ...                               ...
# 35516       FordRanger Pickup 2WD1984
# 35519       FordRanger Pickup 2WD1984
# 35520       FordRanger Pickup 2WD1984
# 35521       FordRanger Pickup 2WD1984
# 35522       FordRanger Pickup 2WD1984
#
# [1293 rows x 17 columns]

# %% [markdown]
# ### Using conditions to create new columns

# %%
tb_veic_2 = tb_veic.copy()

# %%
tb_veic_2.loc[tb_veic['cylinders'] == 6,'make']
# Out:
# array(['GMC', 'Chevrolet', 'Porsche', 'Nissan', 'Kia', 'Genesis',
#        'Lincoln', 'Infiniti', 'Ford', 'Volkswagen', 'Subaru', 'Ram',
#        'Jeep', 'Dodge', 'Chrysler', 'Cadillac', 'Buick', 'Toyota',
#        'Mercedes-Benz', 'Lotus', 'Lexus', 'Honda', 'Acura', 'Hyundai',
#        'Maserati', 'Jaguar', 'BMW', 'Audi', 'Volvo', 'Mitsubishi',
#        'Land Rover', 'Mazda', 'Suzuki', 'Saab', 'Mercury', 'Saturn',
#        'Pontiac', 'Isuzu', 'Oldsmobile', 'Daewoo', 'Plymouth',
#        'Aston Martin', 'Eagle', 'Alfa Romeo', 'PAS, Inc', 'J.K. Motors',
#        'CX Automotive', 'PAS Inc - GMC', 'Wallace Environmental',
#        'Import Trade Services', 'Sterling', 'Goldacre', 'Peugeot',
#        'Merkur', 'Environmental Rsch and Devp Corp',
#        'Ruf Automobile Gmbh', 'JBA Motorcars, Inc.',
#        'American Motors Corporation', 'Bitter Gmbh and Co. Kg',
#        'ASC Incorporated', 'Lambda Control Systems',
#        'TVR Engineering Ltd', 'Vixen Motor Company', 'AM General'],
#       dtype=object)

# %%
tb_veic_2.loc[tb_veic['cylinders'] == 6, 'cyl_6'] = True
tb_veic_2
# Out:
#        index                           make                   model  \
# 670    10889                          Dodge                   Viper
# 227     3191                        Bentley                Mulsanne
# 464    30043                    Rolls-Royce           Phantom Coupe
# 69     30064                    Rolls-Royce             Phantom EWB
# 350    30053                    Rolls-Royce  Phantom Drophead Coupe
# ...      ...                            ...                     ...
# 35363  16887                  Grumman Olson                  Kubvan
# 35308  31980                         Suzuki              SJ 410 4WD
# 35349  31982                         Suzuki             SJ 410V 4WD
# 35360  31984                         Suzuki          SJ410K P/U 4WD
# 35359  18408  Import Foreign Auto Sales Inc                1fas 410
#
#        model_year  engine_displacement  cylinders     transmission  \
# 670          2017                  8.4       10.0     Manual 6-spd
# 227          2017                  6.8        8.0   Automatic (S8)
# 464          2017                  6.7       12.0   Automatic (S8)
# 69           2017                  6.7       12.0   Automatic (S8)
# 350          2017                  6.7       12.0   Automatic (S8)
# ...           ...                  ...        ...              ...
# 35363        1984                  1.6        4.0  Automatic 3-spd
# 35308        1984                  1.0        4.0     Manual 4-spd
# 35349        1984                  1.0        4.0     Manual 4-spd
# 35360        1984                  1.0        4.0     Manual 4-spd
# 35359        1984                  1.0        4.0     Manual 4-spd
#
#                        drivetrain                vehicle_class fuel_type  \
# 670              Rear-Wheel Drive                  Two Seaters   Premium
# 227              Rear-Wheel Drive                 Midsize Cars   Premium
# 464              Rear-Wheel Drive                 Compact Cars   Premium
# 69               Rear-Wheel Drive                   Large Cars   Premium
# 350              Rear-Wheel Drive                 Compact Cars   Premium
# ...                           ...                          ...       ...
# 35363               2-Wheel Drive  Special Purpose Vehicle 2WD    Diesel
# 35308  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD   Regular
# 35349  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD   Regular
# 35360  4-Wheel or All-Wheel Drive      Small Pickup Trucks 4WD   Regular
# 35359  4-Wheel or All-Wheel Drive      Small Pickup Trucks 4WD   Regular
#
#        fuel_barrels_by_year  city_mpg  highway_mpg  combined_mpg  \
# 670               23.543571        12           19            14
# 227               23.543571        11           18            14
# 464               23.543571        11           19            14
# 69                23.543571        11           19            14
# 350               23.543571        11           19            14
# ...                     ...       ...          ...           ...
# 35363             14.155000        27           27            27
# 35308             14.982273        22           22            22
# 35349             14.982273        22           22            22
# 35360             14.982273        22           22            22
# 35359             17.347895        18           20            19
#
#        co2_emission_grams_by_mile  fuel_cost_by_year  \
# 670                    623.000000               2900
# 227                    652.000000               2900
# 464                    638.000000               2900
# 69                     637.000000               2900
# 350                    637.000000               2900
# ...                           ...                ...
# 35363                  377.037037               1350
# 35308                  403.954545               1500
# 35349                  403.954545               1500
# 35360                  403.954545               1500
# 35359                  467.736842               1750
#
#                                               id cyl_6
# 670                               DodgeViper2017   NaN
# 227                          BentleyMulsanne2017   NaN
# 464                 Rolls-RoycePhantom Coupe2017   NaN
# 69                    Rolls-RoycePhantom EWB2017   NaN
# 350        Rolls-RoycePhantom Drophead Coupe2017   NaN
# ...                                          ...   ...
# 35363                    Grumman OlsonKubvan1984   NaN
# 35308                       SuzukiSJ 410 4WD1984   NaN
# 35349                      SuzukiSJ 410V 4WD1984   NaN
# 35360                   SuzukiSJ410K P/U 4WD1984   NaN
# 35359  Import Foreign Auto Sales Inc1fas 4101984   NaN
#
# [35952 rows x 18 columns]

# %%
tb_veic_2[tb_veic['cylinders'] == 6]
# Out:
#        index       make                 model  model_year  \
# 65     16088        GMC        Sierra C15 2WD        2017
# 240    16168        GMC        Sierra K15 4WD        2017
# 58      7207  Chevrolet     Silverado K15 4WD        2017
# 63      7131  Chevrolet     Silverado C15 2WD        2017
# 619    29301    Porsche   911 Turbo Cabriolet        2017
# ...      ...        ...                   ...         ...
# 35861   7457  Chevrolet  T10 (S10) Blazer 4WD        1984
# 35858   7455  Chevrolet  T10 (S10) Blazer 4WD        1984
# 35859   7456  Chevrolet  T10 (S10) Blazer 4WD        1984
# 35853   6772  Chevrolet   S10 Cab Chassis 2WD        1984
# 35586   6947  Chevrolet  S10 Utility Body 2WD        1984
#
#        engine_displacement  cylinders     transmission  \
# 65                     4.3        6.0  Automatic 6-spd
# 240                    4.3        6.0  Automatic 6-spd
# 58                     4.3        6.0  Automatic 6-spd
# 63                     4.3        6.0  Automatic 6-spd
# 619                    3.8        6.0      Auto(AM-S7)
# ...                    ...        ...              ...
# 35861                  2.8        6.0     Manual 5-spd
# 35858                  2.8        6.0  Automatic 4-spd
# 35859                  2.8        6.0     Manual 4-spd
# 35853                  2.8        6.0  Automatic 4-spd
# 35586                  2.8        6.0  Automatic 4-spd
#
#                        drivetrain                vehicle_class  \
# 65               Rear-Wheel Drive   Standard Pickup Trucks 2WD
# 240                 4-Wheel Drive   Standard Pickup Trucks 4WD
# 58                  4-Wheel Drive   Standard Pickup Trucks 4WD
# 63               Rear-Wheel Drive   Standard Pickup Trucks 2WD
# 619               All-Wheel Drive             Minicompact Cars
# ...                           ...                          ...
# 35861  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD
# 35858  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD
# 35859  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD
# 35853               2-Wheel Drive     Special Purpose Vehicles
# 35586               2-Wheel Drive  Special Purpose Vehicle 2WD
#
#              fuel_type  fuel_barrels_by_year  city_mpg  highway_mpg  \
# 65     Gasoline or E85             16.480500        18           24
# 240    Gasoline or E85             17.347895        17           22
# 58     Gasoline or E85             17.347895        17           22
# 63     Gasoline or E85             16.480500        18           24
# 619            Premium             15.695714        19           24
# ...                ...                   ...       ...          ...
# 35861          Regular             19.388824        15           22
# 35858          Regular             18.311667        15           22
# 35859          Regular             19.388824        15           20
# 35853          Regular             25.354615        13           13
# 35586          Regular             18.311667        16           22
#
#        combined_mpg  co2_emission_grams_by_mile  fuel_cost_by_year  \
# 65               20                  448.000000               1650
# 240              19                  474.000000               1750
# 58               19                  473.000000               1750
# 63               20                  448.000000               1650
# 619              21                  430.000000               1950
# ...             ...                         ...                ...
# 35861            17                  522.764706               1950
# 35858            18                  493.722222               1850
# 35859            17                  522.764706               1950
# 35853            13                  683.615385               2550
# 35586            18                  493.722222               1850
#
#                                       id cyl_6
# 65                 GMCSierra C15 2WD2017  True
# 240                GMCSierra K15 4WD2017  True
# 58        ChevroletSilverado K15 4WD2017  True
# 63        ChevroletSilverado C15 2WD2017  True
# 619       Porsche911 Turbo Cabriolet2017  True
# ...                                  ...   ...
# 35861  ChevroletT10 (S10) Blazer 4WD1984  True
# 35858  ChevroletT10 (S10) Blazer 4WD1984  True
# 35859  ChevroletT10 (S10) Blazer 4WD1984  True
# 35853   ChevroletS10 Cab Chassis 2WD1984  True
# 35586  ChevroletS10 Utility Body 2WD1984  True
#
# [12765 rows x 18 columns]

# %%
tb_veic_2.loc[tb_veic['cylinders'] != 6, 'cyl_6'] = False
tb_veic_2
# Out:
#        index                           make                   model  \
# 670    10889                          Dodge                   Viper
# 227     3191                        Bentley                Mulsanne
# 464    30043                    Rolls-Royce           Phantom Coupe
# 69     30064                    Rolls-Royce             Phantom EWB
# 350    30053                    Rolls-Royce  Phantom Drophead Coupe
# ...      ...                            ...                     ...
# 35363  16887                  Grumman Olson                  Kubvan
# 35308  31980                         Suzuki              SJ 410 4WD
# 35349  31982                         Suzuki             SJ 410V 4WD
# 35360  31984                         Suzuki          SJ410K P/U 4WD
# 35359  18408  Import Foreign Auto Sales Inc                1fas 410
#
#        model_year  engine_displacement  cylinders     transmission  \
# 670          2017                  8.4       10.0     Manual 6-spd
# 227          2017                  6.8        8.0   Automatic (S8)
# 464          2017                  6.7       12.0   Automatic (S8)
# 69           2017                  6.7       12.0   Automatic (S8)
# 350          2017                  6.7       12.0   Automatic (S8)
# ...           ...                  ...        ...              ...
# 35363        1984                  1.6        4.0  Automatic 3-spd
# 35308        1984                  1.0        4.0     Manual 4-spd
# 35349        1984                  1.0        4.0     Manual 4-spd
# 35360        1984                  1.0        4.0     Manual 4-spd
# 35359        1984                  1.0        4.0     Manual 4-spd
#
#                        drivetrain                vehicle_class fuel_type  \
# 670              Rear-Wheel Drive                  Two Seaters   Premium
# 227              Rear-Wheel Drive                 Midsize Cars   Premium
# 464              Rear-Wheel Drive                 Compact Cars   Premium
# 69               Rear-Wheel Drive                   Large Cars   Premium
# 350              Rear-Wheel Drive                 Compact Cars   Premium
# ...                           ...                          ...       ...
# 35363               2-Wheel Drive  Special Purpose Vehicle 2WD    Diesel
# 35308  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD   Regular
# 35349  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD   Regular
# 35360  4-Wheel or All-Wheel Drive      Small Pickup Trucks 4WD   Regular
# 35359  4-Wheel or All-Wheel Drive      Small Pickup Trucks 4WD   Regular
#
#        fuel_barrels_by_year  city_mpg  highway_mpg  combined_mpg  \
# 670               23.543571        12           19            14
# 227               23.543571        11           18            14
# 464               23.543571        11           19            14
# 69                23.543571        11           19            14
# 350               23.543571        11           19            14
# ...                     ...       ...          ...           ...
# 35363             14.155000        27           27            27
# 35308             14.982273        22           22            22
# 35349             14.982273        22           22            22
# 35360             14.982273        22           22            22
# 35359             17.347895        18           20            19
#
#        co2_emission_grams_by_mile  fuel_cost_by_year  \
# 670                    623.000000               2900
# 227                    652.000000               2900
# 464                    638.000000               2900
# 69                     637.000000               2900
# 350                    637.000000               2900
# ...                           ...                ...
# 35363                  377.037037               1350
# 35308                  403.954545               1500
# 35349                  403.954545               1500
# 35360                  403.954545               1500
# 35359                  467.736842               1750
#
#                                               id  cyl_6
# 670                               DodgeViper2017  False
# 227                          BentleyMulsanne2017  False
# 464                 Rolls-RoycePhantom Coupe2017  False
# 69                    Rolls-RoycePhantom EWB2017  False
# 350        Rolls-RoycePhantom Drophead Coupe2017  False
# ...                                          ...    ...
# 35363                    Grumman OlsonKubvan1984  False
# 35308                       SuzukiSJ 410 4WD1984  False
# 35349                      SuzukiSJ 410V 4WD1984  False
# 35360                   SuzukiSJ410K P/U 4WD1984  False
# 35359  Import Foreign Auto Sales Inc1fas 4101984  False
#
# [35952 rows x 18 columns]

# %%
tb_veic_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35952 entries, 670 to 35359
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   index                       35952 non-null  int64
#  1   make                        35952 non-null  object
#  2   model                       35952 non-null  object
#  3   model_year                  35952 non-null  int64
#  4   engine_displacement         35952 non-null  float64
#  5   cylinders                   35952 non-null  float64
#  6   transmission                35952 non-null  object
#  7   drivetrain                  35952 non-null  object
#  8   vehicle_class               35952 non-null  object
#  9   fuel_type                   35952 non-null  object
#  10  fuel_barrels_by_year        35952 non-null  float64
#  11  city_mpg                    35952 non-null  int64
#  12  highway_mpg                 35952 non-null  int64
#  13  combined_mpg                35952 non-null  int64
#  14  co2_emission_grams_by_mile  35952 non-null  float64
#  15  fuel_cost_by_year           35952 non-null  int64
#  16  id                          35952 non-null  object
#  17  cyl_6                       35952 non-null  object
# dtypes: float64(4), int64(6), object(8)
# memory usage: 5.2+ MB

# %%
tb_veic_2.describe()
# Out:
#               index   model_year  engine_displacement     cylinders  \
# count  35952.000000  35952.00000         35952.000000  35952.000000
# mean   17975.500000   2000.71640             3.338493      5.765076
# std    10378.592776     10.08529             1.359395      1.755268
# min        0.000000   1984.00000             0.600000      2.000000
# 25%     8987.750000   1991.00000             2.200000      4.000000
# 50%    17975.500000   2001.00000             3.000000      6.000000
# 75%    26963.250000   2010.00000             4.300000      6.000000
# max    35951.000000   2017.00000             8.400000     16.000000
#
#        fuel_barrels_by_year      city_mpg   highway_mpg  combined_mpg  \
# count          35952.000000  35952.000000  35952.000000  35952.000000
# mean              17.609056     17.646139     23.880646     19.929322
# std                4.467283      4.769349      5.890876      5.112409
# min                0.060000      6.000000      9.000000      7.000000
# 25%               14.699423     15.000000     20.000000     16.000000
# 50%               17.347895     17.000000     24.000000     19.000000
# 75%               20.600625     20.000000     27.000000     23.000000
# max               47.087143     58.000000     61.000000     56.000000
#
#        co2_emission_grams_by_mile  fuel_cost_by_year
# count                35952.000000       35952.000000
# mean                   475.316339        1892.598465
# std                    119.060773         506.958627
# min                     37.000000         600.000000
# 25%                    395.000000        1500.000000
# 50%                    467.736842        1850.000000
# 75%                    555.437500        2200.000000
# max                   1269.571429        5800.000000

# %%
tb_veic_2.loc[tb_veic_2['city_mpg']  < 15, 'eff_city'] = 'C'
tb_veic_2.loc[(tb_veic_2['city_mpg']  >= 15) & (tb_veic_2['city_mpg']  < 20), 'eff_city'] = 'B'
tb_veic_2.loc[tb_veic_2['city_mpg']  >= 20, 'eff_city'] = 'A'

# %%
tb_veic_2['eff_city'].value_counts()
# Out:
# B    17601
# A     9879
# C     8472
# Name: eff_city, dtype: int64

# %%
p25_citympg = tb_veic_2['city_mpg']  < 15
p75_citympg = tb_veic_2['city_mpg'] < 20

# %%
print(p75_citympg)
# Out:
# 670       True
# 227       True
# 464       True
# 69        True
# 350       True
#          ...
# 35363    False
# 35308    False
# 35349    False
# 35360    False
# 35359     True
# Name: city_mpg, Length: 35952, dtype: bool

# %%
tb_veic_2.loc[p25_citympg, 'eff_city'] = 'C'
tb_veic_2.loc[~p25_citympg & p75_citympg, 'eff_city'] = 'B'
tb_veic_2.loc[~p75_citympg, 'eff_city'] = 'A'

# %%
tb_veic_2['eff_city'].value_counts()
# Out:
# B    17601
# A     9879
# C     8472
# Name: eff_city, dtype: int64

# %%
# np.where(CONDICAO, VALOR_SE_VERDADEIRO, VALOR_SE_FALSO)
tb_veic['cyl_6'] = np.where(tb_veic['cylinders'] == 6, True, False)
print(tb_veic['cyl_6'].describe())
sum(tb_veic['cyl_6'])
# Out:
# count     35952
# unique        2
# top       False
# freq      23187
# Name: cyl_6, dtype: object
# 12765

# %%
tb_veic['cyl_6_ford'] = np.where((tb_veic['make'] == 'Ford') & (tb_veic['cylinders'] == 6),
                                 True,
                                 False)
print(tb_veic['cyl_6_ford'].describe())
sum(tb_veic['cyl_6_ford'])
# Out:
# count     35952
# unique        2
# top       False
# freq      34659
# Name: cyl_6_ford, dtype: object
# 1293

# %%
tb_veic['seila'] = tb_veic['cylinders'] * tb_veic['highway_mpg']
tb_veic.describe()
# Out:
#               index   model_year  engine_displacement     cylinders  \
# count  35952.000000  35952.00000         35952.000000  35952.000000
# mean   17975.500000   2000.71640             3.338493      5.765076
# std    10378.592776     10.08529             1.359395      1.755268
# min        0.000000   1984.00000             0.600000      2.000000
# 25%     8987.750000   1991.00000             2.200000      4.000000
# 50%    17975.500000   2001.00000             3.000000      6.000000
# 75%    26963.250000   2010.00000             4.300000      6.000000
# max    35951.000000   2017.00000             8.400000     16.000000
#
#        fuel_barrels_by_year      city_mpg   highway_mpg  combined_mpg  \
# count          35952.000000  35952.000000  35952.000000  35952.000000
# mean              17.609056     17.646139     23.880646     19.929322
# std                4.467283      4.769349      5.890876      5.112409
# min                0.060000      6.000000      9.000000      7.000000
# 25%               14.699423     15.000000     20.000000     16.000000
# 50%               17.347895     17.000000     24.000000     19.000000
# 75%               20.600625     20.000000     27.000000     23.000000
# max               47.087143     58.000000     61.000000     56.000000
#
#        co2_emission_grams_by_mile  fuel_cost_by_year         seila
# count                35952.000000       35952.000000  35952.000000
# mean                   475.316339        1892.598465    130.949905
# std                    119.060773         506.958627     28.964032
# min                     37.000000         600.000000     40.000000
# 25%                    395.000000        1500.000000    108.000000
# 50%                    467.736842        1850.000000    128.000000
# 75%                    555.437500        2200.000000    150.000000
# max                   1269.571429        5800.000000    264.000000

# %%
sum(tb_veic['city_mpg'] > tb_veic['highway_mpg'])
# Out:
# 183

# %%
tb_veic['co2grams_by_gallon'] = np.where(tb_veic['city_mpg'] > tb_veic['highway_mpg'],
                               tb_veic['co2_emission_grams_by_mile']/tb_veic['highway_mpg'],
                               tb_veic['co2_emission_grams_by_mile']/tb_veic['city_mpg'],
                              )
print(tb_veic['co2grams_by_gallon'].describe())
# Out:
# count    35952.000000
# mean        30.523495
# std         16.005434
# min          1.000000
# 25%         19.900000
# 50%         27.513932
# 75%         37.029167
# max        211.595238
# Name: co2grams_by_gallon, dtype: float64

# %%
tb_veic['eff_city'] = np.where(tb_veic['city_mpg'] < 15, 'C',
                               np.where(tb_veic['city_mpg'] < 20, 'B', 'A'))
tb_veic['eff_city'].value_counts()
# Out:
# B    17601
# A     9879
# C     8472
# Name: eff_city, dtype: int64

# %% [markdown]
# ## Another way to do the same thing

# %% [markdown]
# * using the method `query`
#
# The method `query` receives a string in which you can say your condition. Important things:
# - `.query()` is a method of your dataframe
# - `.query()` method receives a string
# - Every word inside the string that is not `quoted` is considered a variable of your dataframe (so, for example `.query('Year == 1999')` will look for the variable `Year`. Another example: if you try to run `.query('Make == Ford')` will look both for the column name `Make` and the column named `Ford`. If you want the results of the column `Make` to match the **string** Ford, you have to run `.query('Make == "Ford"')`
# - If your column has spaces, you have to call it using backticks like in **.query('\`Engine Displacement\` < 4')**:

# %%
tb_veic.query('model_year == 2016')
# Out:
#       index         make                   model  model_year  \
# 1113  10911        Dodge               Viper SRT        2016
# 1952   3190      Bentley                Mulsanne        2016
# 1970  30052  Rolls-Royce  Phantom Drophead Coupe        2016
# 1958  30063  Rolls-Royce             Phantom EWB        2016
# 1904  30042  Rolls-Royce           Phantom Coupe        2016
# ...     ...          ...                     ...         ...
# 1251  13310         Ford               Focus FWD        2016
# 1271  13314         Ford               Focus FWD        2016
# 1740  35950        smart            fortwo coupe        2016
# 1005  35951        smart            fortwo coupe        2016
# 1977   3071          BMW                  i3 REX        2016
#
#       engine_displacement  cylinders    transmission         drivetrain  \
# 1113                  8.4       10.0    Manual 6-spd   Rear-Wheel Drive
# 1952                  6.8        8.0  Automatic (S8)   Rear-Wheel Drive
# 1970                  6.7       12.0  Automatic (S8)   Rear-Wheel Drive
# 1958                  6.7       12.0  Automatic (S8)   Rear-Wheel Drive
# 1904                  6.7       12.0  Automatic (S8)   Rear-Wheel Drive
# ...                   ...        ...             ...                ...
# 1251                  1.0        3.0    Manual 6-spd  Front-Wheel Drive
# 1271                  1.0        3.0  Automatic (S6)  Front-Wheel Drive
# 1740                  0.9        3.0       Auto(AM6)   Rear-Wheel Drive
# 1005                  0.9        3.0    Manual 5-spd   Rear-Wheel Drive
# 1977                  0.6        2.0  Automatic (A1)   Rear-Wheel Drive
#
#         vehicle_class                   fuel_type  ...  highway_mpg  \
# 1113      Two Seaters                     Premium  ...           21
# 1952     Midsize Cars                     Premium  ...           18
# 1970     Compact Cars                     Premium  ...           19
# 1958       Large Cars                     Premium  ...           19
# 1904     Compact Cars                     Premium  ...           19
# ...               ...                         ...  ...          ...
# 1251     Compact Cars                     Regular  ...           42
# 1271     Compact Cars                     Regular  ...           40
# 1740      Two Seaters                     Premium  ...           39
# 1005      Two Seaters                     Premium  ...           39
# 1977  Subcompact Cars  Premium Gas or Electricity  ...           37
#
#       combined_mpg  co2_emission_grams_by_mile  fuel_cost_by_year  \
# 1113            15                       579.0               2700
# 1952            13                       656.0               3100
# 1970            14                       637.0               2900
# 1958            14                       637.0               2900
# 1904            14                       638.0               2900
# ...            ...                         ...                ...
# 1251            35                       255.0                950
# 1271            32                       272.0               1050
# 1740            36                       246.0               1100
# 1005            35                       255.0               1150
# 1977            39                        37.0               1050
#
#                                          id  cyl_6 cyl_6_ford  seila  \
# 1113                     DodgeViper SRT2016  False      False  210.0
# 1952                    BentleyMulsanne2016  False      False  144.0
# 1970  Rolls-RoycePhantom Drophead Coupe2016  False      False  228.0
# 1958             Rolls-RoycePhantom EWB2016  False      False  228.0
# 1904           Rolls-RoycePhantom Coupe2016  False      False  228.0
# ...                                     ...    ...        ...    ...
# 1251                      FordFocus FWD2016  False      False  126.0
# 1271                      FordFocus FWD2016  False      False  120.0
# 1740                  smartfortwo coupe2016  False      False  117.0
# 1005                  smartfortwo coupe2016  False      False  117.0
# 1977                          BMWi3 REX2016  False      False   74.0
#
#       co2grams_by_gallon  eff_city
# 1113           48.250000         C
# 1952           59.636364         C
# 1970           57.909091         C
# 1958           57.909091         C
# 1904           58.000000         C
# ...                  ...       ...
# 1251            8.500000         A
# 1271            9.714286         A
# 1740            7.235294         A
# 1005            7.968750         A
# 1977            1.000000         A
#
# [1228 rows x 22 columns]

# %%
tb_veic.\
    query('make == "Ford"').\
    query('cylinders == 6').\
    query('model_year == 2017')
# Out:
#   File "<ipython-input-119-67027e98fa60>", line 1
#     tb_veic.
#             ^
# SyntaxError: invalid syntax
