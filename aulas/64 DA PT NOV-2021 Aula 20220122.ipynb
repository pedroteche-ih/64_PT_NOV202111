# %%
# !pip3 install bs4

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # The url to scrape

# %%
url = 'https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm'

# %% [markdown]
# # Get the response

# %%
response = requests.get(url)

# %%
html_str = response.text
type(html_str)
# Out:
# str

# %%
html_str
# Out:
# '<!DOCTYPE html> <html lang="pt-br"> <head><meta charset="utf-8"><meta http-equiv="Content-Type" content="text/html; charset=utf-8">   <title>Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu - 22/01/2022 - UOL Esporte</title><link rel="preconnect" href="https://stc.uol.com" crossorigin="anonymous"><link rel="preconnect" href="https://c.jsuol.com.br" crossorigin="anonymous"><link rel="preconnect" href="https://conteudo.jsuol.com.br" crossorigin="anonymous"><link rel="preconnect" href="https://conteudo.imguol.com.br" crossorigin="anonymous"><link rel="preconnect" href="https://me.jsuol.com.br" crossorigin="anonymous"><link rel="preconnect" href="https://www.google-analytics.com" crossorigin="anonymous"><link rel="dns-prefetch" href="https://stc.uol.com"><link rel="dns-prefetch" href="https://c.jsuol.com.br"><link rel="dns-prefetch" href="https://conteudo.jsuol.com.br"><link rel="dns-prefetch" href="https://conteudo.imguol.com.br"><link rel="dns-prefetch" href="https://me.jsuol.com.br"><link rel="dns-prefetch" href="https://www.google-analytics.com"><link rel="dns-prefetch" href="//securepubads.g.doubleclick.net.com"><link rel="dns-prefetch" href="//tt-10162-1.seg.t.tailtarget.com"><link rel="dns-prefetch" href="https://tm.uol.com.br"><link rel="dns-prefetch" href="https://tm.jsuol.com.br">  <link rel="preload" href="https://stc.uol.com/c/webfont/projeto-grafico/v2/icones-setas/uol-icones-setas.woff?v6" as="font" crossorigin="anonymous" type="font/woff">  <link rel="preload" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-lighter.woff2?v5" as="font" crossorigin="anonymous" type="font/woff2">  <link rel="preload" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-light.woff2?v5" as="font" crossorigin="anonymous" type="font/woff2">  <link rel="preload" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-regular.woff2?v5" as="font" crossorigin="anonymous" type="font/woff2">   <link rel="preload" href="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_900x506.jpg.webp" as="image"  media="(min-width: 768px)"  >  <link rel="preload" href="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_900x506.jpg" as="image"  media="(min-width: 768px)"  >  <link rel="preload" href="https://me.jsuol.com.br/aud/uolestacoes.js" as="script" crossorigin="anonymous"><link rel="preload" href="//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/jquery.min&cache=202201201930" as="script" crossorigin="anonymous"><link rel="preload" href="//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/audience/audience.min&cache=202201201930" as="script" crossorigin="anonymous">   <meta property="fb:pages" content="115401215190141">    <meta property="fb:pages" content="21539158238">    <meta property="fb:pages" content="146391125938238">    <meta property="fb:pages" content="702958396425837">    <meta property="fb:pages" content="221456874659747">    <meta property="fb:pages" content="124493634232128">    <meta property="fb:pages" content="123014924007">    <meta property="fb:pages" content="124400289445">    <meta property="fb:pages" content="143813098922">    <meta property="fb:pages" content="112341259449730">    <meta property="fb:pages" content="357889721305340">    <meta property="fb:pages" content="120098554660">    <meta  name="referrer" content="always">  <meta  name="description" content="Acostumado a ter em seu gramado grandes jogadores, dribles desconcertantes e gols inesquecíveis, o estádio do Pacaembu teve uma manhã diferente no dia 20 de agosto de 1995. Palmeiras e São Paulo - que se enfrentam neste sábado (22), pela semifinal da C">  <meta  name="robots" content="inde ...

# %% [markdown]
# # Get the html

# %%
# Your code here!
html_bytes = response.content
type(html_bytes)
# Out:
# bytes

# %%
html_bytes
# Out:
# b'<!DOCTYPE html> <html lang="pt-br"> <head><meta charset="utf-8"><meta http-equiv="Content-Type" content="text/html; charset=utf-8">   <title>Em 1995, decis\xc3\xa3o na base entre Palmeiras x SP terminou em morte no Pacaembu - 22/01/2022 - UOL Esporte</title><link rel="preconnect" href="https://stc.uol.com" crossorigin="anonymous"><link rel="preconnect" href="https://c.jsuol.com.br" crossorigin="anonymous"><link rel="preconnect" href="https://conteudo.jsuol.com.br" crossorigin="anonymous"><link rel="preconnect" href="https://conteudo.imguol.com.br" crossorigin="anonymous"><link rel="preconnect" href="https://me.jsuol.com.br" crossorigin="anonymous"><link rel="preconnect" href="https://www.google-analytics.com" crossorigin="anonymous"><link rel="dns-prefetch" href="https://stc.uol.com"><link rel="dns-prefetch" href="https://c.jsuol.com.br"><link rel="dns-prefetch" href="https://conteudo.jsuol.com.br"><link rel="dns-prefetch" href="https://conteudo.imguol.com.br"><link rel="dns-prefetch" href="https://me.jsuol.com.br"><link rel="dns-prefetch" href="https://www.google-analytics.com"><link rel="dns-prefetch" href="//securepubads.g.doubleclick.net.com"><link rel="dns-prefetch" href="//tt-10162-1.seg.t.tailtarget.com"><link rel="dns-prefetch" href="https://tm.uol.com.br"><link rel="dns-prefetch" href="https://tm.jsuol.com.br">  <link rel="preload" href="https://stc.uol.com/c/webfont/projeto-grafico/v2/icones-setas/uol-icones-setas.woff?v6" as="font" crossorigin="anonymous" type="font/woff">  <link rel="preload" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-lighter.woff2?v5" as="font" crossorigin="anonymous" type="font/woff2">  <link rel="preload" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-light.woff2?v5" as="font" crossorigin="anonymous" type="font/woff2">  <link rel="preload" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-regular.woff2?v5" as="font" crossorigin="anonymous" type="font/woff2">   <link rel="preload" href="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_900x506.jpg.webp" as="image"  media="(min-width: 768px)"  >  <link rel="preload" href="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_900x506.jpg" as="image"  media="(min-width: 768px)"  >  <link rel="preload" href="https://me.jsuol.com.br/aud/uolestacoes.js" as="script" crossorigin="anonymous"><link rel="preload" href="//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/jquery.min&cache=202201201930" as="script" crossorigin="anonymous"><link rel="preload" href="//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/audience/audience.min&cache=202201201930" as="script" crossorigin="anonymous">   <meta property="fb:pages" content="115401215190141">    <meta property="fb:pages" content="21539158238">    <meta property="fb:pages" content="146391125938238">    <meta property="fb:pages" content="702958396425837">    <meta property="fb:pages" content="221456874659747">    <meta property="fb:pages" content="124493634232128">    <meta property="fb:pages" content="123014924007">    <meta property="fb:pages" content="124400289445">    <meta property="fb:pages" content="143813098922">    <meta property="fb:pages" content="112341259449730">    <meta property="fb:pages" content="357889721305340">    <meta property="fb:pages" content="120098554660">    <meta  name="referrer" content="always">  <meta  name="description" content="Acostumado a ter em seu gramado grandes jogadores, dribles desconcertantes e gols inesquec\xc3\xadveis, o est\xc3\xa1dio do Pacaembu teve uma manh\xc3\xa3 diferente no dia 20 de agosto de 1995. Palmeiras e S\xc3\xa3o Paulo - que se enfrentam neste s\xc3\xa1bado (22), pela semifinal ...

# %% [markdown]
# # Do the soup

# %%
soup = BeautifulSoup(html_bytes)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="pt-br"> <head><meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/> <title>Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu - 22/01/2022 - UOL Esporte</title><link crossorigin="anonymous" href="https://stc.uol.com" rel="preconnect"/><link crossorigin="anonymous" href="https://c.jsuol.com.br" rel="preconnect"/><link crossorigin="anonymous" href="https://conteudo.jsuol.com.br" rel="preconnect"/><link crossorigin="anonymous" href="https://conteudo.imguol.com.br" rel="preconnect"/><link crossorigin="anonymous" href="https://me.jsuol.com.br" rel="preconnect"/><link crossorigin="anonymous" href="https://www.google-analytics.com" rel="preconnect"/><link href="https://stc.uol.com" rel="dns-prefetch"/><link href="https://c.jsuol.com.br" rel="dns-prefetch"/><link href="https://conteudo.jsuol.com.br" rel="dns-prefetch"/><link href="https://conteudo.imguol.com.br" rel="dns-prefetch"/><link href="https://me.jsuol.com.br" rel="dns-prefetch"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><link href="//securepubads.g.doubleclick.net.com" rel="dns-prefetch"/><link href="//tt-10162-1.seg.t.tailtarget.com" rel="dns-prefetch"/><link href="https://tm.uol.com.br" rel="dns-prefetch"/><link href="https://tm.jsuol.com.br" rel="dns-prefetch"/> <link as="font" crossorigin="anonymous" href="https://stc.uol.com/c/webfont/projeto-grafico/v2/icones-setas/uol-icones-setas.woff?v6" rel="preload" type="font/woff"/> <link as="font" crossorigin="anonymous" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-lighter.woff2?v5" rel="preload" type="font/woff2"/> <link as="font" crossorigin="anonymous" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-light.woff2?v5" rel="preload" type="font/woff2"/> <link as="font" crossorigin="anonymous" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-regular.woff2?v5" rel="preload" type="font/woff2"/> <link as="image" href="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_900x506.jpg.webp" media="(min-width: 768px)" rel="preload"/> <link as="image" href="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_900x506.jpg" media="(min-width: 768px)" rel="preload"/> <link as="script" crossorigin="anonymous" href="https://me.jsuol.com.br/aud/uolestacoes.js" rel="preload"/><link as="script" crossorigin="anonymous" href="//c.jsuol.com.br/assets/?loadComponent=media&amp;contentType=js&amp;tpl=assets/dist/libs/jquery.min&amp;cache=202201201930" rel="preload"/><link as="script" crossorigin="anonymous" href="//c.jsuol.com.br/assets/?loadComponent=media&amp;contentType=js&amp;tpl=assets/dist/audience/audience.min&amp;cache=202201201930" rel="preload"/> <meta content="115401215190141" property="fb:pages"/> <meta content="21539158238" property="fb:pages"/> <meta content="146391125938238" property="fb:pages"/> <meta content="702958396425837" property="fb:pages"/> <meta content="221456874659747" property="fb:pages"/> <meta content="124493634232128" property="fb:pages"/> <meta content="123014924007" property="fb:pages"/> <meta content="124400289445" property="fb:pages"/> <meta content="143813098922" property="fb:pages"/> <meta content="112341259449730" property="fb:pages"/> <meta content="357889721305340" property="fb:pages"/> <meta content="120098554660" property="fb:pages"/> <meta content="always" name="referrer"/> <meta content="Acostumado a ter em seu gramado grandes jogadores, dribles desconcertantes e gols inesquecíveis, o estádio do Pacaembu teve uma manhã diferente no dia 20 de agosto de 1995. Palmeiras e São Paulo - que se enfrentam neste sábado (22), pela semifinal da C" name="description"/> <meta content="index,follow,max-image-previe ...
#             window.createMeasureObserver = (measureName) => {
#                 var markPrefix = `_uol-measure-${measureName}-${new Date().getTime()}`;
#
#                 performance.mark(`${markPrefix}-start`);
#
#                 return {
#                     end: function() {
#                         performance.mark(`${markPrefix}-end`);
#                         performance.measure(`uol-measure-${measureName}`, `${markPrefix}-start`, `${markPrefix}-end`);
#                         performance.clearMarks(`${markPrefix}-start`);
#                         performance.clearMarks(`${markPrefix}-end`);
#                     }
#                 }
#             };
#
#             /**
#             * Gerenciador de eventos
#             */
#             window.gevent = {
#                 stack: [],
#                 RUN_ONCE: true,
#                 on: function(name, callback, once) {
#                     this.stack.push([name, callback, !!once]);
#                 },
#                 emit: function(name, args) {
#                     for (var i = this.stack.length, item; i--;) {
#                         item = this.stack[i];
#                         if (item[0] === name) {
#                             item[1](args);
#                             if (item[2]) {
#                                 this.stack.splice(i, 1);
#                             }
#                         }
#                     }
#                 }
#             };
#
#             var runningSearch = false;
#             var hadAnUserEvent = true;
#             var elementsToWatch = window.elementsToWatch = new Map();
#             var innerHeight = window.innerHeight;
#
#             // timestamp da última rodada do requestAnimationFrame
#             // É usado para limitar a procura por elementos visíveis.
#             var lastAnimationTS = 0;
#
#             // verifica se elemento está no viewport do usuário
#             var isElementInViewport = function(el) {
#                 var rect = el.getBoundingClientRect();
#                 var clientHeight = window.innerHeight || document.documentElement.clientHeight;
#
#                 // garante que usa ao mínimo 280px de margem para fazer o lazyload
#                 var margin = clientHeight + Math.max(280, clientHeight * 0.2);
#
#                 // se a base do componente está acima da altura da tela do usuário, está oculto
#                 if(rect.bottom < 0 && rect.bottom > margin * -1) {
#                     return false;
#                 }
#
#                 // se o topo do elemento está abaixo da altura da tela do usuário, está oculto
#                 if(rect.top > margin) {
#                     return false;
#                 }
#
#                 // se a posição do topo é negativa, verifica se a altura dele ainda
#                 // compensa o que já foi scrollado
#                 if(rect.top < 0 && rect.height + rect.top < 0) {
#                     return false;
#                 }
#
#                 return true;
#             };
#
#             var asynxNextFreeTime = () => {
#                 return new Promise((resolve) => {
#                     if(window.requestIdleCallback) {
#                         window.requestIdleCallback(resolve, {
#                             timeout: 5000,
#                         });
#                     } else {
#                         window.requestAnimationFrame(resolve);
#                     }
#                 });
#             };
#
#             var asyncValidateIfElIsInViewPort = function(promise, el) {
#                 return promise.then(() => {
#                     if(el) {
#                         if(isElementInViewport(el) == true) {
#                             const cb = elementsToWatch.get(el);
#
#                             // remove da lista para não ser disparado novamente
#                             elementsToWatch.delete(el);
#
#                             cb();
#                         }
#                     }
#                 }).then(asynxNextFreeTime);
#             };
#
#             // inicia o fluxo de procura de elementos procurados
#             var look = function() {
#                 if(window.requestIdleCallback) {
#                     window.requestIdleCallback(findByVisibleElements, {
#                         timeout: 5000,
#                     });
#                 } else {
#                     window.requestAnimationFrame(findByVisibleElements);
#                 }
#             };
#
#             var findByVisibleElements = function(ts) {
#                 var elapsedSinceLast = ts - lastAnimationTS;
#
#                 // se não teve nenhum evento que possa alterar a página
#                 if(hadAnUserEvent == false) {
#                     return look();
#                 }
#
#                 if(elementsToWatch.size == 0) {
#                     return look();
#                 }
#
#                 if(runningSearch == true) {
#                     return look();
#                 }
#
#                 // procura por elementos visíveis apenas 5x/seg
#                 if(elapsedSinceLast < 1000/5) {
#                     return look();
#                 }
#
#                 // atualiza o último ts
#                 lastAnimationTS = ts;
#
#                 // reseta status de scroll para não entrar novamente aqui
#                 hadAnUserEvent = false;
#
#                 // indica que está rodando a procura por elementos no viewport
#                 runningSearch = true;
#
#                 const done = Array.from(elementsToWatch.keys()).reduce(asyncValidateIfElIsInViewPort, Promise.resolve());
#
#                 // obtém todos os elementos que podem ter view contabilizados
#                 //elementsToWatch.forEach(function(cb, el) {
#                 //    if(isElementInViewport(el) == true) {
#                 //        // remove da lista para não ser disparado novamente
#                 //        elementsToWatch.delete(el);
#                 //        cb(el);
#                 //    }
#                 //});
#
#                 done.then(function() { runningSearch = false; });
#
#                 // reinicia o fluxo de procura
#                 look();
#             };
#
#             /**
#             * Quando o elemento `el` entrar no viewport (-20%), cb será disparado.
#             */
#             window.lazyload = function(el, cb) {
#                 if(el.nodeType != Node.ELEMENT_NODE) {
#                     throw new Error("element parameter should be a Element Node");
#                 }
#
#                 if(typeof cb !== 'function') {
#                     throw new Error("callback parameter should be a Function");
#                 }
#
#                 elementsToWatch.set(el, cb);
#             }
#
#             var setUserEvent = function() {
#                 hadAnUserEvent = true;
#             };
#
#             window.addEventListener('scroll', setUserEvent, { capture: true, passive: true });
#             window.addEventListener('click', setUserEvent, { passive: true });
#             window.addEventListener('resize', setUserEvent, { passive: true });
#             window.addEventListener('load', setUserEvent, { once: true, passive: true });
#             window.addEventListener('DOMContentLoaded', setUserEvent, { once: true, passive: true });
#             window.gevent.on('allJSLoadedAndCreated', setUserEvent, window.gevent.RUN_ONCE);
#
#             // inicia a validação
#             look();
#         })();</script><script type="text/javascript">var inHeadTS=(new Date).getTime();window.isUolNewGraphicDesign=!0,window.uolads=window.uolads||[],window.universal_variable=window.universal_variable||{},window.universal_variable.dfp={custom_params:{subchan:"",keyword:""}},window.universal_variable.page=window.universal_variable.page||{},window.universal_variable.page.tags=[15308,12810,79585,16026,16130];var _sf_async_config=_sf_async_config||{};_sf_async_config.uid=61085,_sf_async_config.domain="uol.com.br",_sf_async_config.flickerControl=!1,_sf_async_config.useCanonical=!0,_sf_async_config.autoDetect=!1;var _sf_startpt=(new Date).getTime();</script><script type="text/javascript">!function(t,n,o){t[n]=t[n]||function(){(t[n].q=t[n].q||[]).push(arguments)},t[n].t=t[n].t||[],t[n].t.push(o)}(window,"uolAnalytics","uolestacoes")</script><script async="" crossorigin="anonymous" src="https://me.jsuol.com.br/aud/uolestacoes.js"></script> <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script async="" src="https://tm.jsuol.com.br/modules/external/Prebid.js"></script><script async="" src="https://tm.jsuol.com.br/modules/external/tailtarget/profiles.js"></script><script async="" src="https://tm.jsuol.com.br/modules/external/tailtarget/t3m/TT-10162-1/CT-10.js"></script> <script async="" src="https://tm.jsuol.com.br/uoltm.js?id=zvcg6p"></script> <script async="" src="https://static.chartbeat.com/js/chartbeat_mab.js"></script> <script type="text/javascript">var Component={}</script> <script id="see-jserror" type="text/javascript">;(function(window) {
#     // Valida se o navegador possui suporte para `Symbol`. Se não tiver,
#     // está em um range de navegadores não mais suportados pelo UOL e que
#     // não precisam ter o registro de erros feito.
#     var isBrowserSupported = "Symbol" in window;
#
#     console.log('[see-jserror] ativando registro de erro', isBrowserSupported);
#
#     var historyErrors = [{
#         message: "Script error.",
#         stack: "Script error. at :0:0"
#     }];
#
#     var findError = function(data) {
#         data = data || {};
#         for(var i=0; i < historyErrors.length; i++) {
#             if(data.message == historyErrors[i].message && data.stack == historyErrors[i].stack) {
#                 console.log('[see-jserror] erro já reportado');
#                 return true;
#             }
#         }
#
#         historyErrors.push(data);
#
#         return false;
#     };
#
#     var storageValidation = (function(window) {
#         'use strict';
#         var validation;
#         try {
#             // IE <= 9 e demais navegadores devem retornar TRUE
#             validation = !!window.localStorage;
#
#             // Se estiver em modo Private no Safari, DOM Exception será retornado,
#             // alegando falta de espaço para armazenamento.
#             if(validation === true) {
#                 localStorage.setItem('__test', '');
#                 localStorage.removeItem('__test');
#             }
#         } catch(e) {
#             // possível erro de Access Denied no IE 10 ou
#             // modo private no Safari.
#             validation = false;
#         }
#         return validation;
#     }(window));
#
#     function getAdBlockerStatus() {
#         try {
#             switch (googlefc.getAdBlockerStatus()) {
#             case googlefc.AdBlockerStatusEnum.EXTENSION_LEVEL_AD_BLOCKER:
#                 return 'EXTENSION_LEVEL_AD_BLOCKER';
#
#             case googlefc.AdBlockerStatusEnum.NETWORK_LEVEL_AD_BLOCKER:
#                 return 'NETWORK_LEVEL_AD_BLOCKER';
#
#             case googlefc.AdBlockerStatusEnum.NO_AD_BLOCKER:
#                 return 'NO_AD_BLOCKER';
#
#             case googlefc.AdBlockerStatusEnum.UNKNOWN:
#                 return 'UNKNOWN';
#             }
#         } catch(err) {
#             return `GOOGLEFC_ERROR: ${err.message}`;
#         }
#     };
#
#     function continueReportError(data) {
#         console.log('[see-jserror] novo erro reportado');
#
#         var body = [{
#             'groupingMap': {
#                 'Url': window.location.href,
#                 'UserAgent': window.navigator.userAgent + '',
#                 'CookieAtivado': window.navigator.cookieEnabled + '',
#                 'Language': window.navigator.language,
#                 'LocalStorage': storageValidation + '',
#                 'Erro': data.message || '',
#                 'Stack': data.stack || '',
#                 'AdBlockerStatus': getAdBlockerStatus(),
#                 'HitJsDomain': 'true',
#                 'ErrorTime': data.ErrorTime,
#             },
#             'measureMap': {
#                 'JSErrors': 1
#             }
#         }];
#
#         // valida se tem acesso ao c.jsuol para descartar problemas de proxy ou bloqueios
#         // em redes corporativas / adblocks
#         fetch("https://c.jsuol.com.br/assets/?loadComponent=media&contentType=js").then(function(response) {
#             if(response.status == 200) {
#                 return Promise.resolve();
#             }
#
#             return Promise.reject('Failed to fetch, statusCode ' + response.status);
#         }).catch(function(err) {
#             body[0].groupingMap.HitJsDomain = 'false';
#             body[0].groupingMap.Erro += ' (hit jsuol: ' + err.message + ')';
#         }).then(function() {
#             var req = new XMLHttpRequest();
#             req.open('POST', '//logger.uol.com.br/v1/?prd=41&disp=true&mm=true', true);
#             req.setRequestHeader('Content-Type', 'application/json; charset=UTF-8');
#             req.send(JSON.stringify(body));
#         });
#     }
#
#     window.ReportError = function(data) {
#         if(isBrowserSupported === false) {
#             console.log('[see-jserror] browser not supported, ignoring error');
#             return undefined;
#         }
#
#         try {
#             console.log('[see-jserror] report error');
#
#             // utiliza try..catch para evitar loop
#             data = data || {};
#
#             if(findError(data) == true) {
#                 return undefined;
#             }
#
#             data.ErrorTime = performance.now();
#
#             // limita o wait ao Google FC em 5s para evitar perder registro de erro
#             // caso ocorra algum problema com a lib
#             var googleFcTimeout = setTimeout(function() {
#                 continueReportError(data);
#             }, 5 * 1000);
#
#             // Make sure that the properties exist on the window.
#             window.googlefc = window.googlefc || {};
#             window.googlefc.ccpa = window.googlefc.ccpa || {}
#             window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
#
#             // Garante que o Google FC está pronto e com o status de adblock obtido.
#             googlefc.callbackQueue.push({
#                 'AD_BLOCK_DATA_READY': function () {
#                     clearTimeout(googleFcTimeout);
#                     continueReportError(data);
#                 }
#             });
#         } catch(err) {
#             console.error('[see-jserror] erro ao enviar erro :/', err.message);
#             return undefined;
#         }
#     };
#
#     window.onerror = function(message, file, line, column, error) {
#         try {
#             // utiliza try..catch para evitar loop
#             window.ReportError({
#                 message: error ? error.message : message,
#                 stack: error ? error.stack : message+' at '+file+':'+line+':'+column
#             });
#         } catch(e) { console.error('[see-jserror] catch ', e) }
#     };
# })(window);</script> <script type="text/javascript">window._uolabtestsev=window._uolabtestsev||[]</script><script async="" src="https://abtest.conteudo.uol/c/abc.js"></script> <script async="" src="https://contributor.google.com/scripts/6ad0910ba2d6bbd7/loader.js"></script><script>window.googlefc = window.googlefc || {};
#             window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
#
#             googlefc.controlledMessagingFunction = function(message) {
#                 var hasCookie = function(cookieName) {
#                     var hasCookie = false;
#                     var allCookies = document.cookie.split(';');
#                     for (var i=allCookies.length-1; i>=0; i--) {
#                         if(allCookies[i].indexOf(cookieName) >= 0) {
#                             hasCookie = true;
#                         }
#                     }
#                     return hasCookie;
#                 };
#                 var hasCookieGFC = hasCookie('_ugfc');
#
#                 if (!hasCookieGFC) {
#                     message.proceed(true);
#
#                     // Cookie para controle de sessão
#                     // Modal será exibido somente 1x ao dia
#                     var midnight = new Date();
#                     midnight.setDate(midnight.getDate() + 6);
#                     midnight.setHours(23, 59, 59, 0);
#                     document.cookie = '_ugfc=1; expires='+midnight.toUTCString()+'; domain=uol.com.br; path=/';
#                 } else {
#                     message.proceed(false);
#                 }
#             };</script><script>(function(){'use strict';var g=function(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}},l=this||self,aa=/^[\w+/_-]+[=]{0,2}$/,m=null,p=function(){},q=function(a){var b=typeof a;if("object"==b)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return b;var c=Object.prototype.toString.call(a);if("[object Window]"==c)return"object";if("[object Array]"==c||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";
#             if("[object Function]"==c||"undefined"!=typeof a.call&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";else if("function"==b&&"undefined"==typeof a.call)return"object";return b},r=Date.now||function(){return+new Date},t=function(a,b){function c(){}c.prototype=b.prototype;a.prototype=new c;a.prototype.constructor=a};var ba=function(a,b){Object.defineProperty(l,a,{configurable:!1,get:function(){return b},set:p})};var x=function(a,b){this.b=a===v&&b||"";this.a=w},w={},v={};var ca=function(a,b){a.src=b instanceof x&&b.constructor===x&&b.a===w?b.b:"type_error:TrustedResourceUrl";if(null===m)b:{b=l.document;if((b=b.querySelector&&b.querySelector("script[nonce]"))&&(b=b.nonce||b.getAttribute("nonce"))&&aa.test(b)){m=b;break b}m=""}b=m;b&&a.setAttribute("nonce",b)};var y=function(){return Math.floor(2147483648*Math.random()).toString(36)+Math.abs(Math.floor(2147483648*Math.random())^r()).toString(36)};var z=function(a,b){b=String(b);"application/xhtml+xml"===a.contentType&&(b=b.toLowerCase());return a.createElement(b)},A=function(a){this.a=a||l.document||document};A.prototype.appendChild=function(a,b){a.appendChild(b)};var B=function(a,b,c,d,e,f){try{var k=a.a,h=z(a.a,"SCRIPT");h.async=!0;ca(h,b);k.head.appendChild(h);h.addEventListener("load",function(){e();d&&k.head.removeChild(h)});h.addEventListener("error",function(){0<c?B(a,b,c-1,d,e,f):(d&&k.head.removeChild(h),f())})}catch(n){f()}};var da=l.atob("aHR0cHM6Ly93d3cuZ3N0YXRpYy5jb20vaW1hZ2VzL2ljb25zL21hdGVyaWFsL3N5c3RlbS8xeC93YXJuaW5nX2FtYmVyXzI0ZHAucG5n"),ea=l.atob("WW91IGFyZSBzZWVpbmcgdGhpcyBtZXNzYWdlIGJlY2F1c2UgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlIGlzIGludGVyZmVyaW5nIHdpdGggdGhpcyBwYWdlLg=="),fa=l.atob("RGlzYWJsZSBhbnkgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlLCB0aGVuIHJlbG9hZCB0aGlzIHBhZ2Uu"),ha=function(a,b,c){this.b=a;this.f=new A(this.b);this.a=null;this.c=[];this.g=!1;this.i=b;this.h=c},E=function(a){if(a.b.body&&!a.g){var b=
#             function(){C(a);l.setTimeout(function(){return D(a,3)},50)};B(a.f,a.i,2,!0,function(){l[a.h]||b()},b);a.g=!0}},C=function(a){for(var b=F(1,5),c=0;c<b;c++){var d=G(a);a.b.body.appendChild(d);a.c.push(d)}b=G(a);b.style.bottom="0";b.style.left="0";b.style.position="fixed";b.style.width=F(100,110).toString()+"%";b.style.zIndex=F(2147483544,2147483644).toString();b.style["background-color"]=H(249,259,242,252,219,229);b.style["box-shadow"]="0 0 12px #888";b.style.color=H(0,10,0,10,0,10);b.style.display=
#             "flex";b.style["justify-content"]="center";b.style["font-family"]="Roboto, Arial";c=G(a);c.style.width=F(80,85).toString()+"%";c.style.maxWidth=F(750,775).toString()+"px";c.style.margin="24px";c.style.display="flex";c.style["align-items"]="flex-start";c.style["justify-content"]="center";d=z(a.f.a,"IMG");d.className=y();d.src=da;d.style.height="24px";d.style.width="24px";d.style["padding-right"]="16px";var e=G(a),f=G(a);f.style["font-weight"]="bold";f.textContent=ea;var k=G(a);k.textContent=fa;I(a,
#             e,f);I(a,e,k);I(a,c,d);I(a,c,e);I(a,b,c);a.a=b;a.b.body.appendChild(a.a);b=F(1,5);for(c=0;c<b;c++)d=G(a),a.b.body.appendChild(d),a.c.push(d)},I=function(a,b,c){for(var d=F(1,5),e=0;e<d;e++){var f=G(a);b.appendChild(f)}b.appendChild(c);c=F(1,5);for(d=0;d<c;d++)e=G(a),b.appendChild(e)},F=function(a,b){return Math.floor(a+Math.random()*(b-a))},H=function(a,b,c,d,e,f){return"rgb("+F(Math.max(a,0),Math.min(b,255)).toString()+","+F(Math.max(c,0),Math.min(d,255)).toString()+","+F(Math.max(e,0),Math.min(f,
#             255)).toString()+")"},G=function(a){a=z(a.f.a,"DIV");a.className=y();return a},D=function(a,b){0>=b||null!=a.a&&0!=a.a.offsetHeight&&0!=a.a.offsetWidth||(ia(a),C(a),l.setTimeout(function(){return D(a,b-1)},50))},ia=function(a){var b=a.c;var c="undefined"!=typeof Symbol&&Symbol.iterator&&b[Symbol.iterator];b=c?c.call(b):{next:g(b)};for(c=b.next();!c.done;c=b.next())(c=c.value)&&c.parentNode&&c.parentNode.removeChild(c);a.c=[];(b=a.a)&&b.parentNode&&b.parentNode.removeChild(b);a.a=null};var ka=function(a,b,c,d,e){var f=ja(c),k=function(n){n.appendChild(f);l.setTimeout(function(){f?(0!==f.offsetHeight&&0!==f.offsetWidth?b():a(),f.parentNode&&f.parentNode.removeChild(f)):a()},d)},h=function(n){document.body?k(document.body):0<n?l.setTimeout(function(){h(n-1)},e):b()};h(3)},ja=function(a){var b=document.createElement("div");b.className=a;b.style.width="1px";b.style.height="1px";b.style.position="absolute";b.style.left="-10000px";b.style.top="-10000px";b.style.zIndex="-10000";return b};var J={},K=null;var L=function(){},M="function"==typeof Uint8Array,N=function(a,b){a.b=null;b||(b=[]);a.j=void 0;a.f=-1;a.a=b;a:{if(b=a.a.length){--b;var c=a.a[b];if(!(null===c||"object"!=typeof c||"array"==q(c)||M&&c instanceof Uint8Array)){a.g=b-a.f;a.c=c;break a}}a.g=Number.MAX_VALUE}a.i={}},O=[],P=function(a,b){if(b<a.g){b+=a.f;var c=a.a[b];return c===O?a.a[b]=[]:c}if(a.c)return c=a.c[b],c===O?a.c[b]=[]:c},Q=function(a,b,c){if(b<a.g)a.a[b+a.f]=c;else{var d=a.g+a.f;a.a[d]||(a.c=a.a[d]={});a.c[b]=c}return a},S=
#             function(a,b){var c=R;a.b||(a.b={});if(!a.b[b]){var d=P(a,b);d&&(a.b[b]=new c(d))}return a.b[b]};
#             L.prototype.h=M?function(){var a=Uint8Array.prototype.toJSON;Uint8Array.prototype.toJSON=function(){var b;void 0===b&&(b=0);if(!K){K={};for(var c="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789".split(""),d=["+/=","+/","-_=","-_.","-_"],e=0;5>e;e++){var f=c.concat(d[e].split(""));J[e]=f;for(var k=0;k<f.length;k++){var h=f[k];void 0===K[h]&&(K[h]=k)}}}b=J[b];c=[];for(d=0;d<this.length;d+=3){var n=this[d],u=(e=d+1<this.length)?this[d+1]:0;h=(f=d+2<this.length)?this[d+2]:0;k=n>>2;n=(n&
#             3)<<4|u>>4;u=(u&15)<<2|h>>6;h&=63;f||(h=64,e||(u=64));c.push(b[k],b[n],b[u]||"",b[h]||"")}return c.join("")};try{return JSON.stringify(this.a&&this.a,T)}finally{Uint8Array.prototype.toJSON=a}}:function(){return JSON.stringify(this.a&&this.a,T)};var T=function(a,b){return"number"!=typeof b||!isNaN(b)&&Infinity!==b&&-Infinity!==b?b:String(b)};L.prototype.toString=function(){return this.a.toString()};var R=function(a){N(this,a)};t(R,L);var U=function(a){N(this,a)};t(U,L);var la=function(a,b){this.c=new A(a);var c=S(b,5);c=new x(v,P(c,4)||"");this.b=new ha(a,c,P(b,4));this.a=b},ma=function(a,b,c,d){b=new R(b?JSON.parse(b):null);b=new x(v,P(b,4)||"");B(a.c,b,3,!1,c,function(){ka(function(){E(a.b);d(!1)},function(){d(!0)},P(a.a,2),P(a.a,3),P(a.a,1))})};var na=function(a,b){V(a,"internal_api_load_with_sb",function(c,d,e){ma(b,c,d,e)});V(a,"internal_api_sb",function(){E(b.b)})},V=function(a,b,c){a=l.btoa(a+b);ba(a,c)},W=function(a,b,c){for(var d=[],e=2;e<arguments.length;++e)d[e-2]=arguments[e];e=l.btoa(a+b);e=l[e];if("function"==q(e))e.apply(null,d);else throw Error("API not exported.");};var X=function(a){N(this,a)};t(X,L);var Y=function(a){var b=this.h=l.document;var c=new U;var d=P(a,3);c=Q(c,1,d);d=P(a,12);c=Q(c,2,d);d=P(a,5);c=Q(c,3,d);d=P(a,10);c=Q(c,4,d);d=S(a,11);c.b||(c.b={});var e=d?d.a:d;c.b[5]=d;c=Q(c,5,e);this.g=new la(b,c);this.a=P(a,1);this.f=S(a,2);this.c=!1;this.b=a};Y.prototype.start=function(){try{oa(),na(this.a,this.g),l.googlefc=l.googlefc||{},"callbackQueue"in l.googlefc||(l.googlefc.callbackQueue=[]),pa(this)}catch(a){W(this.a,"internal_api_sb")}};
#             var oa=function(){var a=function(){if(!l.frames.googlefcPresent)if(document.body){var b=document.createElement("iframe");b.style.display="none";b.style.width="0px";b.style.height="0px";b.style.border="none";b.style.zIndex="-1000";b.style.left="-1000px";b.style.top="-1000px";b.name="googlefcPresent";document.body.appendChild(b)}else l.setTimeout(a,5)};a()},pa=function(a){var b=r();W(a.a,"internal_api_load_with_sb",a.f.h(),function(){var c;var d=a.a,e=l[l.btoa(d+"cached_js")];if(e){e=l.atob(e);e=parseInt(e,
#             10);d=l.btoa(d+"cached_js").split(".");var f=l;d[0]in f||"undefined"==typeof f.execScript||f.execScript("var "+d[0]);for(;d.length&&(c=d.shift());)d.length?f[c]&&f[c]!==Object.prototype[c]?f=f[c]:f=f[c]={}:f[c]=null;c=Math.abs(b-e);c=1728E5>c?0:c}else c=-1;0!=c&&(W(a.a,"internal_api_sb"),Z(a,P(a.b,9)))},function(c){c?Z(a,P(a.b,7)):Z(a,P(a.b,8))})},Z=function(a,b){a.c||(a.c=!0,a=new l.XMLHttpRequest,a.open("GET",b,!0),a.send())};(function(a,b){l[a]=function(c){for(var d=[],e=0;e<arguments.length;++e)d[e-0]=arguments[e];l[a]=p;b.apply(null,d)}})("__475an521in8a__",function(a){"function"==typeof l.atob&&(a=l.atob(a),a=new X(a?JSON.parse(a):null),(new Y(a)).start())});}).call(this);
#             window.__475an521in8a__("...");</script> </head><body data-is-bot="false"> <span central="esporte" channel-name="www.uol.com.br" class="uol-notifications-widget" data-container=".webalert_parent_container" style="display:none;" themes="geral,futebol"></span><script async="" crossorigin="anonymous" src="https://c.jsuol.com.br/assets/?loadComponent=media&amp;contentType=js&amp;tpl=assets/dist/service-worker/webalert-notification&amp;cache=202201201930"></script><script type="text/javascript">"Promise"in window==1&&"serviceWorker"in navigator==1&&navigator.serviceWorker.getRegistrations().then(function(r){for(var e in r){var t=r[e];if(t&&t.scope=="https://"+location.hostname+"/"){var o=t.active;if(!0===/\?loadComponent=service-worker\&vn$/.test(o.scriptURL))try{window.ReportError({message:"service-worker-start: removendo SW deprecated",stack:"SW url: "+o.scriptURL}),t.unregister()}catch(r){}}}})</script> <span class="football-ws" data-settings='{"general":true,"ticker":true,"standingsAndMatch":true}'></span> <script type="application/ld+json">[{"@type":"NewsArticle","@context":"http://schema.org","headline":"Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu","description":"Acostumado a ter em seu gramado grandes jogadores, dribles desconcertantes e gols inesquecíveis, o estádio do Pacaembu teve uma manhã diferente no dia 20 de agosto de 1995. Palmeiras e São Paulo - que se enfrentam neste sábado (22), pela semifinal da Copa","author":{"name":"Thiago Braga","@type":"Person","url":"https://uol.com.br/"},"publisher":{"@type":"Organization","name":"UOL","url":"https://www.uol.com.br","logo":{"@type":"ImageObject","url":"https://conteudo.imguol.com.br/uolamp/UOL_logo_156x60.png","width":156,"height":60}},"url":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm","mainEntityOfPage":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm","image":["https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_1x1.jpg","https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_3x4.jpg","https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_4x3.jpg"],"datePublished":"2022-01-22T04:00:00-03:00","dateModified":"2022-01-22T04:00:32-03:00"}]</script> <div class="bannersticky-base"></div><div class="bannersticky-wrapper"><div class="bannersticky-top-container"><div class="bannersticky-top ignore-header"> <div class="ads-wrapper"> <div class="chapeu"><span>PUBLICIDADE</span></div> <div class="ads" data-ads='{"xs":"responsive-top-horizontal","sm":"responsive-top-horizontal","md":"responsive-top-horizontal","lg":"responsive-top-horizontal"}' data-disablescroll="false"></div></div> </div></div></div> <header class="header webalert_parent_container gradient fixed" data-chn-id="22" data-has-scroll-metrics="" data-refresh-sess="true" data-scroll-metrics=""> <div class="container"><div class="over"><div class="header-menu-lateral"> <ul class="products clearfix hidden-xs hidden-sm"> <li><a data-audience-click='{"component":"barra-uol","reference":"item-batepapo","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://batepapo.uol.com.br/">BATE-PAPO</a></li> <li><a data-audience-click='{"component":"barra-uol","reference":"item-uol-meunegocio","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://meunegocio.uol.com.br/?utm_source=uol.com.br&amp;utm_medium=barrauol&amp;utm_campaign=linkfixo-barrauol-umn&amp;utm_term=barrauol-umn&amp ...
#         var js, id = 'instagram-script', ref = d.getElementsByTagName('script')[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement('script'); js.id = id; js.async = true;
#         js.src = "https://www.instagram.com/embed.js";
#         ref.parentNode.insertBefore(js, ref);
#     }(document));
#
#     (function(d){
#         var js, id = 'twitter-script', ref = d.getElementsByTagName('script')[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement('script'); js.id = id; js.async = true;
#         js.src = "https://platform.twitter.com/widgets.js";
#         ref.parentNode.insertBefore(js, ref);
#     }(document));
#
#     (function(d){
#         var js, id = 'facebook-script', ref = d.getElementsByTagName('script')[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement('script'); js.id = id; js.async = true;
#         js.src = "https://connect.facebook.net/en_US/sdk.js#xfbml=1&version=v3.2";
#         ref.parentNode.insertBefore(js, ref);
#     }(document));</script> </div><p>Pela regra da prorrogação na morte súbita adotada naquela competição, o time que marcasse o gol seria campeão. Pouco mais de 21 anos após aquela final, o gol de Rogério, que decretou o título do Verdão, é um fato menor daquela decisão. O tento, aos 5 min da prorrogação, fez os torcedores alviverdes explodirem em comemoração. A alegria pelo título inédito incentivou os palestrinos a invadirem o gramado do Pacaembu. Alguns torcedores começaram a provocar os são-paulinos que ainda não haviam deixado o estádio. Foi o estopim para que o campo de jogo virasse um campo de guerra.</p><p>Os tricolores derrubaram o alambrado do setor em que estavam, invadiram o tobogã, então em obras e, armados de paus, pedras e tudo mais que pudesse servir de arma, revidaram. A partir daí o gramado do Pacaembu virou cenário de guerra medieval.</p><p><figure class="photo photo-embed no-gutter col-sm-24 crop-750x421 limit-crop figure" data-format="horizontal" style="max-width:750px"> <div class="image bg"><div class="placeholder" style="max-width:750px"> <img alt="Briga entre as torcidas do Palmeiras e do São Paulo durante a final da Taça São Paulo de Juniores de 1995 - Roberto Delduque/Folhapress - Roberto Delduque/Folhapress" class="pinit-img" data-crop='{"xs":"450x253","sm":"750x421","md":"600x337","lg":"750x421"}' data-src="https://conteudo.imguol.com.br/c/esporte/71/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111848841_v2_750x421.jpg" height="421" src="https://conteudo.imguol.com.br/c/geral/3d/2021/05/25/placeholder-image-1621949831997_v2_750x421.jpg" width="750"/> <i class="placeholder-mask" style="padding-bottom: 56.13333333333333%"></i><div class="slot-a"></div></div></div> <figcaption class="container bottom-title"><div>Torcedor é ferido durante briga entre torcidas de Palmeiras e São Paulo</div> <span>Imagem: Roberto Delduque/Folhapress</span></figcaption> </figure></p><p>Os palmeirenses recuaram. Em maior número, contra-atacaram. O efetivo policial era reduzido por ser um jogo de juniores. Assim, o entulho encontrado no estádio virou arsenal na mão dos torcedores. Quem caía, era espancado impiedosamente. Uma das cenas mais impactantes é quando um torcedor recebe pauladas na cabeça e sai cambaleando até desabar no alambrado.</p><p>Agredido inúmeras vezes, o são-paulino Márcio Gasparin da Silva, 16, sofreu múltiplos traumatismos cranianos. Morreu oito dias depois da briga no Pacaembu.</p><p>O palmeirense Adalberto Benedito dos Santos foi responsabilizado pelo assassinato de Márcio. Em 1998, três anos após o confronto, Adalberto foi julgado e condenado a 12 anos de prisão pela morte de Márcio. Cumpriu aproximadamente quatro em reclusão, e conseguiu progressão para o regime semi-aberto.</p><p>A família de Márcio entrou na Justiça contra a Prefeitura de São Paulo, mas o judiciário não concedeu a indenização pretendida e também não considerou o município culpado pela morte do adolescente.</p><p>O caso também foi um marco para a regulamentação das torcidas no Estado. O Ministério Público de São Paulo decretou a extinção da Mancha Verde e da Independente, que ressurgiram após mudanças jurídicas e de nome. Na prática, culminou com a decisão de restringir apenas aos torcedores da equipe mandante a presença em clássicos em São Paulo. "Naquela época, o Ministério Público ainda não havia iniciado o controle das organizadas, mas o preço da tranquilidade é a eterna vigilância. O jogo requer atenção", falou ao UOL Fernando Capez, então promotor público que pediu a extinção das organizadas de São Paulo e Palmeiras.</p> </div> <div class="slot-c"> <div class="feed-gallery-render" data-json='{"url":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm","show":false,"tags":{"principal":[{"name":"Futebol","id":15308}],"secundarias":[{"name":"Esporte","id":12810} ...
#         var js, id = 'instagram-script', ref = d.getElementsByTagName('script')[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement('script'); js.id = id; js.async = true;
#         js.src = "https://www.instagram.com/embed.js";
#         ref.parentNode.insertBefore(js, ref);
#     }(document));
#
#     (function(d){
#         var js, id = 'twitter-script', ref = d.getElementsByTagName('script')[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement('script'); js.id = id; js.async = true;
#         js.src = "https://platform.twitter.com/widgets.js";
#         ref.parentNode.insertBefore(js, ref);
#     }(document));
#
#     (function(d){
#         var js, id = 'facebook-script', ref = d.getElementsByTagName('script')[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement('script'); js.id = id; js.async = true;
#         js.src = "https://connect.facebook.net/en_US/sdk.js#xfbml=1&version=v3.2";
#         ref.parentNode.insertBefore(js, ref);
#     }(document));</script> <div class="lazy-component not-loaded" config-name="esporte/esporte.futebol.ultimas-noticias" cp-area='{"xs-sm":"30px","md-lg":"40px"}' cp-data='{"titulo":"Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu","reportError":true,"tags":{"tag1":[],"tag2":[],"tag3":[],"tag4":[],"tag6":[],"tag-local":[],"tag-colecao":[{"name":"Futebol","id":15308}],"tag-outras":[{"name":"Esporte","id":12810},{"name":"BOL Esporte","id":79585},{"name":"Palmeiras","id":16026},{"name":"São Paulo","id":16130}],"colecao-primaria":"esporte"}}' cp-name="report-error-button" cp-shell="false" detected="false" style="height:40px"></div> <div class="related-content-front" data-blockread="" data-component="related-content-uol-item" data-contentid="6aed318a7bde45f4161dfba864fcaac20220121" data-titulo="Veja também"> <div class="chartbeat-related-content" ia-blocked=""><div class="related-content" data-audience-print='{"abTest4":"default","abTest6":"chartbeat","tags":"15308,12810,79585,16026,16130","component":"related-content-uol-item"}'> <h4 class="h-components custom-title" ia-related-title="">As mais lidas agora</h4> <div class="row"> <div class="thumbnail-standard col-xs-8 col-sm-6 col-md-8 alignmentSide"><div class="row thumbnail-standard-wrapper"> <a data-audience-click='{"reference":"abrir-chamada","position":"chamada-1","component":"related-content-uol-item","mediaName":false,"source":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm","abTest4":"default","abTest6":"chartbeat","tags":"15308,12810,79585,16026,16130"}' href="https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/lentidao-e-salario-europeu-de-diego-costa-explicam-o-nao-do-corinthians.htm"> <figure class="thumb-image col-xs-4 col-sm-24"><div class="thumb-layer"> <img alt="" data-crop='{"xs":"150x112","sm":"300x225"}' data-src="https://conteudo.imguol.com.br/c/esporte/6f/2022/01/19/centroavante-diego-costa-ex-atletico-mg-avalia-propostas-para-saber-onde-vai-jogar-em-2022-1642614127733_v2_900x506.jpg" height="225" src="https://conteudo.imguol.com.br/c/geral/3d/2021/05/25/placeholder-image-1621949831997_v2_300x225.jpg" width="300"/> </div></figure> <div class="thumb-caption col-xs-6 col-sm-24"> <h3 class="thumb-title"> Lentidão e salário 'europeu' de Diego Costa explicam o não do Corinthians  </h3> </div> </a> </div></div> <div class="thumbnail-standard col-xs-8 col-sm-6 col-md-8 alignmentSide"><div class="row thumbnail-standard-wrapper"> <a data-audience-click='{"reference":"abrir-chamada","position":"chamada-2","component":"related-content-uol-item","mediaName":false,"source":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm","abTest4":"default","abTest6":"chartbeat","tags":"15308,12810,79585,16026,16130"}' href="https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/por-que-o-flamengo-puxa-freio-de-mao-e-nao-repete-agressividade-no-mercado.htm"> <figure class="thumb-image col-xs-4 col-sm-24"><div class="thumb-layer"> <img alt="" data-crop='{"xs":"150x112","sm":"300x225"}' data-src="https://conteudo.imguol.com.br/c/esporte/a5/2022/01/21/gabigol-e-arrascaeta-sao-apresentados-para-a-torcida-do-flamengo-no-maracana-1642795907933_v2_900x506.jpg" height="225" src="https://conteudo.imguol.com.br/c/geral/3d/2021/05/25/placeholder-image-1621949831997_v2_300x225.jpg" width="300"/> </div></figure> <div class="thumb-caption col-xs-6 col-sm-24"> <h3 class="thumb-title"> Por que o Flamengo puxa freio de mão e não repete agressividade no mercado  </h3> </div> </a> </div></div> <div class="thumbnail-standard col-xs-8 col-sm-6 col-md-8 hidden-md alignmentSide"><div class="row thumbnail-standard-wrapper"> <a data-audience-click='{"reference":"abrir-chamada","position":"chamada-3","component":"related-content-uol-item","mediaName":false,"source":" ...
#                 "path" : "commons.uol.com.br/monaco/export/api.uol.com.br/collection/esporte/futebol/ultimas//data.json",
#                 "collectionIndex" : true,
#                 "channel" : "futebol",
#                 "central" : "esporte",
#                 "titulo" : "Futebol",
#                 "search" : {"repository":"mix2","tags":"15308"}
#             };</script> <div class="lazy-component not-loaded" config-name="esporte/esporte.futebol.ultimas-noticias" cp-area='{"xs-sm":"230px","md-lg":"128px"}' cp-data='{"audience":{"pv":{"mediaName":"Notícia","mediaType":"article","mediaId":"6aed318a7bde45f4161dfba864fcaac20220121","mediaTitle":"Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu","collection":"Futebol","tags":"15308,12810,79585,16026,16130","channel":"futebol","central":"esporte","author":"Thiago Braga","publicationDate":"20220122040000"},"click":{"mediaName":"Notícia","source":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm"}},"isNoSpace":false}' cp-name="footer" cp-shell="false" detected="false" style="height:128px"></div> <script id="js-audience">var Audience = {"channel":"futebol","central":"esporte","mediaName":"Notícia","mediaType":"article","mediaId":"6aed318a7bde45f4161dfba864fcaac20220121","mediaTitle":"Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu","collection":"Futebol","tags":"15308,12810,79585,16026,16130","author":"Thiago Braga","publicationDate":"22/01/2022 04:00:00","abTest3":"album:nao|enquete:nao|foto:meio|foto:topo|lista:nao|video:nao|video_autoplay:sem","charactersQuantity":2935,"ga":{"rollupChannel":"Estacoes","id":"UA-97689914-185","filename":"uolestacoes"}};</script> <script>var Config = {"platform":"web","allComponents":[],"portal":{"slug":"uol","title":"UOL"},"central":{"title":"Esporte","slug":"esporte","link":"https://www.uol.com.br/esporte/"},"channel":{"title":"Esporte","slug":"esporte","link":"https://www.uol.com.br/esporte/"},"color":"esporte","configPath":"esporte/esporte.futebol.ultimas-noticias","servicename":"/esporte/service/","loadedCssAssets":["reset","alert","forms","photo","grid","headings","icons","svg-icons","label","table","link","scroll","masks","read-more","misc","paragraph","hr","line","time","modal","babel-login","webfonts","piano-modal","ads","thumbnail-standard","thumbnails","author","results-index","badge-content-past","collection-index","header-menu","logo","photo-embed","related-content","share","widget-profile","article-wrapper","back-to-top","bannersticky","chartbeat-related-content","collection","components-loader","feed-gallery-render","footer","header","title","tooltip","auxiliary-content-list","comments","match-center-ticker","modal-content-ticker","report-error-button","tabs","teams-nav","title-sponsor"],"cache":202201201930};</script><script>var System = {"corepath":"commons.uol.com.br/static/v3","monaco":"commons.uol.com.br/monaco/export","version":"static/v3","media":{"js":"//c.jsuol.com.br/assets/?loadComponent=media&contentType=js","css":"//c.jsuol.com.br/assets/?loadComponent=assets"},"map":{"css":{"a2hs-install":"a2hs-install.css","accordion-box":"accordion-box.css","ads":"ads-default.css","agenda-brazil-wrapper":"agenda-brazil-wrapper.css","agenda-brazil":"agenda-brazil.css","album-content":"album-content.css","album-content/version/vertical":"album-content.vertical.css","album-embed":"base-structure-album.css","album-embed/version/vertical":"base-structure-album-vertical.css","album-header":"album-header.css","album-header/version/universa":"logo-universa.css","album-header/version/vertical":"album-header.vertical.css","alert":"default.css","amp-consent":"amp-consent.css","amp-stories-page-editorial":"logo-mov.css","amp-stories-page":"logo-mov.css","amp-stories-reporterror":"amp-stories-reporterror.css","amp-stories-story-editorial":"amp-stories-story-editorial.css","amp-stories-story-editorial/version/vertical":"amp-stories-story-editorial.vertical.css","amp-stories-story":"amp-stories-story.css","amp-stories-story/version/vertical":"amp-stories-story.vertical.css","animated-gif":"animated-gif.css","article-wording-correction":"article-wording-correction.css","article-wording-home":"article-wording-home.css","article-wording":"article-wor ...
#     var script = document.createElement('script');
#     script.type = 'text/javascript';
#     script.async = true;
#     script.crossOrigin = 'anonymous';
#     script.src = src;
#
#     document.head.appendChild(script);
#
#     return new Promise(function(resolve) {
#         script.onload = script.onreadystatechange = function() {
#             if (!script.readyState || script.readyState == 'loaded' || script.readyState == 'complete') {
#                 document.head.removeChild(script);
#                 script.onload = script.onreadystatechange = null;
#                 resolve();
#             }
#         }
#     });
# };
#
# ;(function (document) {
#     var generics = [
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/duckslake-sdk.min&cache=202201201930',
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/uol-talker/uol-talker&cache=202201201930',
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/frameworks.min&cache=202201201930',
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/libs.min&cache=202201201930',
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/angular.min&cache=202201201930',
#     ];
#
#     // carrega todos os scripts não dependentes um do outro
#     var promises = generics.map(_asyncLoadScript);
#
#     return Promise.all(promises)
#         .then(function() {
#             // carrega a expose e os scripts necessários para webpack
#             return Promise.all([
#                 '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/exposejs/expose.min&cache=202201201930',  '//c.jsuol.com.br/assets/?loadComponent=assets&contentType=js&tpl=vendors.js,runtime.js,main.js&hash=085429b9ad48fff7a61ef6a79e422dc0aeb33c349bfdfd8586603bbd78e5&origin=vendors-js',  ].map(_asyncLoadScript));
#         })
#         .then(function() {
#             // Executa o UOLoader e carrega os scripts que dependen da expose
#             // Como são ações que não dependem de si, rodam em paralelo
#             return Promise.all([
#                 UOLoader([{"id":"svg-icons","path":"structure/bootstrap/svg-icons"},{"id":"results-index","path":"basics/results-index"},{"id":"header-menu","path":"basics/header-menu"},{"id":"widget-profile","path":"basics/widget-profile"},{"id":"article-wrapper","path":"basics/article-wrapper"},{"id":"back-to-top","path":"basics/back-to-top"},{"id":"feed-gallery-render","path":"projects/feed/feed-gallery/feed-gallery-render"},{"id":"header","path":"basics/header"},{"id":"header-slot","path":"basics/header-slot"},{"id":"title","path":"basics/title"},{"id":"feed-redirect","path":"projects/feed/feed-redirect"},{"id":"modal-content-ticker","path":"basics/modal-content-ticker"},{"id":"related-content-front","path":"basics/related-content-front"},{"id":"report-error-button","path":"basics/report-error-button"},{"id":"title-sponsor","path":"basics/title-sponsor"},{"id":"user","path":"basics/user"},{"id":"scroll","path":"structure/bootstrap/scroll"},{"id":"piano/version/esporte","path":"basics/piano/version/esporte"}]),
#                 ...[
#                     '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=alert,forms,photo,read-more,modal,babel,babel-login,contauol-login,babel-service,suggest,ads,share,collection,tooltip,comments,football-ws,match-center-ticker,tabs,teams-nav&cache=202201201930',
#                 ].map(_asyncLoadScript),
#             ]);
#         })
#         .then(function() {
#             // roda o primeiro render
#             render();
#
#             // dispara evento que indica que o primeiro UOLoader foi completo
#             window.gevent.emit('firstLoaderDone');
#         });
# })(document);</script> <script language="JavaScript1.1">(function() {
#             var tag = document.createElement("script");
#             var attrsTail = [{"key":"tt_age","value":"tt_age"},{"key":"tt_cluster","value":"tt_cluster"},{"key":"tt_gender","value":"tt_gender"},{"key":"tt_microsegments","value":"tt_microsegments"},{"key":"tt_socialclass","value":"tt_socialclass"},{"key":"tt_subjects","value":"tt_subjects"},{"key":"tt_teams","value":"tt_subjects"}];
#             var dType = window.Config && window.Config.channel && window.Config.channel.slug || '';
#             var tailNa = attrsTail.reduce((item, { key, value }) => {
#                 item[key] = 'na';
#                 return item;
#             }, {});
#
#             var userTailDataLayer = Object.assign(tailNa, (window.UOLPD && UOLPD.dataLayer || {}), {});
#
#             var dataLayer = Object.keys(userTailDataLayer).reduce((data, item ) => {
#                 if(attrsTail.some(i => i.key == item)){
#                     data[item.replace('_','-')] = userTailDataLayer[item];
#                 }
#                 return data
#             }, {});
#
#             var plaicementQs = Object.keys(dataLayer).map(function(item) {
#                return `;${item}=${dataLayer[item]}`
#             }); tag.language="JavaScript1.1"; tag.type="text/javascript";
#             tag.src = "https://t.dynad.net/script/?dc=5550021010;ord="+Date.now()+plaicementQs.join('')+";d-type="+dType+";click="
#
#             document.body.appendChild( tag );
#         })();</script> <script>var _sf_async_config = _sf_async_config || {};
#         _sf_async_config.sections = 'Total UOL Conteúdo, Total - Estacoes, UOL - esporte';
#         _sf_async_config.authors = 'UOL';
#         (function() {
#             function loadChartbeat() {
#                 window._sf_endpt = (new Date()).getTime();
#                 var e = document.createElement('script');
#                 e.setAttribute('language', 'javascript');
#                 e.setAttribute('type', 'text/javascript');
#
#                 e.setAttribute('src', '//static.chartbeat.com/js/chartbeat_video.js');
#                 document.body.appendChild(e);
#             }
#
#             var _cbv = window._cbv || (window._cbv = []);
#             _cbv.push(['autoDetectYouTubeIframes']);
#
#             _asyncLoadScript('//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/chartbeat/chartbeat.min&cache=202201201930')
#                 .then(loadChartbeat);
#         })();</script> <script>if('serviceWorker' in navigator) {
#     window.addEventListener('load', function() {  navigator.serviceWorker.register('/esporte?loadComponent=pwa-sw&configPath=esporte/esporte.futebol.ultimas-noticias', {
#             scope: '/esporte'
#         }).then(function() {
#             console.log('[PGV3-SW] Successfully registered');
#         }).catch(function(registrationError) {
#             console.error('[PGV3-SW] Registration failed: ', registrationError);
#         });
#     });
# }</script> </body> </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu - 22/01/2022 - UOL Esporte
#   </title>
#   <link crossorigin="anonymous" href="https://stc.uol.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://c.jsuol.com.br" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://conteudo.jsuol.com.br" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://conteudo.imguol.com.br" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://me.jsuol.com.br" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://stc.uol.com" rel="dns-prefetch"/>
#   <link href="https://c.jsuol.com.br" rel="dns-prefetch"/>
#   <link href="https://conteudo.jsuol.com.br" rel="dns-prefetch"/>
#   <link href="https://conteudo.imguol.com.br" rel="dns-prefetch"/>
#   <link href="https://me.jsuol.com.br" rel="dns-prefetch"/>
#   <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="//securepubads.g.doubleclick.net.com" rel="dns-prefetch"/>
#   <link href="//tt-10162-1.seg.t.tailtarget.com" rel="dns-prefetch"/>
#   <link href="https://tm.uol.com.br" rel="dns-prefetch"/>
#   <link href="https://tm.jsuol.com.br" rel="dns-prefetch"/>
#   <link as="font" crossorigin="anonymous" href="https://stc.uol.com/c/webfont/projeto-grafico/v2/icones-setas/uol-icones-setas.woff?v6" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="anonymous" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-lighter.woff2?v5" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-light.woff2?v5" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://stc.uol.com/c/webfont/projeto-grafico/uol-font/uol-text-regular.woff2?v5" rel="preload" type="font/woff2"/>
#   <link as="image" href="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_900x506.jpg.webp" media="(min-width: 768px)" rel="preload"/>
#   <link as="image" href="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_900x506.jpg" media="(min-width: 768px)" rel="preload"/>
#   <link as="script" crossorigin="anonymous" href="https://me.jsuol.com.br/aud/uolestacoes.js" rel="preload"/>
#   <link as="script" crossorigin="anonymous" href="//c.jsuol.com.br/assets/?loadComponent=media&amp;contentType=js&amp;tpl=assets/dist/libs/jquery.min&amp;cache=202201201930" rel="preload"/>
#   <link as="script" crossorigin="anonymous" href="//c.jsuol.com.br/assets/?loadComponent=media&amp;contentType=js&amp;tpl=assets/dist/audience/audience.min&amp;cache=202201201930" rel="preload"/>
#   <meta content="115401215190141" property="fb:pages"/>
#   <meta content="21539158238" property="fb:pages"/>
#   <meta content="146391125938238" property="fb:pages"/>
#   <meta content="702958396425837" property="fb:pages"/>
#   <meta content="221456874659747" property="fb:pages"/>
#   <meta content="124493634232128" property="fb:pages"/>
#   <meta content="123014924007" property="fb:pages"/>
#   <meta content="124400289445" property="fb:pages"/>
#   <meta content="143813098922" property="fb:pages"/>
#   <meta content="112341259449730" property="fb:pages"/>
#   <meta content="357889721305340" property="fb:pages"/>
#   <meta content="120098554660" property="fb:pages"/>
#   <meta content="always" name="referrer"/>
#   <meta content="Acostumado a ter em seu gramado grandes jogadores, dribles desconcertantes e gols inesquecíveis, o estádio do Pacaembu teve uma manhã diferente no dia 20 de agosto de 1995. Palmeiras e São Paulo - que se enfrentam neste sábado (22), pela semifinal da C" name="description"/>
#   <meta content="index,follow,max-image-preview:large" name="robots"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=1.0,maximum-scale=10.0" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="uPoEEmwsmGUXmhtQSbPK1DFcI9TNUZB19rqvpshC4vw" name="google-site-verification"/>
#   <meta content="3773adcdaf781c767a0dca14277f9101" name="p:domain_verify"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <meta content="190329594333794" property="fb:app_id"/>
#   <meta content="Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu" property="og:title"/>
#   <meta content="Acostumado a ter em seu gramado grandes jogadores, dribles desconcertantes e gols inesquecíveis, o estádio do Pacaembu teve uma manhã diferente no dia 20 de agosto de 1995. Palmeiras e São Paulo - que se enfrentam neste sábado (22), pela semifinal da C" property="og:description"/>
#   <meta content="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_615x300.jpg" property="og:image"/>
#   <meta content="615" property="og:image:width"/>
#   <meta content="300" property="og:image:height"/>
#   <meta content="https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="pt_BR" property="og:locale"/>
#   <meta content="https://www.facebook.com/UOL" property="article:publisher"/>
#   <meta content="false" property="article:opinion"/>
#   <meta content="Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu" name="twitter:title"/>
#   <meta content="Acostumado a ter em seu gramado grandes jogadores, dribles desconcertantes e gols inesquec..." name="twitter:description"/>
#   <meta content="https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_615x300.jpg" name="twitter:image"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="UOLEsporte @UOL" name="twitter:site"/>
#   <meta content="https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm?loadComponent=rule-generator&amp;data=%7B%22mediaId%22%3A%226aed318a7bde45f4161dfba864fcaac20220121%22%2C%22collection%22%3A%22Futebol%22%2C%22tags%22%3A%2215308%2C12810%2C79585%2C16026%2C16130%22%2C%22central%22%3A%22esporte%22%2C%22channel%22%3A%22futebol%22%2C%22publicationDate%22%3A%2220220122040000%22%2C%22gaAuthor%22%3A%22Thiago%20Braga%22%2C%22heroImage%22%3Atrue%2C%22author%22%3A%7B%22name%22%3A%22Thiago%20Braga%22%2C%22image%22%3Anull%7D%7D" property="ia:rules_url"/>
#   <meta content="Football (Association Rules, Soccer)" property="article:tag"/>
#   <meta content="Sports" property="article:tag"/>
#   <link href="//conteudo.imguol.com.br/c/_layout/favicon/uol2021.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm" rel="canonical"/>
#   <link href="https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.amp.htm" rel="amphtml"/>
#   <style type="text/css">
#    /* !color-cp:back-to-top */.back-to-top{bottom:8px;position:fixed;right:8px;z-index:121}.back-to-top .box{display:block;background:rgba(26,26,26,.8);border:none;color:#fff;font-size:16px;height:40px;line-height:14px;width:40px}.back-to-top .box i{font-size:16px;margin:0 12px}.back-to-top .box span{display:block;font-size:11px;font-weight:400;text-align:center}@media (max-width:767px){.back-to-top .box i{display:inline-block}}.back-to-top .box{padding:6px 0 0}.back-to-top[data-show=false]{visibility:hidden}@media (min-width:992px){.back-to-top .box{background:#1a1a1a;height:50px;line-height:17px;padding-top:6px;transition:.5s;width:50px}.back-to-top .box i{font-size:20px;margin:0 15px}.back-to-top .box span{font-size:14px;line-height:19px}.back-to-top .box:hover{background-color:rgba(26,26,26,.8);color:#fff}}/* !end-color-cp:back-to-top *//* !color-cp:bannersticky */.bannersticky-base{height:75px}@media (min-width:768px){.bannersticky-base{height:126px}}@media (min-width:992px){.bannersticky-base{height:287px}}.bannersticky-wrapper{position:absolute;top:0;width:100%;height:135px}@media (min-width:768px){.bannersticky-wrapper{height:170px}}@media (min-width:992px){.bannersticky-wrapper{height:386px}}.bannersticky-wrapper.fixed{position:absolute;top:0;height:75px;z-index:999999;transition:all .5s ease-in}.bannersticky-top-container{background-image:url(https://conteudo.imguol.com.br/c/_layout/v2/ads/bg-listras.png);position:sticky;position:-webkit-sticky;position:-moz-sticky;position:-ms-sticky;position:-o-sticky;top:0;z-index:6000007}@media screen and (-webkit-min-device-pixel-ratio:0) and (min-resolution:0.001dpcm){.bannersticky-top-container{background-image:url(https://conteudo.imguol.com.br/c/_layout/v2/ads/bg-listras.webp)}}.bannersticky-top-container .bannersticky-top{min-height:75px;position:relative}.bannersticky-top-container .bannersticky-top .ads{margin:0 auto;padding:10px 0}.bannersticky-top-container .bannersticky-top .chapeu{display:none}.bannersticky-top-container.is-absolute{position:absolute;width:100%}@media (min-width:768px){.bannersticky-top-container{min-height:126px}.bannersticky-top-container .bannersticky-top{min-height:126px}.bannersticky-top-container .bannersticky-top .chapeu{display:block}.bannersticky-top-container .bannersticky-top .ads{padding:0 0 10px 0}}@media (min-width:992px){.bannersticky-top-container .bannersticky-top{height:287px;width:100%}.bannersticky-top-container .bannersticky-top .chapeu{padding-top:2px}.bannersticky-top-container .bannersticky-top.ignore-header.ads-stick{position:absolute!important;top:135px!important}.bannersticky-top-container .bannersticky-top .ads-wrapper{position:relative;transform:translate(0,-50%);top:50%}.bannersticky-top-container .bannersticky-top .ads{margin:0!important}}@media (min-width:768px){.bannersticky-wrapper.fixed{height:126px}}@media (min-width:992px){.bannersticky-wrapper.fixed{height:289px}}/* !end-color-cp:bannersticky *//* !color-cp:disclaimer-exclusive-content */.info-exclusive-content{display:flex;align-items:center;justify-content:space-between;background-color:#ffe3c6;height:40px;margin-bottom:30px;width:100%}.info-exclusive-content span{width:100%;font-family:UOLtext;font-size:14px;font-weight:700;text-transform:uppercase;margin-left:10px;color:#ff8000;line-height:normal;letter-spacing:normal}@media (min-width:1230px){.info-exclusive-content span{font-size:16px}}/* !end-color-cp:disclaimer-exclusive-content *//* !color-cp:header */.header .products li:last-child{right:25px}.header.sticky{position:-webkit-sticky;position:sticky;z-index:99999;top:-115px}.header.sticky.down{top:0;transition:top .2s linear}.header.sticky.up{top:-115px;transition:top .2s linear}.header.fixed{position:relative;width:100%;z-index:99999}.header.fixed .container,.header.fixed .header-logo,.header.fixed .header-menu-lateral,.header.fixed .station,.header.fixed .under{transition:all .4s ease-in}.header.fixed .header-logo{z-index:999}.header.fixed .over{position: ...
#   </style>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=default.css&amp;origin=alert&amp;hash=16b9d8624305c149e592b22794f3855e" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=default.css&amp;origin=alert&amp;hash=16b9d8624305c149e592b22794f3855e" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=comment-default.css&amp;origin=babel-login&amp;hash=f535ec642bdf7d7ce26ba819512618f1" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=comment-default.css&amp;origin=babel-login&amp;hash=f535ec642bdf7d7ce26ba819512618f1" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=piano-modal.css&amp;origin=piano-modal&amp;hash=783850ebeb6e247f1265b89672c09f81" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=piano-modal.css&amp;origin=piano-modal&amp;hash=783850ebeb6e247f1265b89672c09f81" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=indice-default.css&amp;origin=results-index&amp;hash=4221ee04aeb21f954c8307fa754bc994" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=indice-default.css&amp;origin=results-index&amp;hash=4221ee04aeb21f954c8307fa754bc994" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=badge-content-past.css&amp;origin=badge-content-past&amp;hash=70b482b28d53080a08b170b0cfc116cf" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=badge-content-past.css&amp;origin=badge-content-past&amp;hash=70b482b28d53080a08b170b0cfc116cf" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=photo-embed.css&amp;origin=photo-embed&amp;hash=7d5b2efbbf58d5474575624e4c0d210f" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=photo-embed.css&amp;origin=photo-embed&amp;hash=7d5b2efbbf58d5474575624e4c0d210f" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=components-loader.css&amp;origin=components-loader&amp;hash=c43419f735dcbf42ab96b7b5625fdb06" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=components-loader.css&amp;origin=components-loader&amp;hash=c43419f735dcbf42ab96b7b5625fdb06" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=footer.css&amp;origin=footer&amp;hash=46136b8d20a2c9aa7505a1f868576d8b" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=footer.css&amp;origin=footer&amp;hash=46136b8d20a2c9aa7505a1f868576d8b" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=auxiliary-content-list.css&amp;origin=auxiliary-content-list&amp;hash=83f39941ebaded00eb463d3231cb780b" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=auxiliary-content-list.css&amp;origin=auxiliary-content-list&amp;hash=83f39941ebaded00eb463d3231cb780b" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=modal-content-ticker.css&amp;origin=modal-content-ticker&amp;hash=32981a32a91e4ae6e46193cc8df28ddb" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=modal-content-ticker.css&amp;origin=modal-content-ticker&amp;hash=32981a32a91e4ae6e46193cc8df28ddb" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=report-error-default.css&amp;origin=report-error-button&amp;hash=c1c66c70b7c6e95fdae44485929bc903" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=report-error-default.css&amp;origin=report-error-button&amp;hash=c1c66c70b7c6e95fdae44485929bc903" rel="stylesheet"/>
#   </noscript>
#   <link as="style" href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=chunk-color$esporte.css&amp;origin=esporte&amp;hash=1c5a07a293772116f624b3526e3d7261" onload='this.onload=null;this.rel="stylesheet";' rel="preload"/>
#   <noscript>
#    <link href="//c.jsuol.com.br/assets/?loadComponent=assets&amp;tpl=chunk-color$esporte.css&amp;origin=esporte&amp;hash=1c5a07a293772116f624b3526e3d7261" rel="stylesheet"/>
#   </noscript>
#   <script type="text/javascript">
#    ;(function() {
#             window.createMeasureObserver = (measureName) => {
#                 var markPrefix = `_uol-measure-${measureName}-${new Date().getTime()}`;
#
#                 performance.mark(`${markPrefix}-start`);
#
#                 return {
#                     end: function() {
#                         performance.mark(`${markPrefix}-end`);
#                         performance.measure(`uol-measure-${measureName}`, `${markPrefix}-start`, `${markPrefix}-end`);
#                         performance.clearMarks(`${markPrefix}-start`);
#                         performance.clearMarks(`${markPrefix}-end`);
#                     }
#                 }
#             };
#
#             /**
#             * Gerenciador de eventos
#             */
#             window.gevent = {
#                 stack: [],
#                 RUN_ONCE: true,
#                 on: function(name, callback, once) {
#                     this.stack.push([name, callback, !!once]);
#                 },
#                 emit: function(name, args) {
#                     for (var i = this.stack.length, item; i--;) {
#                         item = this.stack[i];
#                         if (item[0] === name) {
#                             item[1](args);
#                             if (item[2]) {
#                                 this.stack.splice(i, 1);
#                             }
#                         }
#                     }
#                 }
#             };
#
#             var runningSearch = false;
#             var hadAnUserEvent = true;
#             var elementsToWatch = window.elementsToWatch = new Map();
#             var innerHeight = window.innerHeight;
#
#             // timestamp da última rodada do requestAnimationFrame
#             // É usado para limitar a procura por elementos visíveis.
#             var lastAnimationTS = 0;
#
#             // verifica se elemento está no viewport do usuário
#             var isElementInViewport = function(el) {
#                 var rect = el.getBoundingClientRect();
#                 var clientHeight = window.innerHeight || document.documentElement.clientHeight;
#
#                 // garante que usa ao mínimo 280px de margem para fazer o lazyload
#                 var margin = clientHeight + Math.max(280, clientHeight * 0.2);
#
#                 // se a base do componente está acima da altura da tela do usuário, está oculto
#                 if(rect.bottom < 0 && rect.bottom > margin * -1) {
#                     return false;
#                 }
#
#                 // se o topo do elemento está abaixo da altura da tela do usuário, está oculto
#                 if(rect.top > margin) {
#                     return false;
#                 }
#
#                 // se a posição do topo é negativa, verifica se a altura dele ainda
#                 // compensa o que já foi scrollado
#                 if(rect.top < 0 && rect.height + rect.top < 0) {
#                     return false;
#                 }
#
#                 return true;
#             };
#
#             var asynxNextFreeTime = () => {
#                 return new Promise((resolve) => {
#                     if(window.requestIdleCallback) {
#                         window.requestIdleCallback(resolve, {
#                             timeout: 5000,
#                         });
#                     } else {
#                         window.requestAnimationFrame(resolve);
#                     }
#                 });
#             };
#
#             var asyncValidateIfElIsInViewPort = function(promise, el) {
#                 return promise.then(() => {
#                     if(el) {
#                         if(isElementInViewport(el) == true) {
#                             const cb = elementsToWatch.get(el);
#
#                             // remove da lista para não ser disparado novamente
#                             elementsToWatch.delete(el);
#
#                             cb();
#                         }
#                     }
#                 }).then(asynxNextFreeTime);
#             };
#
#             // inicia o fluxo de procura de elementos procurados
#             var look = function() {
#                 if(window.requestIdleCallback) {
#                     window.requestIdleCallback(findByVisibleElements, {
#                         timeout: 5000,
#                     });
#                 } else {
#                     window.requestAnimationFrame(findByVisibleElements);
#                 }
#             };
#
#             var findByVisibleElements = function(ts) {
#                 var elapsedSinceLast = ts - lastAnimationTS;
#
#                 // se não teve nenhum evento que possa alterar a página
#                 if(hadAnUserEvent == false) {
#                     return look();
#                 }
#
#                 if(elementsToWatch.size == 0) {
#                     return look();
#                 }
#
#                 if(runningSearch == true) {
#                     return look();
#                 }
#
#                 // procura por elementos visíveis apenas 5x/seg
#                 if(elapsedSinceLast < 1000/5) {
#                     return look();
#                 }
#
#                 // atualiza o último ts
#                 lastAnimationTS = ts;
#
#                 // reseta status de scroll para não entrar novamente aqui
#                 hadAnUserEvent = false;
#
#                 // indica que está rodando a procura por elementos no viewport
#                 runningSearch = true;
#
#                 const done = Array.from(elementsToWatch.keys()).reduce(asyncValidateIfElIsInViewPort, Promise.resolve());
#
#                 // obtém todos os elementos que podem ter view contabilizados
#                 //elementsToWatch.forEach(function(cb, el) {
#                 //    if(isElementInViewport(el) == true) {
#                 //        // remove da lista para não ser disparado novamente
#                 //        elementsToWatch.delete(el);
#                 //        cb(el);
#                 //    }
#                 //});
#
#                 done.then(function() { runningSearch = false; });
#
#                 // reinicia o fluxo de procura
#                 look();
#             };
#
#             /**
#             * Quando o elemento `el` entrar no viewport (-20%), cb será disparado.
#             */
#             window.lazyload = function(el, cb) {
#                 if(el.nodeType != Node.ELEMENT_NODE) {
#                     throw new Error("element parameter should be a Element Node");
#                 }
#
#                 if(typeof cb !== 'function') {
#                     throw new Error("callback parameter should be a Function");
#                 }
#
#                 elementsToWatch.set(el, cb);
#             }
#
#             var setUserEvent = function() {
#                 hadAnUserEvent = true;
#             };
#
#             window.addEventListener('scroll', setUserEvent, { capture: true, passive: true });
#             window.addEventListener('click', setUserEvent, { passive: true });
#             window.addEventListener('resize', setUserEvent, { passive: true });
#             window.addEventListener('load', setUserEvent, { once: true, passive: true });
#             window.addEventListener('DOMContentLoaded', setUserEvent, { once: true, passive: true });
#             window.gevent.on('allJSLoadedAndCreated', setUserEvent, window.gevent.RUN_ONCE);
#
#             // inicia a validação
#             look();
#         })();
#   </script>
#   <script type="text/javascript">
#    var inHeadTS=(new Date).getTime();window.isUolNewGraphicDesign=!0,window.uolads=window.uolads||[],window.universal_variable=window.universal_variable||{},window.universal_variable.dfp={custom_params:{subchan:"",keyword:""}},window.universal_variable.page=window.universal_variable.page||{},window.universal_variable.page.tags=[15308,12810,79585,16026,16130];var _sf_async_config=_sf_async_config||{};_sf_async_config.uid=61085,_sf_async_config.domain="uol.com.br",_sf_async_config.flickerControl=!1,_sf_async_config.useCanonical=!0,_sf_async_config.autoDetect=!1;var _sf_startpt=(new Date).getTime();
#   </script>
#   <script type="text/javascript">
#    !function(t,n,o){t[n]=t[n]||function(){(t[n].q=t[n].q||[]).push(arguments)},t[n].t=t[n].t||[],t[n].t.push(o)}(window,"uolAnalytics","uolestacoes")
#   </script>
#   <script async="" crossorigin="anonymous" src="https://me.jsuol.com.br/aud/uolestacoes.js">
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script async="" src="https://tm.jsuol.com.br/modules/external/Prebid.js">
#   </script>
#   <script async="" src="https://tm.jsuol.com.br/modules/external/tailtarget/profiles.js">
#   </script>
#   <script async="" src="https://tm.jsuol.com.br/modules/external/tailtarget/t3m/TT-10162-1/CT-10.js">
#   </script>
#   <script async="" src="https://tm.jsuol.com.br/uoltm.js?id=zvcg6p">
#   </script>
#   <script async="" src="https://static.chartbeat.com/js/chartbeat_mab.js">
#   </script>
#   <script type="text/javascript">
#    var Component={}
#   </script>
#   <script id="see-jserror" type="text/javascript">
#    ;(function(window) {
#     // Valida se o navegador possui suporte para `Symbol`. Se não tiver,
#     // está em um range de navegadores não mais suportados pelo UOL e que
#     // não precisam ter o registro de erros feito.
#     var isBrowserSupported = "Symbol" in window;
#
#     console.log('[see-jserror] ativando registro de erro', isBrowserSupported);
#
#     var historyErrors = [{
#         message: "Script error.",
#         stack: "Script error. at :0:0"
#     }];
#
#     var findError = function(data) {
#         data = data || {};
#         for(var i=0; i < historyErrors.length; i++) {
#             if(data.message == historyErrors[i].message && data.stack == historyErrors[i].stack) {
#                 console.log('[see-jserror] erro já reportado');
#                 return true;
#             }
#         }
#
#         historyErrors.push(data);
#
#         return false;
#     };
#
#     var storageValidation = (function(window) {
#         'use strict';
#         var validation;
#         try {
#             // IE <= 9 e demais navegadores devem retornar TRUE
#             validation = !!window.localStorage;
#
#             // Se estiver em modo Private no Safari, DOM Exception será retornado,
#             // alegando falta de espaço para armazenamento.
#             if(validation === true) {
#                 localStorage.setItem('__test', '');
#                 localStorage.removeItem('__test');
#             }
#         } catch(e) {
#             // possível erro de Access Denied no IE 10 ou
#             // modo private no Safari.
#             validation = false;
#         }
#         return validation;
#     }(window));
#
#     function getAdBlockerStatus() {
#         try {
#             switch (googlefc.getAdBlockerStatus()) {
#             case googlefc.AdBlockerStatusEnum.EXTENSION_LEVEL_AD_BLOCKER:
#                 return 'EXTENSION_LEVEL_AD_BLOCKER';
#
#             case googlefc.AdBlockerStatusEnum.NETWORK_LEVEL_AD_BLOCKER:
#                 return 'NETWORK_LEVEL_AD_BLOCKER';
#
#             case googlefc.AdBlockerStatusEnum.NO_AD_BLOCKER:
#                 return 'NO_AD_BLOCKER';
#
#             case googlefc.AdBlockerStatusEnum.UNKNOWN:
#                 return 'UNKNOWN';
#             }
#         } catch(err) {
#             return `GOOGLEFC_ERROR: ${err.message}`;
#         }
#     };
#
#     function continueReportError(data) {
#         console.log('[see-jserror] novo erro reportado');
#
#         var body = [{
#             'groupingMap': {
#                 'Url': window.location.href,
#                 'UserAgent': window.navigator.userAgent + '',
#                 'CookieAtivado': window.navigator.cookieEnabled + '',
#                 'Language': window.navigator.language,
#                 'LocalStorage': storageValidation + '',
#                 'Erro': data.message || '',
#                 'Stack': data.stack || '',
#                 'AdBlockerStatus': getAdBlockerStatus(),
#                 'HitJsDomain': 'true',
#                 'ErrorTime': data.ErrorTime,
#             },
#             'measureMap': {
#                 'JSErrors': 1
#             }
#         }];
#
#         // valida se tem acesso ao c.jsuol para descartar problemas de proxy ou bloqueios
#         // em redes corporativas / adblocks
#         fetch("https://c.jsuol.com.br/assets/?loadComponent=media&contentType=js").then(function(response) {
#             if(response.status == 200) {
#                 return Promise.resolve();
#             }
#
#             return Promise.reject('Failed to fetch, statusCode ' + response.status);
#         }).catch(function(err) {
#             body[0].groupingMap.HitJsDomain = 'false';
#             body[0].groupingMap.Erro += ' (hit jsuol: ' + err.message + ')';
#         }).then(function() {
#             var req = new XMLHttpRequest();
#             req.open('POST', '//logger.uol.com.br/v1/?prd=41&disp=true&mm=true', true);
#             req.setRequestHeader('Content-Type', 'application/json; charset=UTF-8');
#             req.send(JSON.stringify(body));
#         });
#     }
#
#     window.ReportError = function(data) {
#         if(isBrowserSupported === false) {
#             console.log('[see-jserror] browser not supported, ignoring error');
#             return undefined;
#         }
#
#         try {
#             console.log('[see-jserror] report error');
#
#             // utiliza try..catch para evitar loop
#             data = data || {};
#
#             if(findError(data) == true) {
#                 return undefined;
#             }
#
#             data.ErrorTime = performance.now();
#
#             // limita o wait ao Google FC em 5s para evitar perder registro de erro
#             // caso ocorra algum problema com a lib
#             var googleFcTimeout = setTimeout(function() {
#                 continueReportError(data);
#             }, 5 * 1000);
#
#             // Make sure that the properties exist on the window.
#             window.googlefc = window.googlefc || {};
#             window.googlefc.ccpa = window.googlefc.ccpa || {}
#             window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
#
#             // Garante que o Google FC está pronto e com o status de adblock obtido.
#             googlefc.callbackQueue.push({
#                 'AD_BLOCK_DATA_READY': function () {
#                     clearTimeout(googleFcTimeout);
#                     continueReportError(data);
#                 }
#             });
#         } catch(err) {
#             console.error('[see-jserror] erro ao enviar erro :/', err.message);
#             return undefined;
#         }
#     };
#
#     window.onerror = function(message, file, line, column, error) {
#         try {
#             // utiliza try..catch para evitar loop
#             window.ReportError({
#                 message: error ? error.message : message,
#                 stack: error ? error.stack : message+' at '+file+':'+line+':'+column
#             });
#         } catch(e) { console.error('[see-jserror] catch ', e) }
#     };
# })(window);
#   </script>
#   <script type="text/javascript">
#    window._uolabtestsev=window._uolabtestsev||[]
#   </script>
#   <script async="" src="https://abtest.conteudo.uol/c/abc.js">
#   </script>
#   <script async="" src="https://contributor.google.com/scripts/6ad0910ba2d6bbd7/loader.js">
#   </script>
#   <script>
#    window.googlefc = window.googlefc || {};
#             window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
#
#             googlefc.controlledMessagingFunction = function(message) {
#                 var hasCookie = function(cookieName) {
#                     var hasCookie = false;
#                     var allCookies = document.cookie.split(';');
#                     for (var i=allCookies.length-1; i>=0; i--) {
#                         if(allCookies[i].indexOf(cookieName) >= 0) {
#                             hasCookie = true;
#                         }
#                     }
#                     return hasCookie;
#                 };
#                 var hasCookieGFC = hasCookie('_ugfc');
#
#                 if (!hasCookieGFC) {
#                     message.proceed(true);
#
#                     // Cookie para controle de sessão
#                     // Modal será exibido somente 1x ao dia
#                     var midnight = new Date();
#                     midnight.setDate(midnight.getDate() + 6);
#                     midnight.setHours(23, 59, 59, 0);
#                     document.cookie = '_ugfc=1; expires='+midnight.toUTCString()+'; domain=uol.com.br; path=/';
#                 } else {
#                     message.proceed(false);
#                 }
#             };
#   </script>
#   <script>
#    (function(){'use strict';var g=function(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}},l=this||self,aa=/^[\w+/_-]+[=]{0,2}$/,m=null,p=function(){},q=function(a){var b=typeof a;if("object"==b)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return b;var c=Object.prototype.toString.call(a);if("[object Window]"==c)return"object";if("[object Array]"==c||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";
#             if("[object Function]"==c||"undefined"!=typeof a.call&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";else if("function"==b&&"undefined"==typeof a.call)return"object";return b},r=Date.now||function(){return+new Date},t=function(a,b){function c(){}c.prototype=b.prototype;a.prototype=new c;a.prototype.constructor=a};var ba=function(a,b){Object.defineProperty(l,a,{configurable:!1,get:function(){return b},set:p})};var x=function(a,b){this.b=a===v&&b||"";this.a=w},w={},v={};var ca=function(a,b){a.src=b instanceof x&&b.constructor===x&&b.a===w?b.b:"type_error:TrustedResourceUrl";if(null===m)b:{b=l.document;if((b=b.querySelector&&b.querySelector("script[nonce]"))&&(b=b.nonce||b.getAttribute("nonce"))&&aa.test(b)){m=b;break b}m=""}b=m;b&&a.setAttribute("nonce",b)};var y=function(){return Math.floor(2147483648*Math.random()).toString(36)+Math.abs(Math.floor(2147483648*Math.random())^r()).toString(36)};var z=function(a,b){b=String(b);"application/xhtml+xml"===a.contentType&&(b=b.toLowerCase());return a.createElement(b)},A=function(a){this.a=a||l.document||document};A.prototype.appendChild=function(a,b){a.appendChild(b)};var B=function(a,b,c,d,e,f){try{var k=a.a,h=z(a.a,"SCRIPT");h.async=!0;ca(h,b);k.head.appendChild(h);h.addEventListener("load",function(){e();d&&k.head.removeChild(h)});h.addEventListener("error",function(){0<c?B(a,b,c-1,d,e,f):(d&&k.head.removeChild(h),f())})}catch(n){f()}};var da=l.atob("aHR0cHM6Ly93d3cuZ3N0YXRpYy5jb20vaW1hZ2VzL2ljb25zL21hdGVyaWFsL3N5c3RlbS8xeC93YXJuaW5nX2FtYmVyXzI0ZHAucG5n"),ea=l.atob("WW91IGFyZSBzZWVpbmcgdGhpcyBtZXNzYWdlIGJlY2F1c2UgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlIGlzIGludGVyZmVyaW5nIHdpdGggdGhpcyBwYWdlLg=="),fa=l.atob("RGlzYWJsZSBhbnkgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlLCB0aGVuIHJlbG9hZCB0aGlzIHBhZ2Uu"),ha=function(a,b,c){this.b=a;this.f=new A(this.b);this.a=null;this.c=[];this.g=!1;this.i=b;this.h=c},E=function(a){if(a.b.body&&!a.g){var b=
#             function(){C(a);l.setTimeout(function(){return D(a,3)},50)};B(a.f,a.i,2,!0,function(){l[a.h]||b()},b);a.g=!0}},C=function(a){for(var b=F(1,5),c=0;c<b;c++){var d=G(a);a.b.body.appendChild(d);a.c.push(d)}b=G(a);b.style.bottom="0";b.style.left="0";b.style.position="fixed";b.style.width=F(100,110).toString()+"%";b.style.zIndex=F(2147483544,2147483644).toString();b.style["background-color"]=H(249,259,242,252,219,229);b.style["box-shadow"]="0 0 12px #888";b.style.color=H(0,10,0,10,0,10);b.style.display=
#             "flex";b.style["justify-content"]="center";b.style["font-family"]="Roboto, Arial";c=G(a);c.style.width=F(80,85).toString()+"%";c.style.maxWidth=F(750,775).toString()+"px";c.style.margin="24px";c.style.display="flex";c.style["align-items"]="flex-start";c.style["justify-content"]="center";d=z(a.f.a,"IMG");d.className=y();d.src=da;d.style.height="24px";d.style.width="24px";d.style["padding-right"]="16px";var e=G(a),f=G(a);f.style["font-weight"]="bold";f.textContent=ea;var k=G(a);k.textContent=fa;I(a,
#             e,f);I(a,e,k);I(a,c,d);I(a,c,e);I(a,b,c);a.a=b;a.b.body.appendChild(a.a);b=F(1,5);for(c=0;c<b;c++)d=G(a),a.b.body.appendChild(d),a.c.push(d)},I=function(a,b,c){for(var d=F(1,5),e=0;e<d;e++){var f=G(a);b.appendChild(f)}b.appendChild(c);c=F(1,5);for(d=0;d<c;d++)e=G(a),b.appendChild(e)},F=function(a,b){return Math.floor(a+Math.random()*(b-a))},H=function(a,b,c,d,e,f){return"rgb("+F(Math.max(a,0),Math.min(b,255)).toString()+","+F(Math.max(c,0),Math.min(d,255)).toString()+","+F(Math.max(e,0),Math.min(f,
#             255)).toString()+")"},G=function(a){a=z(a.f.a,"DIV");a.className=y();return a},D=function(a,b){0>=b||null!=a.a&&0!=a.a.offsetHeight&&0!=a.a.offsetWidth||(ia(a),C(a),l.setTimeout(function(){return D(a,b-1)},50))},ia=function(a){var b=a.c;var c="undefined"!=typeof Symbol&&Symbol.iterator&&b[Symbol.iterator];b=c?c.call(b):{next:g(b)};for(c=b.next();!c.done;c=b.next())(c=c.value)&&c.parentNode&&c.parentNode.removeChild(c);a.c=[];(b=a.a)&&b.parentNode&&b.parentNode.removeChild(b);a.a=null};var ka=function(a,b,c,d,e){var f=ja(c),k=function(n){n.appendChild(f);l.setTimeout(function(){f?(0!==f.offsetHeight&&0!==f.offsetWidth?b():a(),f.parentNode&&f.parentNode.removeChild(f)):a()},d)},h=function(n){document.body?k(document.body):0<n?l.setTimeout(function(){h(n-1)},e):b()};h(3)},ja=function(a){var b=document.createElement("div");b.className=a;b.style.width="1px";b.style.height="1px";b.style.position="absolute";b.style.left="-10000px";b.style.top="-10000px";b.style.zIndex="-10000";return b};var J={},K=null;var L=function(){},M="function"==typeof Uint8Array,N=function(a,b){a.b=null;b||(b=[]);a.j=void 0;a.f=-1;a.a=b;a:{if(b=a.a.length){--b;var c=a.a[b];if(!(null===c||"object"!=typeof c||"array"==q(c)||M&&c instanceof Uint8Array)){a.g=b-a.f;a.c=c;break a}}a.g=Number.MAX_VALUE}a.i={}},O=[],P=function(a,b){if(b<a.g){b+=a.f;var c=a.a[b];return c===O?a.a[b]=[]:c}if(a.c)return c=a.c[b],c===O?a.c[b]=[]:c},Q=function(a,b,c){if(b<a.g)a.a[b+a.f]=c;else{var d=a.g+a.f;a.a[d]||(a.c=a.a[d]={});a.c[b]=c}return a},S=
#             function(a,b){var c=R;a.b||(a.b={});if(!a.b[b]){var d=P(a,b);d&&(a.b[b]=new c(d))}return a.b[b]};
#             L.prototype.h=M?function(){var a=Uint8Array.prototype.toJSON;Uint8Array.prototype.toJSON=function(){var b;void 0===b&&(b=0);if(!K){K={};for(var c="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789".split(""),d=["+/=","+/","-_=","-_.","-_"],e=0;5>e;e++){var f=c.concat(d[e].split(""));J[e]=f;for(var k=0;k<f.length;k++){var h=f[k];void 0===K[h]&&(K[h]=k)}}}b=J[b];c=[];for(d=0;d<this.length;d+=3){var n=this[d],u=(e=d+1<this.length)?this[d+1]:0;h=(f=d+2<this.length)?this[d+2]:0;k=n>>2;n=(n&
#             3)<<4|u>>4;u=(u&15)<<2|h>>6;h&=63;f||(h=64,e||(u=64));c.push(b[k],b[n],b[u]||"",b[h]||"")}return c.join("")};try{return JSON.stringify(this.a&&this.a,T)}finally{Uint8Array.prototype.toJSON=a}}:function(){return JSON.stringify(this.a&&this.a,T)};var T=function(a,b){return"number"!=typeof b||!isNaN(b)&&Infinity!==b&&-Infinity!==b?b:String(b)};L.prototype.toString=function(){return this.a.toString()};var R=function(a){N(this,a)};t(R,L);var U=function(a){N(this,a)};t(U,L);var la=function(a,b){this.c=new A(a);var c=S(b,5);c=new x(v,P(c,4)||"");this.b=new ha(a,c,P(b,4));this.a=b},ma=function(a,b,c,d){b=new R(b?JSON.parse(b):null);b=new x(v,P(b,4)||"");B(a.c,b,3,!1,c,function(){ka(function(){E(a.b);d(!1)},function(){d(!0)},P(a.a,2),P(a.a,3),P(a.a,1))})};var na=function(a,b){V(a,"internal_api_load_with_sb",function(c,d,e){ma(b,c,d,e)});V(a,"internal_api_sb",function(){E(b.b)})},V=function(a,b,c){a=l.btoa(a+b);ba(a,c)},W=function(a,b,c){for(var d=[],e=2;e<arguments.length;++e)d[e-2]=arguments[e];e=l.btoa(a+b);e=l[e];if("function"==q(e))e.apply(null,d);else throw Error("API not exported.");};var X=function(a){N(this,a)};t(X,L);var Y=function(a){var b=this.h=l.document;var c=new U;var d=P(a,3);c=Q(c,1,d);d=P(a,12);c=Q(c,2,d);d=P(a,5);c=Q(c,3,d);d=P(a,10);c=Q(c,4,d);d=S(a,11);c.b||(c.b={});var e=d?d.a:d;c.b[5]=d;c=Q(c,5,e);this.g=new la(b,c);this.a=P(a,1);this.f=S(a,2);this.c=!1;this.b=a};Y.prototype.start=function(){try{oa(),na(this.a,this.g),l.googlefc=l.googlefc||{},"callbackQueue"in l.googlefc||(l.googlefc.callbackQueue=[]),pa(this)}catch(a){W(this.a,"internal_api_sb")}};
#             var oa=function(){var a=function(){if(!l.frames.googlefcPresent)if(document.body){var b=document.createElement("iframe");b.style.display="none";b.style.width="0px";b.style.height="0px";b.style.border="none";b.style.zIndex="-1000";b.style.left="-1000px";b.style.top="-1000px";b.name="googlefcPresent";document.body.appendChild(b)}else l.setTimeout(a,5)};a()},pa=function(a){var b=r();W(a.a,"internal_api_load_with_sb",a.f.h(),function(){var c;var d=a.a,e=l[l.btoa(d+"cached_js")];if(e){e=l.atob(e);e=parseInt(e,
#             10);d=l.btoa(d+"cached_js").split(".");var f=l;d[0]in f||"undefined"==typeof f.execScript||f.execScript("var "+d[0]);for(;d.length&&(c=d.shift());)d.length?f[c]&&f[c]!==Object.prototype[c]?f=f[c]:f=f[c]={}:f[c]=null;c=Math.abs(b-e);c=1728E5>c?0:c}else c=-1;0!=c&&(W(a.a,"internal_api_sb"),Z(a,P(a.b,9)))},function(c){c?Z(a,P(a.b,7)):Z(a,P(a.b,8))})},Z=function(a,b){a.c||(a.c=!0,a=new l.XMLHttpRequest,a.open("GET",b,!0),a.send())};(function(a,b){l[a]=function(c){for(var d=[],e=0;e<arguments.length;++e)d[e-0]=arguments[e];l[a]=p;b.apply(null,d)}})("__475an521in8a__",function(a){"function"==typeof l.atob&&(a=l.atob(a),a=new X(a?JSON.parse(a):null),(new Y(a)).start())});}).call(this);
#             window.__475an521in8a__("...");
#   </script>
#  </head>
#  <body data-is-bot="false">
#   <span central="esporte" channel-name="www.uol.com.br" class="uol-notifications-widget" data-container=".webalert_parent_container" style="display:none;" themes="geral,futebol">
#   </span>
#   <script async="" crossorigin="anonymous" src="https://c.jsuol.com.br/assets/?loadComponent=media&amp;contentType=js&amp;tpl=assets/dist/service-worker/webalert-notification&amp;cache=202201201930">
#   </script>
#   <script type="text/javascript">
#    "Promise"in window==1&&"serviceWorker"in navigator==1&&navigator.serviceWorker.getRegistrations().then(function(r){for(var e in r){var t=r[e];if(t&&t.scope=="https://"+location.hostname+"/"){var o=t.active;if(!0===/\?loadComponent=service-worker\&vn$/.test(o.scriptURL))try{window.ReportError({message:"service-worker-start: removendo SW deprecated",stack:"SW url: "+o.scriptURL}),t.unregister()}catch(r){}}}})
#   </script>
#   <span class="football-ws" data-settings='{"general":true,"ticker":true,"standingsAndMatch":true}'>
#   </span>
#   <script type="application/ld+json">
#    [{"@type":"NewsArticle","@context":"http://schema.org","headline":"Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu","description":"Acostumado a ter em seu gramado grandes jogadores, dribles desconcertantes e gols inesquecíveis, o estádio do Pacaembu teve uma manhã diferente no dia 20 de agosto de 1995. Palmeiras e São Paulo - que se enfrentam neste sábado (22), pela semifinal da Copa","author":{"name":"Thiago Braga","@type":"Person","url":"https://uol.com.br/"},"publisher":{"@type":"Organization","name":"UOL","url":"https://www.uol.com.br","logo":{"@type":"ImageObject","url":"https://conteudo.imguol.com.br/uolamp/UOL_logo_156x60.png","width":156,"height":60}},"url":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm","mainEntityOfPage":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm","image":["https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_1x1.jpg","https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_3x4.jpg","https://conteudo.imguol.com.br/c/esporte/1b/2015/08/20/briga-entre-as-torcidas-do-palmeiras-e-do-sao-paulo-durante-a-final-da-taca-sao-paulo-de-juniores-de-1995-1440111821589_v2_4x3.jpg"],"datePublished":"2022-01-22T04:00:00-03:00","dateModified":"2022-01-22T04:00:32-03:00"}]
#   </script>
#   <div class="bannersticky-base">
#   </div>
#   <div class="bannersticky-wrapper">
#    <div class="bannersticky-top-container">
#     <div class="bannersticky-top ignore-header">
#      <div class="ads-wrapper">
#       <div class="chapeu">
#        <span>
#         PUBLICIDADE
#        </span>
#       </div>
#       <div class="ads" data-ads='{"xs":"responsive-top-horizontal","sm":"responsive-top-horizontal","md":"responsive-top-horizontal","lg":"responsive-top-horizontal"}' data-disablescroll="false">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <header class="header webalert_parent_container gradient fixed" data-chn-id="22" data-has-scroll-metrics="" data-refresh-sess="true" data-scroll-metrics="">
#    <div class="container">
#     <div class="over">
#      <div class="header-menu-lateral">
#       <ul class="products clearfix hidden-xs hidden-sm">
#        <li>
#         <a data-audience-click='{"component":"barra-uol","reference":"item-batepapo","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://batepapo.uol.com.br/">
#          BATE-PAPO
#         </a>
#        </li>
#        <li>
#         <a data-audience-click='{"component":"barra-uol","reference":"item-uol-meunegocio","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://meunegocio.uol.com.br/?utm_source=uol.com.br&amp;utm_medium=barrauol&amp;utm_campaign=linkfixo-barrauol-umn&amp;utm_term=barrauol-umn&amp;utm_content=barrauol-umn">
#          UOL MEU NEGÓCIO
#         </a>
#        </li>
#        <li>
#         <a data-audience-click='{"component":"barra-uol","reference":"item-cursos","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://www.passeidireto.com/?utm_source=uol.com.br&amp;utm_medium=barra-uol">
#          Estude Online
#         </a>
#        </li>
#        <li>
#         <a data-audience-click='{"component":"barra-uol","reference":"item-pagseguro","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://clicklogger.rm.uol.com.br/?prd=32&amp;grp=src:210;chn:22;cpg:barrauol;creative:barrauol-pagseguro&amp;msr=Cliques%20de%20Origem:1&amp;oper=11&amp;redir=https://pagseguro.uol.com.br/">
#          Pagseguro
#         </a>
#        </li>
#        <li>
#         <a data-audience-click='{"component":"barra-uol","reference":"item-pagbank","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://clicklogger.rm.uol.com.br/?prd=32&amp;grp=src:210;chn:22;cpg:barrauol;creative:barrauol-pagseguro&amp;msr=Cliques%20de%20Origem:1&amp;oper=11&amp;redir=https://pagseguro.uol.com.br/">
#          PagBank
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="header-logo">
#       <div class="logo reverse">
#        <div class="alignment">
# ...
#                </p>
#                <time class="thumb-date">
#                 22/01/2022 09h06
#                </time>
#               </div>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <button class="btn-search align-center ver-mais btn-more btn btn-large btn-primary" data-audience-click='{"reference":"ver-mais","component":"results-index-click","mediaName":"Home"}' data-history="true" data-loadcomponent="" data-next="0001H43233U11N" data-request='{"history":true,"dateFormat":"DD/MM/YYYY HH[h]mm","busca":{"params":{"size":12,"conteudo-adulto":"false","charset":"utf-8","format":"json","repository":"mix2","sort":"created:desc","pgv3":true,"tags-id":"15308","id-not":"publisher-6aed318a7bde45f4161dfba864fcaac20220121","next":"0001H43233U11N"}},"options":{"scrollLoad":false,"crop":"300x225","variation":"list","hideKicker":true,"hideDate":"","hideAuthor":true,"hideDescriptionWithImage":"","gallery":{"columnEnd":3,"columnClass":"col-xs-4 col-sm-8"}},"hasNext":true,"request":{},"thumbnails":{"list":true,"alignHorizontal":true,"grid":false,"columns":""},"ads":{"show":false},"native":{"show":false}}'>
#         ver mais
#         <svg class="svg-icon-view-box-small right-icon">
#          <use xlink:href="#svg-single-arrow-down">
#          </use>
#         </svg>
#        </button>
#       </section>
#      </div>
#      <div class="col-md-8 col-lg-7 hidden-xs hidden-sm sidebar">
#       <div class="ads-wrapper">
#        <div class="chapeu">
#         <span>
#          PUBLICIDADE
#         </span>
#        </div>
#        <div class="ads" data-ads='{"md":"responsive-vertical"}' data-disablescroll="false">
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <script id="js-collection">
#    var Collection = {
#                 "path" : "commons.uol.com.br/monaco/export/api.uol.com.br/collection/esporte/futebol/ultimas//data.json",
#                 "collectionIndex" : true,
#                 "channel" : "futebol",
#                 "central" : "esporte",
#                 "titulo" : "Futebol",
#                 "search" : {"repository":"mix2","tags":"15308"}
#             };
#   </script>
#   <div class="lazy-component not-loaded" config-name="esporte/esporte.futebol.ultimas-noticias" cp-area='{"xs-sm":"230px","md-lg":"128px"}' cp-data='{"audience":{"pv":{"mediaName":"Notícia","mediaType":"article","mediaId":"6aed318a7bde45f4161dfba864fcaac20220121","mediaTitle":"Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu","collection":"Futebol","tags":"15308,12810,79585,16026,16130","channel":"futebol","central":"esporte","author":"Thiago Braga","publicationDate":"20220122040000"},"click":{"mediaName":"Notícia","source":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm"}},"isNoSpace":false}' cp-name="footer" cp-shell="false" detected="false" style="height:128px">
#   </div>
#   <script id="js-audience">
#    var Audience = {"channel":"futebol","central":"esporte","mediaName":"Notícia","mediaType":"article","mediaId":"6aed318a7bde45f4161dfba864fcaac20220121","mediaTitle":"Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu","collection":"Futebol","tags":"15308,12810,79585,16026,16130","author":"Thiago Braga","publicationDate":"22/01/2022 04:00:00","abTest3":"album:nao|enquete:nao|foto:meio|foto:topo|lista:nao|video:nao|video_autoplay:sem","charactersQuantity":2935,"ga":{"rollupChannel":"Estacoes","id":"UA-97689914-185","filename":"uolestacoes"}};
#   </script>
#   <script>
#    var Config = {"platform":"web","allComponents":[],"portal":{"slug":"uol","title":"UOL"},"central":{"title":"Esporte","slug":"esporte","link":"https://www.uol.com.br/esporte/"},"channel":{"title":"Esporte","slug":"esporte","link":"https://www.uol.com.br/esporte/"},"color":"esporte","configPath":"esporte/esporte.futebol.ultimas-noticias","servicename":"/esporte/service/","loadedCssAssets":["reset","alert","forms","photo","grid","headings","icons","svg-icons","label","table","link","scroll","masks","read-more","misc","paragraph","hr","line","time","modal","babel-login","webfonts","piano-modal","ads","thumbnail-standard","thumbnails","author","results-index","badge-content-past","collection-index","header-menu","logo","photo-embed","related-content","share","widget-profile","article-wrapper","back-to-top","bannersticky","chartbeat-related-content","collection","components-loader","feed-gallery-render","footer","header","title","tooltip","auxiliary-content-list","comments","match-center-ticker","modal-content-ticker","report-error-button","tabs","teams-nav","title-sponsor"],"cache":202201201930};
#   </script>
#   <script>
#    var System = {"corepath":"commons.uol.com.br/static/v3","monaco":"commons.uol.com.br/monaco/export","version":"static/v3","media":{"js":"//c.jsuol.com.br/assets/?loadComponent=media&contentType=js","css":"//c.jsuol.com.br/assets/?loadComponent=assets"},"map":{"css":{"a2hs-install":"a2hs-install.css","accordion-box":"accordion-box.css","ads":"ads-default.css","agenda-brazil-wrapper":"agenda-brazil-wrapper.css","agenda-brazil":"agenda-brazil.css","album-content":"album-content.css","album-content/version/vertical":"album-content.vertical.css","album-embed":"base-structure-album.css","album-embed/version/vertical":"base-structure-album-vertical.css","album-header":"album-header.css","album-header/version/universa":"logo-universa.css","album-header/version/vertical":"album-header.vertical.css","alert":"default.css","amp-consent":"amp-consent.css","amp-stories-page-editorial":"logo-mov.css","amp-stories-page":"logo-mov.css","amp-stories-reporterror":"amp-stories-reporterror.css","amp-stories-story-editorial":"amp-stories-story-editorial.css","amp-stories-story-editorial/version/vertical":"amp-stories-story-editorial.vertical.css","amp-stories-story":"amp-stories-story.css","amp-stories-story/version/vertical":"amp-stories-story.vertical.css","animated-gif":"animated-gif.css","article-wording-correction":"article-wording-correction.css","article-wording-home":"article-wording-home.css","article-wording":"article-wording.css","article-wrapper":"base-structure-article.css","article-wrapper/version/vertical":"base-structure-article-vertical.css","author":"base-structure-article.css","author/version/vertical":"base-structure-article-vertical.css","auxiliary-content-box":"auxiliary-content-box.css","auxiliary-content-list":"auxiliary-content-list.css","babel-login":"comment-default.css","babel-login/version/vertical":"comment-vertical.css","back-to-top/version/bol":"back-to-top.bol.css","back-to-top":"base-structure.css","back-to-top/version/vertical":"default-vertical.css","badge-content-past":"badge-content-past.css","bannersmart":"ads-default.css","bannersticky":"base-structure.css","bio-date":"base-structure-education-biography.css","blog-ads":"blog-ads.css","blog-article":"blog-article.css","blog-header":"base-structure-colunists.css","blog-header/version/vertical":"base-structure-colunists-vertical.css","blogs-and-columns-recommendation":"blogs-and-columns-recommendation.css","blogs-and-columns":"home-default.css","blogs-and-columns/version/vertical":"home-vertical.css","calendar":"base-structure-sport-matches.css","card-simulator":"card-simulator.css","carnauol-bottom-2020":"carnauol-bottom-2020.css","carnauol-bottom":"carnauol-bottom.css","carnauol-page-2020":"carnauol-page-2020.css","carnauol-page":"carnauol-page.css","carnauol-top-2020":"carnauol-top-2020.css","carnauol-top":"carnauol-top.css","championship-home":"championship-home.css","championship-index":"championship-index.css","channel-collection-guide":"channel-collection-guide.css","channel-live-guide":"channel-live-guide.css","channel-player":"channel-player.css","channel-related-list":"channel-related-list.css","channel-wrapper":"base-canaluol-play.css","chapter-synopsis":"chapter-synopsis.css","chartbeat-related-content":"base-structure-related-content.css","chartbeat-results-index":"chartbeat-results-index.css","classification":"base-structure-sport-f1.css","collection-brief":"collection-brief.css","collection-championship-proxy":"base-structure-sport-standings.css","collection-home":"collection-home.css","collection-home/version/vertical":"collection-home.vertical.css","collection-index":"collection-vertical.css","collection-index/version/vertical":"collection-vertical.css","collection-item":"collection-default.css","collection-standard":"collection-standard.css","collection":"collection-vertical.css","collection/version/vertical":"collection-vertical.css","comments":"comment-default.css","comments/version/vertical":"comment-vertical.css","compare-dropdown-group" ...
#   </script>
#   <script crossorigin="anonymous" src="https://c.jsuol.com.br/assets/?loadComponent=media&amp;contentType=js&amp;tpl=assets/dist/libs/jquery.min&amp;cache=202201201930">
#   </script>
#   <script crossorigin="anonymous" src="https://c.jsuol.com.br/assets/?loadComponent=media&amp;contentType=js&amp;tpl=assets/dist/audience/audience.min&amp;cache=202201201930">
#   </script>
#   <script type="text/javascript">
#    window._asyncLoadScript = function asyncLoadScript(src) {
#     var script = document.createElement('script');
#     script.type = 'text/javascript';
#     script.async = true;
#     script.crossOrigin = 'anonymous';
#     script.src = src;
#
#     document.head.appendChild(script);
#
#     return new Promise(function(resolve) {
#         script.onload = script.onreadystatechange = function() {
#             if (!script.readyState || script.readyState == 'loaded' || script.readyState == 'complete') {
#                 document.head.removeChild(script);
#                 script.onload = script.onreadystatechange = null;
#                 resolve();
#             }
#         }
#     });
# };
#
# ;(function (document) {
#     var generics = [
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/duckslake-sdk.min&cache=202201201930',
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/uol-talker/uol-talker&cache=202201201930',
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/frameworks.min&cache=202201201930',
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/libs.min&cache=202201201930',
#         '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/libs/angular.min&cache=202201201930',
#     ];
#
#     // carrega todos os scripts não dependentes um do outro
#     var promises = generics.map(_asyncLoadScript);
#
#     return Promise.all(promises)
#         .then(function() {
#             // carrega a expose e os scripts necessários para webpack
#             return Promise.all([
#                 '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/exposejs/expose.min&cache=202201201930',  '//c.jsuol.com.br/assets/?loadComponent=assets&contentType=js&tpl=vendors.js,runtime.js,main.js&hash=085429b9ad48fff7a61ef6a79e422dc0aeb33c349bfdfd8586603bbd78e5&origin=vendors-js',  ].map(_asyncLoadScript));
#         })
#         .then(function() {
#             // Executa o UOLoader e carrega os scripts que dependen da expose
#             // Como são ações que não dependem de si, rodam em paralelo
#             return Promise.all([
#                 UOLoader([{"id":"svg-icons","path":"structure/bootstrap/svg-icons"},{"id":"results-index","path":"basics/results-index"},{"id":"header-menu","path":"basics/header-menu"},{"id":"widget-profile","path":"basics/widget-profile"},{"id":"article-wrapper","path":"basics/article-wrapper"},{"id":"back-to-top","path":"basics/back-to-top"},{"id":"feed-gallery-render","path":"projects/feed/feed-gallery/feed-gallery-render"},{"id":"header","path":"basics/header"},{"id":"header-slot","path":"basics/header-slot"},{"id":"title","path":"basics/title"},{"id":"feed-redirect","path":"projects/feed/feed-redirect"},{"id":"modal-content-ticker","path":"basics/modal-content-ticker"},{"id":"related-content-front","path":"basics/related-content-front"},{"id":"report-error-button","path":"basics/report-error-button"},{"id":"title-sponsor","path":"basics/title-sponsor"},{"id":"user","path":"basics/user"},{"id":"scroll","path":"structure/bootstrap/scroll"},{"id":"piano/version/esporte","path":"basics/piano/version/esporte"}]),
#                 ...[
#                     '//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=alert,forms,photo,read-more,modal,babel,babel-login,contauol-login,babel-service,suggest,ads,share,collection,tooltip,comments,football-ws,match-center-ticker,tabs,teams-nav&cache=202201201930',
#                 ].map(_asyncLoadScript),
#             ]);
#         })
#         .then(function() {
#             // roda o primeiro render
#             render();
#
#             // dispara evento que indica que o primeiro UOLoader foi completo
#             window.gevent.emit('firstLoaderDone');
#         });
# })(document);
#   </script>
#   <script language="JavaScript1.1">
#    (function() {
#             var tag = document.createElement("script");
#             var attrsTail = [{"key":"tt_age","value":"tt_age"},{"key":"tt_cluster","value":"tt_cluster"},{"key":"tt_gender","value":"tt_gender"},{"key":"tt_microsegments","value":"tt_microsegments"},{"key":"tt_socialclass","value":"tt_socialclass"},{"key":"tt_subjects","value":"tt_subjects"},{"key":"tt_teams","value":"tt_subjects"}];
#             var dType = window.Config && window.Config.channel && window.Config.channel.slug || '';
#             var tailNa = attrsTail.reduce((item, { key, value }) => {
#                 item[key] = 'na';
#                 return item;
#             }, {});
#
#             var userTailDataLayer = Object.assign(tailNa, (window.UOLPD && UOLPD.dataLayer || {}), {});
#
#             var dataLayer = Object.keys(userTailDataLayer).reduce((data, item ) => {
#                 if(attrsTail.some(i => i.key == item)){
#                     data[item.replace('_','-')] = userTailDataLayer[item];
#                 }
#                 return data
#             }, {});
#
#             var plaicementQs = Object.keys(dataLayer).map(function(item) {
#                return `;${item}=${dataLayer[item]}`
#             }); tag.language="JavaScript1.1"; tag.type="text/javascript";
#             tag.src = "https://t.dynad.net/script/?dc=5550021010;ord="+Date.now()+plaicementQs.join('')+";d-type="+dType+";click="
#
#             document.body.appendChild( tag );
#         })();
#   </script>
#   <script>
#    var _sf_async_config = _sf_async_config || {};
#         _sf_async_config.sections = 'Total UOL Conteúdo, Total - Estacoes, UOL - esporte';
#         _sf_async_config.authors = 'UOL';
#         (function() {
#             function loadChartbeat() {
#                 window._sf_endpt = (new Date()).getTime();
#                 var e = document.createElement('script');
#                 e.setAttribute('language', 'javascript');
#                 e.setAttribute('type', 'text/javascript');
#
#                 e.setAttribute('src', '//static.chartbeat.com/js/chartbeat_video.js');
#                 document.body.appendChild(e);
#             }
#
#             var _cbv = window._cbv || (window._cbv = []);
#             _cbv.push(['autoDetectYouTubeIframes']);
#
#             _asyncLoadScript('//c.jsuol.com.br/assets/?loadComponent=media&contentType=js&tpl=assets/dist/chartbeat/chartbeat.min&cache=202201201930')
#                 .then(loadChartbeat);
#         })();
#   </script>
#   <script>
#    if('serviceWorker' in navigator) {
#     window.addEventListener('load', function() {  navigator.serviceWorker.register('/esporte?loadComponent=pwa-sw&configPath=esporte/esporte.futebol.ultimas-noticias', {
#             scope: '/esporte'
#         }).then(function() {
#             console.log('[PGV3-SW] Successfully registered');
#         }).catch(function(registrationError) {
#             console.error('[PGV3-SW] Registration failed: ', registrationError);
#         });
#     });
# }
#   </script>
#  </body>
# </html>

# %% [markdown]
# # With the soup, you'll be able to walk through the HTML tree.
# ## Looking for tag h1

# %%
soup.find_all('h1')
# Out:
# [<h1 class=""> <span> <i class="col-sm-22 col-md-22 col-lg-22 custom-title" ia-title="">Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu  </i></span> </h1>]

# %%
soup.find_all('h1')[0]
# Out:
# <h1 class=""> <span> <i class="col-sm-22 col-md-22 col-lg-22 custom-title" ia-title="">Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu  </i></span> </h1>

# %%
headers = soup.find_all('h1')

# %%
headers
# Out:
# [<h1 class=""> <span> <i class="col-sm-22 col-md-22 col-lg-22 custom-title" ia-title="">Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu  </i></span> </h1>]

# %%
header = headers[0]

# %%
type(header)
# Out:
# bs4.element.Tag

# %%
header
# Out:
# <h1 class=""> <span> <i class="col-sm-22 col-md-22 col-lg-22 custom-title" ia-title="">Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu  </i></span> </h1>

# %%
header.text
# Out:
# '  Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu   '

# %%
type(header)
# Out:
# bs4.element.Tag

# %% [markdown]
# ## Looking for tag a

# %%
# Your code here!
tag_a = soup.find_all('a')

# %%
tag_a
# Out:
# [<a data-audience-click='{"component":"barra-uol","reference":"item-batepapo","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://batepapo.uol.com.br/">BATE-PAPO</a>,
#  <a data-audience-click='{"component":"barra-uol","reference":"item-uol-meunegocio","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://meunegocio.uol.com.br/?utm_source=uol.com.br&amp;utm_medium=barrauol&amp;utm_campaign=linkfixo-barrauol-umn&amp;utm_term=barrauol-umn&amp;utm_content=barrauol-umn">UOL MEU NEGÓCIO</a>,
#  <a data-audience-click='{"component":"barra-uol","reference":"item-cursos","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://www.passeidireto.com/?utm_source=uol.com.br&amp;utm_medium=barra-uol">Estude Online</a>,
#  <a data-audience-click='{"component":"barra-uol","reference":"item-pagseguro","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://clicklogger.rm.uol.com.br/?prd=32&amp;grp=src:210;chn:22;cpg:barrauol;creative:barrauol-pagseguro&amp;msr=Cliques%20de%20Origem:1&amp;oper=11&amp;redir=https://pagseguro.uol.com.br/">Pagseguro</a>,
#  <a data-audience-click='{"component":"barra-uol","reference":"item-pagbank","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://clicklogger.rm.uol.com.br/?prd=32&amp;grp=src:210;chn:22;cpg:barrauol;creative:barrauol-pagseguro&amp;msr=Cliques%20de%20Origem:1&amp;oper=11&amp;redir=https://pagseguro.uol.com.br/">PagBank</a>,
#  <a aria-label="UOL - O melhor conteúdo" data-audience-click='{"component":"barra-uol","reference":"logo-uol","position":"coluna-unica","area":"barra-uol"}' href="https://www.uol.com.br/"><picture> <img alt="UOL - O melhor conteúdo" class="logo logo-uol-svg" height="21" src="https://conteudo.imguol.com.br/c/_layout/v3/logoUOL2021/logo_completo_black.svg" width="60"/> </picture></a>,
#  <a aria-label="Esporte" data-audience-click='{"component":"barra-uol","reference":"ir-para-home-principal","position":"coluna-unica","area":"barra-uol"}' href="https://www.uol.com.br/esporte/"><span class="station">Esporte</span></a>,
#  <a data-audience-click='{"component":"barra-uol","reference":"item-sac","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://sac.uol.com.br/">sac</a>,
#  <a aria-label="UOL Mail - O email do UOL" class="email" data-audience-click='{"action":"clique","component":"barra-uol","reference":"email-checkin","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://mail.uol.com.br/checkin" id="uol-mail-link"><div class="mail-notification"></div> <svg><use xlink:href="#svg-mail"></use></svg> </a>,
#  <a data-audience-click='{"component":"barra-uol","reference":"botao-assine","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href=" https://assine.uol.com.br/?utm_source=uol.com.br&amp;utm_medium=barra-uol&amp;utm_campaign=barra-uol-assine&amp;utm_content=botao-assine-esporte" title="Assine">Assine</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-1","area":"produtos","position":"item-2"}' href="https://assine.uol.com.br/?utm_source=uol_home_menu-produtos&amp;utm_medium=linkfixo_menu_produtos-assine&amp;utm_campaign=uolhome-menu_produtos-assine" title="Produtos">Produtos  </a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":
a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"assine","position":"item-2"}' href="https://clicklogger.rm.uol.com.br/?prd=11&amp;grp=src:13;chn:539;cpg:linkfixo_menu;creative:assine-texto&amp;msr=Cliques%20de%20Origem:1&amp;oper=11&amp;redir=https://assine.uol.com.br/" title="Assine e tenha acesso ilimitado ao conteúdo exclusivo e a produtos UOL">Assine e tenha acesso ilimitado ao conteúdo exclusivo e a produtos UOL</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-1","area":"noticias","position":"item-4"}' href="https://noticias.uol.com.br/" title="Notícias">Notícias  </a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-2"}' href="https://noticias.uol.com.br/blogs-e-colunas/" title="Colunas">Colunas</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-3"}' href="https://noticias.uol.com.br/coronavirus/" title="Coronavírus">Coronavírus</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-4"}' href="https://noticias.uol.com.br/cotidiano/" title="Cotidiano">Cotidiano</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-5"}' href="https://educacao.uol.com.br/" title="Educação">Educação</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-7"}' href="https://noticias.uol.com.br/internacional/" title="Internacional">Internacional</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-9"}' href="https://noticias.uol.com.br/politica/" title="Política">Política</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-10"}' href="https://noticias.uol.com.br/saude/" title="Saúde">Saúde</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-11"}' href="https://noticias.uol.com.br/confere/" title="UOL Confere">UOL Confere</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-13"}' href="https://noticias.uol.com.br/newsletters/?pra-comecar-o-dia" title="Newsletters">Newsletters</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"noticias","position":"item-15"}' href="https://noticias.uol.com.br/ultimas/" title="Últimas notícias">Últimas notícias</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-chapeu-vitrine","area":"noticias","position":"titulo"}' href="https://noticias.uol.com.br/loterias" title="Loterias">Loterias<svg><use xlink:href="#svg-single-arrow-right"></use></svg></a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-1"}' href="https://noticias.uol.com.br/loterias/mega-sena/" title="Mega Sena">Mega Sena</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-2"}' href="https://noticias.uol.com.br/loterias/quina/" title="Quina">Quina</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-3"}' href="https://noticias.uol.com.br/loterias/lotofacil/" title="Lotofácil">Lotofácil</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-4"}' href="https://noticias.uol.com.br/loterias/lotomania/" title="Lotomania">Lotomania</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-5"}' href="https://noticias.uol.com.br/loterias/" title="Outras loterias">Outras loterias</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-chapeu-vitrine","area":"noticias","position":"titulo"}' href="https://www.uol.com.br/podcasts/" title="Podcasts">Podcasts<svg><use xlink:href="#svg-single-arrow-right"></use></svg></a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-1"}' href="https://noticias.uol.com.br/podcast/baixo-clero/" title="Baixo Clero">Baixo Clero</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-2"}' href="https://www.uol.com.br/esporte/podcast/posse-de-bola/" title="Posse de Bola">Posse de Bola</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-3"}' href="https://www.uol.com.br/universa/podcast/sexoterapia/" title="Sexoterapia">Sexoterapia</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-4"}' href="https://www.uol.com.br/play/splash/podcast/splash-ve-tv/" title="Splash Vê TV">Splash Vê TV</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"noticias","position":"item-5"}' href="https://noticias.uol.com.br/podcast/uol-entrevista/" title="UOL Entrevista">UOL Entrevista</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":
a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-1","area":"splash","position":"item-10"}' href="https://www.uol.com.br/splash/" title="Splash">Splash  </a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-1"}' href="https://www.uol.com.br/splash/bbb/" title="BBB">BBB</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-2"}' href="https://www.uol.com.br/splash/celebs/" title="Celebs">Celebs</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-3"}' href="https://www.uol.com.br/splash/filmes/" title="Filmes">Filmes</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-4"}' href="https://www.uol.com.br/splash/series/" title="Séries">Séries</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-5"}' href="https://www.uol.com.br/splash/musica/" title="Música">Música</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-6"}' href="https://www.uol.com.br/splash/televisao/" title="Televisão">Televisão</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-7"}' href="https://www.uol.com.br/splash/novelas/" title="Novelas">Novelas</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-8"}' href="https://www.uol.com.br/splash/reality-shows/" title="Reality shows">Reality shows</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-9"}' href="https://www.uol.com.br/splash/memelandia/" title="Memelândia">Memelândia</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-10"}' href="https://www.uol.com.br/splash/colunas/" title="Colunas">Colunas</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-11"}' href="https://www.uol.com.br/splash/videos/" title="Vídeos">Vídeos</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2","area":"splash","position":"item-12"}' href="https://www.uol.com.br/splash/ultimas/" title="Últimas">Últimas</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-chapeu-vitrine","area":"splash","position":"titulo"}' href="https://www.uol.com.br/splash/novelas/" title="Novelas">Novelas<svg><use xlink:href="#svg-single-arrow-right"></use></svg></a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"splash","position":"item-1"}' href="https://www.uol.com.br/splash/novelas/a-biblia/" title="A Bíblia">A Bíblia</a>,
#  <a data-audience-click='{"component":"menu","reference":"menu-topo-nivel-2-vitrine","area":"splash","position":"item-2"}' href="https://www.uol.com.br/splash/novelas/carinha-de-anjo/" title="Carinha de Anjo">Carinha de Anjo</a>,
# ...
#  <a data-audience-click='{"reference":"abrir-chamada","position":"chamada-2","component":"related-content-uol-item","mediaName":false,"source":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm","abTest4":"default","abTest6":"chartbeat","tags":"15308,12810,79585,16026,16130"}' href="https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/por-que-o-flamengo-puxa-freio-de-mao-e-nao-repete-agressividade-no-mercado.htm"> <figure class="thumb-image col-xs-4 col-sm-24"><div class="thumb-layer"> <img alt="" data-crop='{"xs":"150x112","sm":"300x225"}' data-src="https://conteudo.imguol.com.br/c/esporte/a5/2022/01/21/gabigol-e-arrascaeta-sao-apresentados-para-a-torcida-do-flamengo-no-maracana-1642795907933_v2_900x506.jpg" height="225" src="https://conteudo.imguol.com.br/c/geral/3d/2021/05/25/placeholder-image-1621949831997_v2_300x225.jpg" width="300"/> </div></figure> <div class="thumb-caption col-xs-6 col-sm-24"> <h3 class="thumb-title"> Por que o Flamengo puxa freio de mão e não repete agressividade no mercado  </h3> </div> </a>,
#  <a data-audience-click='{"reference":"abrir-chamada","position":"chamada-3","component":"related-content-uol-item","mediaName":false,"source":"https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/em-1995-decisao-na-base-entre-palmeiras-x-sp-terminou-em-morte-no-pacaembu.htm","abTest4":"default","abTest6":"chartbeat","tags":"15308,12810,79585,16026,16130"}' href="https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/santos-dracena-e-agente-detalham-renovacao-marcante-de-marcos-leonardo.htm"> <figure class="thumb-image col-xs-4 col-sm-24"><div class="thumb-layer"> <img alt="" data-crop='{"xs":"150x112","sm":"300x225"}' data-src="https://conteudo.imguol.com.br/c/esporte/13/2021/04/14/marcos-leonardo-em-santos-2-x-2-san-lorenzo-pela-partida-de-volta-da-ultima-fase-da-pre-libertadores-2021-no-estadio-mane-garrincha-13042021-1618417357135_v2_900x506.jpg" height="225" src="https://conteudo.imguol.com.br/c/geral/3d/2021/05/25/placeholder-image-1621949831997_v2_300x225.jpg" width="300"/> </div></figure> <div class="thumb-caption col-xs-6 col-sm-24"> <h3 class="thumb-title"> Santos: Dracena e agente detalham 'renovação marcante' de Marcos Leonardo  </h3> </div> </a>,
#  <a ng-href="{{comments.info.url}}" target="_blank">{{comments.info.url}}</a>,
#  <a class="alert-close"><i class="icon-close-2"></i></a>,
#  <a class="sign-up-link" href="https://cadastro.uol.com.br/indexb.html?skinPath=uol&amp;skin=cadastrounificado%2Fvisitor%2Fpf&amp;promochild=PROMOPAYWALL&amp;eos=yes&amp;utm_source=Home%20UOL&amp;utm_medium=midia%20interna&amp;utm_campaign=comentarios-paywall&amp;utm_term=comentarios-assinatura-paywall&amp;utm_content=convers%C3%B5es-comentarios-paywall" target="_blank">Assine já</a>,
#  <a class="contauol-login">faça seu login</a>,
#  <a class="comment-report divisor" ng-click="comments.logout()" target="_blank"><span class="logout-btn">sair</span></a>,
#  <a data-audience-click='{"reference":"termos-de-uso","component":"comments"}' ng-href="http://regras.uol.com.br/index.html?apiCadLink=...#ap">Leia os termos de uso</a>,
#  <a class="comment-like" data-category="like" ng-class="{'liked': comment.likedByMe, 'btn-like': user.isLogged, 'contauol-login': !user.isLogged}" ng-click="!comment.likedByMe &amp;&amp; comments.like(comment, $event, 'comment')" ng-href=""><i class="icon-liked"></i><span ng-bind="comment.like"></span></a>,
#  <a class="comment-isReply reply-action divisor" data-category="reply" ng-class="{'contauol-login': !user.isLogged}" ng-click="(comment.replyit = true) &amp;&amp; comments.replyit()" ng-href="" ng-if="!comments.isClosed"><i class="icon-answer"></i>Responder</a>,
#  <a class="comment-replies divisor" ng-click="comments.openReplies(comment)" ng-href="" ng-if="comment.hasReplies">Respostas ({{ comment.reply_count }}) <i ng-class="{'icon-single-arrow-down':!comment.repliesOpened, 'icon-single-arrow-up':comment.repliesOpened}"></i></a>,
#  <a class="comment-report divisor delete-action" ng-click="comments.del(comment)" ng-href="" ng-if="user.isLogged &amp;&amp; comment.isMyMessage"><i class="icon-delete"></i> <span class="hide visible-sm-inline-block visible-md-inline-block visible-lg-inline-block">Excluir</span></a>,
#  <a class="comment-report divisor" ng-click="comments.report('comment', comment.url)" ng-href="{{ comment.url }}" ng-if="!comment.isMyMessage || !user.isLogged" ng-init="comment.url = 'http://n.comentarios.uol.com.br/denounce?subject_id=' + comment.subject_id + '&amp;comment_id=' + comment.id + '&amp;author_cod_profile_hash=' + comment.cod_profile_hash + '&amp;url='+comments.info.url+'#comentarios'" target="_blank"><i class="icon-flag"></i><span class="hide visible-sm-inline-block visible-md-inline-block visible-lg-inline-block">Denunciar</span></a>,
#  <a class="comment-like" ng-class="{'contauol-login': !user.isLogged, 'liked': reply.likedByMe, 'btn-like': user.isLogged}" ng-click="!reply.likedByMe &amp;&amp; comments.like(reply, $event, 'reply')" ng-href=""><i class="icon-liked"></i><span ng-bind="reply.like"></span></a>,
#  <a class="comment-report divisor delete-action" ng-click="comments.del(comment,reply)" ng-href="" ng-if="user.isLogged &amp;&amp; reply.isMyMessage"><i class="icon-delete"></i> <span class="hide visible-sm-inline-block visible-md-inline-block visible-lg-inline-block">Excluir</span></a>,
#  <a class="comment-report divisor" ng-click="comments.report('reply')" ng-href="http://n.comentarios.uol.com.br/denounce?subject_id={{reply.subject_id}}&amp;comment_id={{reply.id}}&amp;author_cod_profile_hash={{reply.cod_profile_hash}}&amp;url={{comments.info.url}}#comentarios" ng-if="!reply.isMyMessage || !user.isLogged" target="_blank"><i class="icon-flag"></i><span class="hide visible-sm-inline-block visible-md-inline-block visible-lg-inline-block">Denunciar</span></a>,
#  <a href="https://sobreuol.noticias.uol.com.br/normas-de-seguranca-e-privacidade.html">Segurança e privacidade</a>,
#  <a data-audience-click='{"reference":"abrir-chamada","component":"results-index-click","mediaName":"Home"}' href="https://www.uol.com.br/esporte/futebol/ultimas-noticias/lancepress/2022/01/22/arsenal-x-burnley-onde-assistir-horario-e-provaveis-escalacoes-do-jogo-do-campeonato-ingles.htm"> <div class="thumb-caption no-gutter col-xs-8 col-sm-24"> <h3 class="thumb-title title-xsmall title-lg-small">Arsenal x Burnley: onde assistir, horário e prováveis escalações do jogo do Campeonato Inglês</h3> <p class="thumb-description description-small description-lg-large">Depois de ser eliminado da Copa da Liga Inglesa, o Arsenal volta a virar a chave para a Premier League. Isso...</p> <time class="thumb-date">22/01/2022 10h48</time> </div></a>,
#  <a data-audience-click='{"reference":"abrir-chamada","component":"results-index-click","mediaName":"Home"}' href="https://www.uol.com.br/esporte/futebol/ultimas-noticias/lancepress/2022/01/22/ferj-altera-horario-do-classico-entre-flamengo-e-fluminense-pelo-carioca.htm"> <div class="thumb-caption no-gutter col-xs-8 col-sm-24"> <h3 class="thumb-title title-xsmall title-lg-small">Ferj altera horário do clássico entre Flamengo e Fluminense, pelo Carioca</h3> <p class="thumb-description description-small description-lg-large">O primeiro Fla-Flu do ano já tem data marcada: será no dia 6 de fevereiro, pela quarta rodada da Taça Guanabara. A </p> <time class="thumb-date">22/01/2022 10h43</time> </div></a>,
#  <a data-audience-click='{"reference":"abrir-chamada","component":"results-index-click","mediaName":"Home"}' href="https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22
/placeholder-image-1621949831997_v2_300x225.jpg" width="300"/></div> <i class="thumb-icon icone-small icone-news"> <svg class="svg-news"><use xlink:href="#svg-news"></use></svg> </i> </figure> <div class="thumb-caption col-xs-5 col-sm-18 no-gutter"> <h3 class="thumb-title title-xsmall title-lg-small">Ancelotti crava permanência de Hazard no Real Madrid</h3> <time class="thumb-date">22/01/2022 09h23</time> </div></a>,
#  <a data-audience-click='{"reference":"abrir-chamada","component":"results-index-click","mediaName":"Home"}' href="https://www.uol.com.br/esporte/ultimas-noticias/enm/2022/01/22/nfl-2021---divisional-round.htm"> <div class="thumb-caption no-gutter col-xs-8 col-sm-24"> <h3 class="thumb-title title-xsmall title-lg-small">NFL 2021 - Divisional Round</h3> <p class="thumb-description description-small description-lg-large">Chegamos ao fim de semana mais emocionante da temporada da NFL. Oito times disputando quatro vagas às finais de...</p> <time class="thumb-date">22/01/2022 09h06</time> </div></a>]

# %%
tag_a[0]
# Out:
# <a data-audience-click='{"component":"barra-uol","reference":"item-batepapo","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://batepapo.uol.com.br/">BATE-PAPO</a>

# %%
first_link = tag_a[0]

# %%
first_link
# Out:
# <a data-audience-click='{"component":"barra-uol","reference":"item-batepapo","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}' href="https://batepapo.uol.com.br/">BATE-PAPO</a>

# %%
first_link.text
# Out:
# 'BATE-PAPO'

# %%
first_link.attrs
# Out:
# {'href': 'https://batepapo.uol.com.br/',
#  'data-audience-click': '{"component":"barra-uol","reference":"item-batepapo","position":"coluna-unica","area":"barra-uol","mediaName":"Home"}'}

# %%
type(first_link)
# Out:
# bs4.element.Tag

# %%
first_link['href']
# Out:
# 'https://batepapo.uol.com.br/'

# %%
[tag.text for tag in tag_a]
# Out:
# ['BATE-PAPO',
#  'UOL MEU NEGÓCIO',
#  'Estude Online',
#  'Pagseguro',
#  'PagBank',
#  '  ',
#  'Esporte',
#  'sac',
#  '  ',
#  'Assine',
#  'Produtos  ',
#  'Conteúdo Exclusivo',
#  'UOL Mail',
#  'UOL Play',
#  'NBA',
#  'TNT Sports',
#  'Nordeste FC',
#  'Bate-papo UOL',
#  'Universinho',
#  'UOL Loja de Jogos',
#  'UOL Leia+',
#  'UOL Segurança Digital',
#  'UOL Família Protegida',
#  'UOL Assistência Técnica',
#  'UOL Resolve',
#  'UOL WI-FI',
#  'UOL Sexo',
#  'Clube UOL',
#  'UOL ads',
#  'UOL Host',
#  'UOL Meu Negócio',
#  'UOL Afiliados',
#  'Assine UOL',
#  '4003-6118 capitais',
#  '0800 703 3000 demais localidades',
#  'Assine e tenha acesso ilimitado ao conteúdo exclusivo e a produtos UOL',
#  'Notícias  ',
#  'Colunas',
#  'Coronavírus',
#  'Cotidiano',
#  'Educação',
#  'Internacional',
#  'Política',
#  'Saúde',
#  'UOL Confere',
#  'Newsletters',
#  'Últimas notícias',
#  'Loterias',
#  'Mega Sena',
#  'Quina',
#  'Lotofácil',
#  'Lotomania',
#  'Outras loterias',
#  'Podcasts',
#  'Baixo Clero',
#  'Posse de Bola',
#  'Sexoterapia',
#  'Splash Vê TV',
#  'UOL Entrevista',
#  'UOL Investiga',
#  'UOL Líderes',
#  'Mídia e Marketing',
#  'Vídeos',
#  'Fora de Série',
#  'Retrato',
#  'MOV.doc',
#  'Mais vídeos',
#  'Carros  ',
#  'Avaliação',
#  'Meu Carro',
#  'Mobilidade',
#  'Motos',
#  'Lançamentos e Mercado',
#  'Segredos Automotivos',
#  'Tabela Fipe',
#  'Vídeos',
#  'Últimas notícias',
#  'Avaliação UOL Carros',
#  'Duelo',
#  'Meu Carro, Minha Vida',
#  'PitsTOP',
#  'Deu ruim',
#  'Séloko Tio!',
#  'Os carros de...',
#  'Economia  ',
#  'Alta Renda',
#  'Cotações',
#  'Investimentos',
#  'Empreendedorismo',
#  'Empregos',
#  'Finanças Pessoais',
#  'Guia de Compras',
#  'Guia de Economia',
#  'Imposto de Renda',
#  'Líderes',
#  'Lugares Incríveis para Trabalhar',
#  'Mídia e Marketing',
#  'Reforma da Previdência',
#  'UOL Economia Explica',
#  'Colunas',
#  'Newsletters',
#  'Vídeos',
#  'Últimas notícias',
#  'Cotações',
#  'Dólar',
#  'Euro',
#  'Outras moedas',
#  'Bolsa de Valores',
#  'Imposto de Renda',
#  'Últimas notícias',
#  'Dúvidas do IR 2021',
#  'Download do programa',
#  'Investimentos',
#  'PagBank',
#  'Levante',
#  'Escola de Finanças',
#  'Guia do Investidor UOL',
#  'Papo com Especialista',
#  'Pensando em Dinheiro',
#  'Perfil de Investidor',
#  'Folha  ',
#  'Esporte  ',
#  'Futebol',
#  'Futebol Muleke',
#  'Jogos de Hoje',
#  'Mercado da Bola',
#  'Mundial de Clubes',
#  'Copa São Paulo',
#  'Paulistão',
#  'Carioca',
#  'Liga dos Campeões',
#  'Eliminatórias Sul-Americanas',
#  'Mais campeonatos',
#  'Fórmula 1',
#  'MMA',
#  'Basquete',
#  'Vôlei',
#  'Tênis',
#  'Reportagens especiais',
#  'Minha História',
#  'Colunas',
#  'Vídeos',
#  'Últimas notícias',
#  'América-MG',
#  'Athletico',
#  'Atletico-MG',
#  'Atlético-GO',
#  'Avaí',
#  'Botafogo',
#  'Ceará',
#  'Corinthians',
#  'Coritiba',
#  'Cruzeiro',
#  'Cuiabá',
#  'Flamengo',
#  'Fluminense',
#  'Fortaleza',
#  'Goiás',
#  'Grêmio',
#  'Internacional',
#  'Juventude',
#  'Palmeiras',
#  'Red Bull Bragantino',
#  'Santos',
#  'São Paulo',
#  'Vasco',
#  'Fim de Papo',
#  'Podcast UOL Corinthians',
#  'Podcast UOL Flamengo',
#  'Podcast UOL Palmeiras',
#  'Podcast UOL São Paulo',
#  'Brasileirão',
#  'Champions League',
#  'Copa do Nordeste',
#  'Campeonato Italiano',
#  'Nations League',
#  'NBA',
#  'Splash  ',
#  'BBB',
#  'Celebs',
#  'Filmes',
#  'Séries',
#  'Música',
#  'Televisão',
#  'Novelas',
#  'Reality shows',
#  'Memelândia',
#  'Colunas',
#  'Vídeos',
#  'Últimas',
#  'Novelas',
#  'A Bíblia',
#  'Carinha de Anjo',
#  'Malhação Sonhos',
#  'Nos Tempos do Imperador',
#  'Quanto Mais Vida Melhor',
#  'Um Lugar ao Sol',
#  'OtaLab',
#  'Poucas',
#  'Meteoro Por Trás da Cena',
#  'Me Segue',
#  'UOL Play',
#  'UOL Leia+ Banca',
#  'UOL Leia+ Livros',
#  'Loja de jogos',
#  'Sexo',
#  'Universa  ',
#  'Transforma',
#  'Inspira',
#  'Pausa',
#  'Horóscopo',
#  'Newsletters',
#  'Colunas',
#  'Vídeos',
#  'Últimas notícias',
#  'Transforma',
#  'Autoestima',
#  'Direitos da mulher',
#  'Diversidade',
#  'Política',
#  'Universa Talks',
#  'Vidas Negras',
#  'Violência contra mulher',
#  'Inspira',
#  'Prêmio Inspiradoras',
#  'A poderosa',
#  'Beleza',
#  'Carreiras e finanças',
#  'Mães e Filhos',
#  'Moda',
#  'Relacionamentos',
#  'Sexo',
#  'Universa Ensina',
#  'Pausa',
#  'Fofuras',
#  'Retratos',
#  'Sem filtro',
#  'Stalkeadas',
#  'Universa experimenta',
#  'VivaBem  ',
#  'Coronavírus',
#  'Alimentação',
#  'Equilíbrio',
#  'Longevidade',
#  'Movimento',
#  'Saúde',
#  'Newsletters',
#  'Colunas',
#  'Vídeos',
#  'Últimas notícias',
#  'Tilt  ',
#  'Fique por dentro',
#  'Tec a seu favor',
#  'Novos hábitos',
#  'Papo cabeça',
#  'Ficção científica?',
#  'Colunas',
#  'Vídeos',
#  'Últimas',
#  'Fique por dentro',
#  'Lançamentos',
#  'WhatsApp',
#  'Redes Sociais',
#  'Apps',
#  'Isso é Golpe!',
#  'Ciência',
#  'Astronomia',
#  'Negócios',
#  'Tec a seu favor',
#  'Teste de Velocidade da Internet',
#  '#ficadica',
#  'Dicas matadoras',
#  'A tecnologia por trás',
#  'Review',
#  'Comparativo',
#  'No Brasil não tem',
#  'Papo cabeça',
#  'Fala, chefia',
#  'Como seria se...',
#  'Podcast Deu Tilt',
#  'Ficção científica?',
#  'O que Steve diria',
#  'Isso é tão Black Mirror',
#  'Ecoa  ',
#  'Pessoas',
#  'Soluções',
#  'Na prática',
#  'Plural',
#  'Podcasts',
#  'Reportagens especiais',
#  'Colunas',
#  'Últimas',
#  'Pessoas',
#  'Causadores',
#  'Fizeram história',
#  'Soluções',
#  'Empresas que mudam',
#  'Iniciativas que inspiram',
#  'Na prática',
#  'Sim ou não?',
#  'Como fazer',
#  'Destretando',
#  'Final feliz',
#  'MOV  ',
#  'Canal UOL',
#  'Entrevistas',
#  'MOV.doc',
#  'Programas',
#  'Blog UOL Play',
#  'Band',
#  'Caras',
#  'History',
#  'RedeTV!',
#  'TV Cultura',
#  'Nossa  ',
#  'Casa',
#  'Cozinha',
#  'Viagem',
#  'Moda',
#  'Bichos',
#  'Temporadas',
#  'UOL no Verão',
#  'Reportagens Especiais',
#  'Colunas',
#  'Últimas',
#  'Casa',
#  'Feito à mão',
#  'Meu apê',
#  'Microespaços',
#  'Plantados',
#  'Tapa na casa',
#  'Casa de estimação',
#  'Cozinha',
#  'Receitas',
#  'Ao ponto',
#  'Eu mereço',
#  'Instachef',
#  'Tim-tim',
#  'Receita de família',
#  'Gastronobásico',
#  'Marinando (na quarentena)',
#  'Viagem',
#  '12 horas',
#  'Fora da rota',
#  'Viajantes',
#  'Retina',
#  'Na Estrada',
#  'Moda',
#  'Meu estilo',
#  'Moodboard',
#  'Essa roupa tem história',
#  'Temporadas',
#  'Japão',
#  'Brasileiro',
#  'Festejo',
#  'Entornos',
#  'TAB  ',
#  'Especiais',
#  'Perfis',
#  'Nas Ruas',
#  'Tendência',
#  'Colunas',
#  'Últimas',
#  'Assista',
#  'Newsletter',
#  'Start  ',
#  'Reviews',
#  'eSports',
#  'Guias',
#  'Curiosidades',
#  'Vídeos',
#  'Colunas',
#  'Últimas notícias',
#  '{{jogo.competicao}}{{jogo.time1.sigla}}{{jogo.placar1}}({{jogo.penalti1}}{{jogo.penalti2}}){{jogo.placar2}}{{jogo.time2.sigla}}',
#  '{{jogo.competicao}}{{jogo.time1.sigla}}{{jogo.placar1}}({{jogo.penalti1}}{{jogo.penalti2}}){{jogo.placar2}}{{jogo.time2.sigla}}',
#  '{{jogo.competicao}}{{jogo.time1.sigla}}{{jogo.placar1}}({{jogo.penalti1}}{{jogo.penalti2}}){{jogo.placar2}}{{jogo.time2.sigla}}',
#  'Ver mais jogos',
#  ' Topo',
#  'Futebol',
#  ' Times',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Futebol ',
#  'Futebol',
#  "      Lentidão e salário 'europeu' de Diego Costa explicam o não do Corinthians    ",
#  '      Por que o Flamengo puxa freio de mão e não repete agressividade no mercado    ',
#  "      Santos: Dracena e agente detalham 'renovação marcante' de Marcos Leonardo    ",
#  '{{comments.info.url}}',
#  '',
#  'Assine já',
#  'faça seu login',
#  'sair',
#  'Leia os termos de uso',
#  '',
#  'Responder',
#  'Respostas ({{ comment.reply_count }}) ',
#  ' Excluir',
#  'Denunciar',
#  '',
#  ' Excluir',
#  'Denunciar',
#  '',
#  '  Arsenal x Burnley: onde assistir, horário e prováveis escalações do jogo do Campeonato Inglês Depois de ser eliminado da Copa da Liga Inglesa, o Arsenal volta a virar a chave para a Premier League. Isso... 22/01/2022 10h48 ',
#  '  Ferj altera horário do clássico entre Flamengo e Fluminense, pelo Carioca O primeiro Fla-Flu do ano já tem data marcada: será no dia 6 de fevereiro, pela quarta rodada da Taça Guanabara. A  22/01/2022 10h43 ',
#  "        CR7 fala sobre momento em que se apaixonou por Georgina: 'Foi um clique' 22/01/2022 10h42 ",
#  "  São Paulo parabeniza Rogério Ceni: 'Nasceu para conquistar o mundo' Este sábado é de comemorações para Rogério Ceni. Ídolo e atual técnico do São Paulo, o 'M1to' completa 49 anos re... 22/01/2022 10h35 ",
#  '  Que golaço! Na web, Gabigol promete encontro especial com torcedor do Flamengo Artilheiro do Flamengo e constantemente exaltado por torcedores do clube carioca, o atacante Gabigol marcou mais... 22/01/2022 10h05 ',
#  '        Morre Gianni Di Marzio, o homem que descobriu Maradona para o Napoli 22/01/2022 09h57 ',
#  '  Após votação nas redes, Íbis negocia para tirar do papel jogo contra clube inglês na Europa e estipula um prazo A enquete com cara de brincadeira que rolou na internet, promovida pelo Sheffield Football Club, reconhecido pela... 22/01/2022 09h52 ',
#  '        Real Madrid é mais um gigante europeu de olho em Endrick, segundo jornal 22/01/2022 09h45 ',
#  '        Milton: O Timão está passando vergonha na busca por um camisa 9 22/01/2022 09h42 ',
#  '        Ancelotti crava permanência de Hazard no Real Madrid 22/01/2022 09h23 ',
#  '  NFL 2021 - Divisional Round Chegamos ao fim de semana mais emocionante da temporada da NFL. Oito times disputando quatro vagas às finais de... 22/01/2022 09h06 ']

# %%
[tag['href'] for tag in tag_a]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-21cb3419be46> in <module>
# ----> 1 [tag['href'] for tag in tag_a]
#
# <ipython-input-44-21cb3419be46> in <listcomp>(.0)
# ----> 1 [tag['href'] for tag in tag_a]
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1404         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1405         and throws an exception if it's not there."""
# -> 1406         return self.attrs[key]
#    1407
#    1408     def __iter__(self):
#
# KeyError: 'href'

# %%
results = []
for tag in tag_a:
    try:
        results.append((tag.text, tag['href']))
    except KeyError:
        results.append((tag.text,'NA'))

# %%
results
# Out:
# [('BATE-PAPO', 'https://batepapo.uol.com.br/'),
#  ('UOL MEU NEGÓCIO',
#   'https://meunegocio.uol.com.br/?utm_source=uol.com.br&utm_medium=barrauol&utm_campaign=linkfixo-barrauol-umn&utm_term=barrauol-umn&utm_content=barrauol-umn'),
#  ('Estude Online',
#   'https://www.passeidireto.com/?utm_source=uol.com.br&utm_medium=barra-uol'),
#  ('Pagseguro',
#   'https://clicklogger.rm.uol.com.br/?prd=32&grp=src:210;chn:22;cpg:barrauol;creative:barrauol-pagseguro&msr=Cliques%20de%20Origem:1&oper=11&redir=https://pagseguro.uol.com.br/'),
#  ('PagBank',
#   'https://clicklogger.rm.uol.com.br/?prd=32&grp=src:210;chn:22;cpg:barrauol;creative:barrauol-pagseguro&msr=Cliques%20de%20Origem:1&oper=11&redir=https://pagseguro.uol.com.br/'),
#  ('  ', 'https://www.uol.com.br/'),
#  ('Esporte', 'https://www.uol.com.br/esporte/'),
#  ('sac', 'https://sac.uol.com.br/'),
#  ('  ', 'https://mail.uol.com.br/checkin'),
#  ('Assine',
#   ' https://assine.uol.com.br/?utm_source=uol.com.br&utm_medium=barra-uol&utm_campaign=barra-uol-assine&utm_content=botao-assine-esporte'),
#  ('Produtos  ',
#   'https://assine.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_menu_produtos-assine&utm_campaign=uolhome-menu_produtos-assine'),
#  ('Conteúdo Exclusivo',
#   'https://assine.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-conteudo&utm_campaign=uolhome-submenu_produtos-conteudo&utm_content=assine'),
#  ('UOL Mail',
#   'https://email.uol.com.br/bem-vindo?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-mail&utm_campaign=uolhome-submenu_produtos-mail'),
#  ('UOL Play',
#   'https://play.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-play&utm_campaign=uolhome-submenu_produtos-play'),
#  ('NBA',
#   'https://esporteclube.uol.com.br/nba?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-uec-nba&utm_campaign=uolhome-submenu_produtos-uec-nba'),
#  ('TNT Sports',
#   'https://esporteclube.uol.com.br/estadio-tnt-sports?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-uec-tnt&utm_campaign=uolhome-submenu_produtos-uec-tnt'),
#  ('Nordeste FC',
#   'https://esporteclube.uol.com.br/nordestefc?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-uec-nfc&utm_campaign=uolhome-submenu_produtos-uec-nfc'),
#  ('Bate-papo UOL',
#   'https://batepapo.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-bp&utm_campaign=uolhome-submenu_produtos-bp'),
#  ('Universinho',
#   'https://universinho.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-universinho&utm_campaign=uolhome-submenu_produtos-universinho'),
#  ('UOL Loja de Jogos',
#   'https://jogos.uol.com.br/loja/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos_loja-de-jogos&utm_campaign=uolhome_submenu_produtos_loja-de-jogos'),
#  ('UOL Leia+',
#   'https://leiamais.uol.com.br?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-leiamais&utm_campaign=uolhome-submenu_produtos-leiamais'),
#  ('UOL Segurança Digital',
#   'https://seguranca.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-seguranca&utm_campaign=uolhome-submenu_produtos-seguranca'),
#  ('UOL Família Protegida',
#   'https://familiaprotegida.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-familiaprotegida&utm_campaign=uolhome-submenu_produtos-familiaprotegida'),
#  ('UOL Assistência Técnica',
#   'https://assistenciatecnica.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-at&utm_campaign=uolhome-submenu_produtos-at'),
#  ('UOL Resolve',
#   'https://resolve.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-resolve&utm_campaign=uolhome-submenu_produtos-resolve'),
#  ('UOL WI-FI',
#   'https://wifi.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-wifi&utm_campaign=uolhome-submenu_produtos-wifi'),
#  ('UOL Sexo',
#   'https://sexo.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-sexo&utm_campaign=uolhome-submenu_produtos-sexo'),
#  ('Clube UOL',
#   'https://clube.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=link-fixo&utm_campaign=linkfixo_menu_produtos&utm_content=clube-uol'),
#  ('UOL ads',
#   'https://ads.uol.com.br/login?utm_source=uol.com.br&utm_medium=link-fixo-menu%20-produtos&utm_campaign=link-fixo-uol%20ads&utm_term=link-fixo-menu-produtos&utm_content=link-fixo-uol-ads'),
#  ('UOL Host',
#   'https://clicklogger.rm.uol.com.br/?prd=16&grp=src:13;chn:539;cpg:linkfixo_menu;creative:assine-host&msr=Cliques%20de%20Origem:1&oper=11&redir=https://uolhost.uol.com.br/'),
#  ('UOL Meu Negócio',
#   'https://meunegocio.uol.com.br?utm_medium=uol.com.br&utm_source=interna&utm_campaign=menu_uol&utm_content=link_fixo_umn&utm_term=menu_topo'),
#  ('UOL Afiliados',
#   'http://afiliados.uol.com.br?utm_source=uol-home-menu_produtos-afiliados&utm_medium=linkfixo-menu-produtos&utm_campaign=site-afiliados'),
#  ('Assine UOL',
#   'https://assine.uol.com.br/?utm_source=uol_home_menu-produtos&utm_medium=linkfixo_submenu_produtos-cta-assine&utm_campaign=uolhome-submenu_produtos-cta-assine'),
#  ('4003-6118 capitais',
#   'https://clicklogger.rm.uol.com.br/?prd=11&grp=src:13;chn:539;cpg:linkfixo_menu;creative:assine-telefones&msr=Cliques%20de%20Origem:1&oper=11&redir=https://assine.uol.com.br/'),
#  ('0800 703 3000 demais localidades',
#   'https://clicklogger.rm.uol.com.br/?prd=11&grp=src:13;chn:539;cpg:linkfixo_menu;creative:assine-telefones&msr=Cliques%20de%20Origem:1&oper=11&redir=https://assine.uol.com.br/'),
#  ('Assine e tenha acesso ilimitado ao conteúdo exclusivo e a produtos UOL',
#   'https://clicklogger.rm.uol.com.br/?prd=11&grp=src:13;chn:539;cpg:linkfixo_menu;creative:assine-texto&msr=Cliques%20de%20Origem:1&oper=11&redir=https://assine.uol.com.br/'),
#  ('Notícias  ', 'https://noticias.uol.com.br/'),
#  ('Colunas', 'https://noticias.uol.com.br/blogs-e-colunas/'),
#  ('Coronavírus', 'https://noticias.uol.com.br/coronavirus/'),
#  ('Cotidiano', 'https://noticias.uol.com.br/cotidiano/'),
#  ('Educação', 'https://educacao.uol.com.br/'),
#  ('Internacional', 'https://noticias.uol.com.br/internacional/'),
#  ('Política', 'https://noticias.uol.com.br/politica/'),
#  ('Saúde', 'https://noticias.uol.com.br/saude/'),
#  ('UOL Confere', 'https://noticias.uol.com.br/confere/'),
#  ('Newsletters', 'https://noticias.uol.com.br/newsletters/?pra-comecar-o-dia'),
#  ('Últimas notícias', 'https://noticias.uol.com.br/ultimas/'),
#  ('Loterias', 'https://noticias.uol.com.br/loterias'),
#  ('Mega Sena', 'https://noticias.uol.com.br/loterias/mega-sena/'),
#  ('Quina', 'https://noticias.uol.com.br/loterias/quina/'),
#  ('Lotofácil', 'https://noticias.uol.com.br/loterias/lotofacil/'),
#  ('Lotomania', 'https://noticias.uol.com.br/loterias/lotomania/'),
#  ('Outras loterias', 'https://noticias.uol.com.br/loterias/'),
#  ('Podcasts', 'https://www.uol.com.br/podcasts/'),
#  ('Baixo Clero', 'https://noticias.uol.com.br/podcast/baixo-clero/'),
#  ('Posse de Bola', 'https://www.uol.com.br/esporte/podcast/posse-de-bola/'),
#  ('Sexoterapia', 'https://www.uol.com.br/universa/podcast/sexoterapia/'),
#  ('Splash Vê TV', 'https://www.uol.com.br/play/splash/podcast/splash-ve-tv/'),
#  ('UOL Entrevista', 'https://noticias.uol.com.br/podcast/uol-entrevista/'),
#  ('UOL Investiga', 'https://noticias.uol.com.br/podcast/uol-investiga/'),
#  ('UOL Líderes', 'https://economia.uol.com.br/podcast/uol-lideres/'),
#  ('Mídia e Marketing',
#   'https://economia.uol.com.br/podcast/midia-e-marketing/'),
#  ('Vídeos', 'https://noticias.uol.com.br/videos/'),
#  ('Fora de Série', 'https://uol.com.br/play/fora-de-serie/'),
#  ('Retrato', 'https://uol.com.br/play/retrato/'),
#  ('MOV.doc', 'https://www.uol.com.br/play/mov-doc/'),
#  ('Mais vídeos', 'https://noticias.uol.com.br/videos/'),
#  ('Carros  ', 'https://www.uol.com.br/carros/'),
#  ('Avaliação', 'https://www.uol.com.br/carros/avaliacao/'),
#  ('Meu Carro', 'https://carros.uol.com.br/meu-carro/'),
#  ('Mobilidade', 'https://www.uol.com.br/carros/mobilidade/'),
#  ('Motos', 'https://www.uol.com.br/carros/motos/'),
#  ('Lançamentos e Mercado',
#   'https://www.uol.com.br/carros/lancamentos-e-mercado/'),
#  ('Segredos Automotivos',
#   'https://www.uol.com.br/carros/segredos-automotivos/'),
#  ('Tabela Fipe', 'https://www.uol.com.br/carros/tabela-fipe/'),
#  ('Vídeos', 'https://www.uol.com.br/carros/videos/'),
#  ('Últimas notícias', 'https://www.uol.com.br/carros/ultimas/'),
#  ('Avaliação UOL Carros', 'https://carros.uol.com.br/avaliacao/videos/'),
#  ('Duelo', 'https://www.uol.com.br/carros/duelo/'),
#  ('Meu Carro, Minha Vida',
#   'https://www.uol.com.br/carros/meu-carro-minha-vida/'),
#  ('PitsTOP', 'https://www.uol.com.br/carros/pitstop/'),
#  ('Deu ruim', 'https://www.uol.com.br/carros/deu-ruim/'),
#  ('Séloko Tio!', 'https://www.uol.com.br/carros/seloko-tio/'),
#  ('Os carros de...', 'https://www.uol.com.br/carros/os-carros-de/'),
#  ('Economia  ', 'https://economia.uol.com.br/'),
#  ('Alta Renda', 'https://economia.uol.com.br/alta-renda/'),
#  ('Cotações', 'https://economia.uol.com.br/cotacoes/'),
#  ('Investimentos',
#   'https://economia.uol.com.br/mais/?utm_source=uol_home_menu-economia&utm_medium=link-fixo&utm_campaign=linkfixo_menu_economia&utm_content=economia_mais'),
#  ('Empreendedorismo', 'https://economia.uol.com.br/empreendedorismo/'),
#  ('Empregos', 'https://economia.uol.com.br/empregos-e-carreiras/'),
#  ('Finanças Pessoais', 'https://economia.uol.com.br/financas-pessoais/'),
#  ('Guia de Compras', 'https://economia.uol.com.br/guia-de-compras/'),
#  ('Guia de Economia', 'https://economia.uol.com.br/guia-de-economia/'),
#  ('Imposto de Renda', 'https://economia.uol.com.br/imposto-de-renda/'),
#  ('Perfil de Investidor',
#   'https://economia.uol.com.br/quiz/perfil-investidor/?utm_source=uol_home_menu-economia&utm_medium=link-fixo&utm_campaign=linkfixo_menu_economia&utm_term=uol-home-menu-economia-perfil_investidor&utm_content=economia_mais-perfil_investidor'),
#  ('Folha  ', 'https://www.folha.uol.com.br/'),
#  ('Esporte  ', 'https://www.uol.com.br/esporte/'),
#  ('Futebol', 'https://www.uol.com.br/esporte/futebol/'),
#  ('Futebol Muleke', 'https://www.uol.com.br/esporte/futebol-muleke/'),
#  ('Jogos de Hoje', 'https://www.uol.com.br/esporte/futebol/central-de-jogos/'),
#  ('Mercado da Bola',
#   'https://www.uol.com.br/esporte/futebol/mercado-da-bola/'),
#  ('Mundial de Clubes',
#   'https://www.uol.com.br/esporte/futebol/campeonatos/mundial-de-clubes/'),
#  ('Copa São Paulo',
#   'https://www.uol.com.br/esporte/futebol/campeonatos/copa-sao-paulo/ '),
#  ('Paulistão', 'https://www.uol.com.br/esporte/futebol/campeonatos/paulista/'),
#  ('Carioca', 'https://www.uol.com.br/esporte/futebol/campeonatos/carioca/'),
#  ('Liga dos Campeões',
#   'https://www.uol.com.br/esporte/futebol/campeonatos/liga-dos-campeoes/'),
#  ('Eliminatórias Sul-Americanas',
#   'https://www.uol.com.br/esporte/futebol/campeonatos/eliminatorias-sul-americanas/'),
#  ('Mais campeonatos', 'https://www.uol.com.br/esporte/futebol/campeonatos/'),
#  ('Fórmula 1', 'https://www.uol.com.br/esporte/f1/'),
#  ('MMA', 'https://www.uol.com.br/esporte/mma/'),
#  ('Basquete', 'https://www.uol.com.br/esporte/basquete/'),
#  ('Vôlei', 'https://www.uol.com.br/esporte/volei/'),
#  ('Tênis', 'https://www.uol.com.br/esporte/tenis/'),
#  ('Reportagens especiais',
#   'https://www.uol.com.br/esporte/reportagens-especiais/'),
#  ('Minha História', 'https://www.uol.com.br/esporte/minha-historia'),
#  ('Colunas', 'https://www.uol.com.br/esporte/blogs-e-colunas/'),
#  ('Vídeos', 'https://www.uol.com.br/esporte/videos/'),
#  ('Últimas notícias', 'https://www.uol.com.br/esporte/ultimas/'),
#  ('América-MG', 'https://www.uol.com.br/esporte/futebol/times/america-mg/'),
#  ('Athletico', 'https://www.uol.com.br/esporte/futebol/times/athletico/'),
#  ('Atletico-MG', 'https://www.uol.com.br/esporte/futebol/times/atletico-mg/'),
#  ('Atlético-GO', 'https://www.uol.com.br/esporte/futebol/times/atletico-go/'),
#  ('Avaí', 'https://www.uol.com.br/esporte/futebol/times/avai/'),
#  ('Botafogo', 'https://www.uol.com.br/esporte/futebol/times/botafogo/'),
#  ('Ceará', 'https://www.uol.com.br/esporte/futebol/times/ceara/'),
#  ('Corinthians',
#   'https://www.uol.com.br/esporte/ao-vivo/futebol/corinthians-agora/'),
#  ('Coritiba', 'https://www.uol.com.br/esporte/futebol/times/coritiba/'),
#  ('Cruzeiro', 'https://www.uol.com.br/esporte/futebol/times/cruzeiro/'),
#  ('Cuiabá', 'https://www.uol.com.br/esporte/futebol/times/cuiaba/'),
#  ('Flamengo',
#   'https://www.uol.com.br/esporte/ao-vivo/futebol/flamengo-agora/'),
#  ('Fluminense', 'https://www.uol.com.br/esporte/futebol/times/fluminense/'),
#  ('Fortaleza', 'https://www.uol.com.br/esporte/futebol/times/fortaleza/'),
#  ('Goiás', 'https://www.uol.com.br/esporte/futebol/times/goias/'),
#  ('Grêmio', 'https://www.uol.com.br/esporte/futebol/times/gremio/'),
#  ('Internacional',
#   'https://www.uol.com.br/esporte/futebol/times/internacional/'),
#  ('Juventude', 'https://www.uol.com.br/esporte/futebol/times/juventude/'),
#  ('Palmeiras',
#   'https://www.uol.com.br/esporte/ao-vivo/futebol/palmeiras-agora/'),
#  ('Red Bull Bragantino',
#   'https://www.uol.com.br/esporte/futebol/times/red-bull-bragantino/'),
#  ('Santos', 'https://www.uol.com.br/esporte/ao-vivo/futebol/santos-agora/'),
#  ('São Paulo',
#   'https://www.uol.com.br/esporte/ao-vivo/futebol/sao-paulo-agora/'),
#  ('Vasco', 'https://www.uol.com.br/esporte/futebol/times/vasco/'),
#  ('Fim de Papo',
#   'https://www.youtube.com/playlist?list=PLrxj5t1Uc3ZfwMIQjuDZ_4j0PXLUMWlzF'),
#  ('Podcast UOL Corinthians',
#   'https://www.uol.com.br/esporte/podcast/uol-corinthians'),
#  ('Podcast UOL Flamengo',
#   'https://www.uol.com.br/esporte/podcast/uol-flamengo'),
#  ('Podcast UOL Palmeiras',
#   'https://www.uol.com.br/esporte/podcast/uol-palmeiras '),
#  ('Podcast UOL São Paulo',
#   'https://www.uol.com.br/esporte/podcast/uol-sao-paulo '),
#  ('Brasileirão',
#   'https://esporteclube.uol.com.br/brasileirao?utm_source=uol-topomenu-home&utm_medium=tntsports&utm_campaign=bra'),
#  ('Champions League',
#   'https://esporteclube.uol.com.br/champions-league?utm_source=uol-topomenu-home&utm_medium=tntsports&utm_campaign=ucl'),
#  ('Copa do Nordeste',
#   'https://esporteclube.uol.com.br/copa-do-nordeste?utm_source=uol-topomenu-home&utm_medium=nordestefc&utm_campaign=cne'),
#  ('Campeonato Italiano',
#   'https://esporteclube.uol.com.br/campeonato-italiano?utm_source=uol-topomenu-home&utm_medium=tntsports&utm_campaign=ita'),
#  ('Nations League',
#   'https://esporteclube.uol.com.br/estadio-tnt-sports?utm_source=uol-topomenu-home&utm_medium=tntsports&utm_campaign=nat'),
#  ('NBA',
#   'https://esporteclube.uol.com.br/nba?utm_source=uol-topomenu-home&utm_medium=nba'),
#  ('Splash  ', 'https://www.uol.com.br/splash/'),
#  ('BBB', 'https://www.uol.com.br/splash/bbb/'),
#  ('Celebs', 'https://www.uol.com.br/splash/celebs/'),
#  ('Filmes', 'https://www.uol.com.br/splash/filmes/'),
#  ('Séries', 'https://www.uol.com.br/splash/series/'),
#  ('Música', 'https://www.uol.com.br/splash/musica/'),
#  ('Televisão', 'https://www.uol.com.br/splash/televisao/'),
#  ('Novelas', 'https://www.uol.com.br/splash/novelas/'),
#  ('Reality shows', 'https://www.uol.com.br/splash/reality-shows/'),
#  ('Memelândia', 'https://www.uol.com.br/splash/memelandia/'),
#  ('Colunas', 'https://www.uol.com.br/splash/colunas/'),
#  ('Vídeos', 'https://www.uol.com.br/splash/videos/'),
#  ('Últimas', 'https://www.uol.com.br/splash/ultimas/'),
#  ('Novelas', 'https://www.uol.com.br/splash/novelas/'),
#  ('A Bíblia', 'https://www.uol.com.br/splash/novelas/a-biblia/'),
#  ('Carinha de Anjo', 'https://www.uol.com.br/splash/novelas/carinha-de-anjo/'),
#  ('Malhação Sonhos', 'https://www.uol.com.br/splash/novelas/malhacao-sonhos/'),
#  ('Nos Tempos do Imperador',
#   'https://www.uol.com.br/splash/novelas/nos-tempos-do-imperador/'),
#  ('Quanto Mais Vida Melhor',
#   'https://www.uol.com.br/splash/novelas/quanto-mais-vida-melhor/'),
#  ('Um Lugar ao Sol', 'https://www.uol.com.br/splash/novelas/um-lugar-ao-sol/'),
#  ('OtaLab', 'https://splash.uol.com.br/otalab/'),
#  ('Poucas', 'https://www.uol.com.br/play/poucas/'),
#  ('Meteoro Por Trás da Cena',
#   'https://www.uol.com.br/play/meteoro-por-tras-da-cena/'),
#  ('Me Segue', 'https://www.uol.com.br/play/me-segue/'),
#  ('UOL Play',
#   'https://play.uol.com.br/conheca/?utm_source=uol.com.br&utm_medium=UOLHome&utm_campaign=menuentrete-assine&utm_term=menuentrete-uolplay&utm_content=menuentreteassine'),
#  ('UOL Leia+ Banca',
#   'https://clicklogger.rm.uol.com.br/?prd=938&grp=src:13;chn:539;cpg:linkfixo_menu;creative:assine-leiamais-entrete-banca;&msr=Cliques%20de%20Origem:1&oper=11&redir=https://leiamais.uol.com.br/banca'),
#  ('UOL Leia+ Livros',
#   'https://clicklogger.rm.uol.com.br/?prd=938&grp=src:13;chn:539;cpg:linkfixo_menu;creative:assine-leiamais-entrete-livro;&msr=Cliques%20de%20Origem:1&oper=11&redir=https://leiamais.uol.com.br/livros'),
#  ('Loja de jogos',
#   'http://clicklogger.rm.uol.com.br/?prd=3&grp=src:13;chn:539;creative:linkfixo_menu;thm:entretenimento-loja-de-jogos&msr=Cliques%20de%20Origem:1&oper=11&redir=https://jogos.uol.com.br/loja'),
#  ('Sexo',
#   'http://clicklogger.rm.uol.com.br/?prd=247&grp=src:13;chn:539;creative:linkfixo_menu;thm:entretenimento-sexo&msr=Cliques%20de%20Origem:1&oper=11&redir=http://sexo.uol.com.br/'),
#  ('Universa  ', 'https://www.uol.com.br/universa/'),
#  ('Transforma', 'https://www.uol.com.br/universa/transforma/'),
#  ('Inspira', 'https://www.uol.com.br/universa/inspira/'),
#  ('Pausa', 'https://www.uol.com.br/universa/pausa/'),
#  ('Horóscopo', 'https://www.uol.com.br/universa/horoscopo/previsao-diaria/'),
#  ('Newsletters', 'https://noticias.uol.com.br/newsletters?universa'),
#  ('Colunas', 'https://www.uol.com.br/universa/blogs-e-colunas/'),
#  ('Vídeos', 'https://www.uol.com.br/universa/videos/'),
#  ('Últimas notícias', 'https://www.uol.com.br/universa/ultimas/'),
#  ('Transforma', 'https://www.uol.com.br/universa/transforma/'),
#  ('Autoestima', 'https://www.uol.com.br/universa/transforma/autoestima/'),
#  ('Direitos da mulher',
#   'https://www.uol.com.br/universa/transforma/direitos-da-mulher/'),
#  ('Diversidade', 'https://www.uol.com.br/universa/transforma/diversidade/'),
#  ('Política', 'https://www.uol.com.br/universa/transforma/politica/'),
#  ('Universa Talks', 'https://uol.com.br/universa/universa-talks/'),
#  ('Vidas Negras', 'https://www.uol.com.br/universa/transforma/vidas-negras/'),
#  ('Violência contra mulher',
#   'https://www.uol.com.br/universa/transforma/violencia-contra-a-mulher/'),
#  ('Inspira', 'https://www.uol.com.br/universa/inspira/'),
#  ('Prêmio Inspiradoras',
#   'https://www.uol.com.br/universa/premio-inspiradoras/'),
#  ('A poderosa', 'https://www.uol.com.br/universa/inspira/a-poderosa/'),
#  ('Beleza', 'https://www.uol.com.br/universa/inspira/beleza/'),
#  ('Carreiras e finanças',
#   'https://www.uol.com.br/universa/inspira/carreira-e-financas/'),
#  ('Mães e Filhos', 'https://www.uol.com.br/universa/inspira/maes-e-filhos/'),
#  ('Moda', 'https://www.uol.com.br/universa/inspira/moda/'),
#  ('Relacionamentos',
#   'https://www.uol.com.br/universa/inspira/relacionamentos/'),
#  ('Sexo', 'https://www.uol.com.br/universa/inspira/sexo/'),
#  ('Universa Ensina',
#   'https://www.uol.com.br/universa/inspira/universa-ensina/'),
#  ('Pausa', 'https://www.uol.com.br/universa/pausa/'),
#  ('Fofuras', 'https://www.uol.com.br/universa/pausa/fofuras/'),
#  ('Retratos', 'https://www.uol.com.br/universa/pausa/retratos/'),
#  ('Sem filtro', 'https://www.uol.com.br/universa/pausa/sem-filtro/'),
#  ('Stalkeadas', 'https://www.uol.com.br/universa/pausa/stalkeadas/'),
#  ('Universa experimenta',
#   'https://www.uol.com.br/universa/pausa/experimenta/'),
#  ('VivaBem  ', 'https://www.uol.com.br/vivabem/'),
#  ('Coronavírus', 'https://www.uol.com.br/vivabem/saude/coronavirus/'),
#  ('Alimentação', 'https://www.uol.com.br/vivabem/alimentacao/'),
#  ('Equilíbrio', 'https://www.uol.com.br/vivabem/equilibrio/'),
#  ('Longevidade', 'https://www.uol.com.br/vivabem/longevidade/'),
#  ('Movimento', 'https://www.uol.com.br/vivabem/movimento/'),
#  ('Saúde', 'https://www.uol.com.br/vivabem/saude/'),
#  ('Newsletters', 'https://noticias.uol.com.br/newsletters?viva-bem'),
#  ('Colunas', 'https://www.uol.com.br/vivabem/blogs-e-colunas/'),
#  ('Vídeos', 'https://www.uol.com.br/vivabem/videos/'),
#  ('Últimas notícias', 'https://www.uol.com.br/vivabem/ultimas/'),
#  ('Tilt  ', 'https://www.uol.com.br/tilt/'),
#  ('Fique por dentro', 'https://www.uol.com.br/tilt/fique-por-dentro/'),
#  ('Tec a seu favor', 'https://www.uol.com.br/tilt/tec-a-seu-favor/'),
#  ('Novos hábitos', 'https://www.uol.com.br/tilt/novos-habitos/'),
#  ('Papo cabeça', 'https://www.uol.com.br/tilt/papo-cabeca/'),
#  ('Ficção científica?', 'https://www.uol.com.br/tilt/ficcao-cientifica/'),
#  ('Colunas', 'https://www.uol.com.br/tilt/blogs-e-colunas/'),
#  ('Vídeos', 'https://www.uol.com.br/tilt/videos/ultimos/'),
#  ('Últimas', 'https://www.uol.com.br/tilt/ultimas/'),
#  ('Fique por dentro', 'https://www.uol.com.br/tilt/fique-por-dentro/'),
#  ('Lançamentos', 'https://www.uol.com.br/tilt/lancamentos/'),
#  ('WhatsApp', 'https://www.uol.com.br/tilt/whatsapp/'),
#  ('Redes Sociais', 'https://www.uol.com.br/tilt/redes-sociais/'),
#  ('Apps', 'https://www.uol.com.br/tilt/app/'),
#  ('Isso é Golpe!', 'https://www.uol.com.br/tilt/isso-e-golpe/'),
#  ('Ciência', 'https://www.uol.com.br/tilt/ciencia/'),
#  ('Astronomia', 'https://www.uol.com.br/tilt/astronomia/'),
#  ('Negócios', 'https://www.uol.com.br/tilt/negocios/'),
#  ('Tec a seu favor', 'https://www.uol.com.br/tilt/tec-a-seu-favor/'),
#  ('Teste de Velocidade da Internet',
#   'https://www.uol.com.br/tilt/teste-velocidade-internet/'),
#  ('#ficadica', 'http://tilt.uol.com.br/ficadica/'),
#  ('Dicas matadoras', 'https://www.uol.com.br/tilt/dicas-matadoras/'),
#  ('A tecnologia por trás',
#   'https://www.uol.com.br/tilt/a-tecnologia-por-tras/'),
#  ('Review', 'https://www.uol.com.br/tilt/review/'),
#  ('Comparativo', 'https://www.uol.com.br/tilt/comparativo/'),
#  ('No Brasil não tem', 'https://www.uol.com.br/tilt/no-brasil-nao-tem/'),
#  ('Papo cabeça', 'https://www.uol.com.br/tilt/papo-cabeca/'),
#  ('Fala, chefia', 'https://www.uol.com.br/tilt/entrevistas-com-ceos/'),
#  ('Como seria se...', 'https://www.uol.com.br/tilt/como-seria-se/'),
#  ('Podcast Deu Tilt', 'https://www.uol.com.br/tilt/podcast/deutilt/'),
#  ('Ficção científica?', 'https://www.uol.com.br/tilt/ficcao-cientifica/'),
#  ('O que Steve diria', 'https://www.uol.com.br/tilt/o-que-steve-diria/'),
#  ('Isso é tão Black Mirror',
#   'https://www.uol.com.br/tilt/isso-e-tao-black-mirror/'),
#  ('Ecoa  ', 'https://www.uol.com.br/ecoa/'),
#  ('Pessoas', 'https://uol.com.br/ecoa/pessoas/'),
#  ('Soluções', 'https://uol.com.br/ecoa/solucoes/'),
#  ('Na prática', 'https://uol.com.br/ecoa/na-pratica/'),
#  ('Plural', 'https://www.uol.com.br/ecoa/plural/'),
#  ('Podcasts', 'https://www.uol.com.br/ecoa/podcasts/'),
#  ('Reportagens especiais', 'https://uol.com.br/ecoa/reportagens-especiais/'),
#  ('Colunas', 'https://uol.com.br/ecoa/blogs-e-colunas/'),
#  ('Últimas', 'https://uol.com.br/ecoa/ultimas/'),
#  ('Pessoas', 'https://uol.com.br/ecoa/pessoas/'),
#  ('Causadores', 'https://uol.com.br/ecoa/causadores'),
#  ('Fizeram história', 'https://uol.com.br/ecoa/fizeram-historia'),
#  ('Soluções', 'https://uol.com.br/ecoa/solucoes/'),
#  ('Empresas que mudam', 'https://uol.com.br/ecoa/empresas-que-mudam'),
#  ('Iniciativas que inspiram',
#   'https://uol.com.br/ecoa/iniciativas-que-inspiram'),
#  ('Na prática', 'https://uol.com.br/ecoa/na-pratica/'),
#  ('Sim ou não?', 'https://uol.com.br/ecoa/sim-ou-nao'),
#  ('Como fazer', 'https://uol.com.br/ecoa/como-fazer'),
#  ('Destretando', 'https://www.uol.com.br/ecoa/destretando'),
#  ('Final feliz', 'https://uol.com.br/ecoa/final-feliz'),
#  ('MOV  ', 'https://www.uol.com.br/play/mov/'),
#  ('Canal UOL', 'https://www.uol.com.br/play/ao-vivo/canal-uol/'),
#  ('Entrevistas', 'https://www.uol.com.br/play/entrevistas/'),
#  ('MOV.doc', 'https://www.uol.com.br/play/mov-doc/'),
#  ('Programas', 'https://www.uol.com.br/play/programas'),
#  ('Blog UOL Play', 'https://www.uol.com.br/play/colunas/uol-play/'),
#  ('Band', 'https://videos.band.uol.com.br/'),
#  ('Caras', 'https://caras.uol.com.br/tv/'),
#  ('History', 'https://history.uol.com.br/'),
#  ('RedeTV!', 'https://www.redetv.uol.com.br/videos/'),
#  ('TV Cultura', 'https://cultura.uol.com.br/aovivo/'),
#  ('Nossa  ', 'https://www.uol.com.br/nossa/'),
#  ('Casa', 'https://uol.com.br/nossa/casa/'),
#  ('Cozinha', 'https://uol.com.br/nossa/cozinha/'),
#  ('Viagem', 'https://uol.com.br/nossa/viagem/'),
#  ('Moda', 'https://uol.com.br/nossa/moda/'),
#  ('Bichos', 'https://www.uol.com.br/nossa/bichos/'),
#  ('Temporadas', 'https://www.uol.com.br/nossa/temporadas/'),
#  ('UOL no Verão', 'https://www.uol.com.br/uolnoverao/'),
#  ('Reportagens Especiais',
#   'https://uol.com.br/nossa/reportagens-especiais/ultimas/'),
#  ('Colunas', 'https://www.uol.com.br/nossa/blogs-e-colunas/'),
#  ('Últimas', 'https://uol.com.br/nossa/ultimas/'),
#  ('Casa', 'https://uol.com.br/nossa/casa/'),
#  ('Feito à mão', 'https://www.uol.com.br/nossa/casa/feito-a-mao/'),
#  ('Meu apê', 'https://www.uol.com.br/nossa/casa/meu-ape/'),
#  ('Microespaços', 'https://www.uol.com.br/nossa/casa/microespacos/'),
#  ('Plantados', 'https://www.uol.com.br/nossa/casa/plantados/'),
#  ('Tapa na casa', 'https://www.uol.com.br/nossa/casa/tapa-na-casa/'),
#  ('Casa de estimação', 'https://www.uol.com.br/nossa/casa/casa-de-estimacao/'),
#  ('Cozinha', 'https://uol.com.br/nossa/cozinha/'),
#  ('Receitas', 'https://www.uol.com.br/nossa/cozinha/receitas/'),
#  ('Ao ponto', 'https://www.uol.com.br/nossa/cozinha/ao-ponto/'),
#  ('Eu mereço', 'https://www.uol.com.br/nossa/cozinha/eu-mereco/'),
#  ('Instachef', 'https://www.uol.com.br/nossa/cozinha/instachef/'),
#  ('Tim-tim', 'https://www.uol.com.br/nossa/cozinha/tim-tim/'),
#  ('Receita de família',
#   'https://www.uol.com.br/nossa/cozinha/receita-de-familia/'),
#  ('Gastronobásico', 'https://www.uol.com.br/nossa/cozinha/gastronobasico/'),
#  ('Marinando (na quarentena)',
#   'https://www.uol.com.br/nossa/cozinha/marinando-na-quarentena/'),
#  ('Viagem', 'https://uol.com.br/nossa/viagem/'),
#  ('12 horas', 'https://www.uol.com.br/nossa/viagem/12-horas/'),
#  ('Fora da rota', 'https://www.uol.com.br/nossa/viagem/fora-da-rota/'),
#  ('Viajantes', 'https://www.uol.com.br/nossa/viagem/viajantes/'),
#  ('Retina', 'https://www.uol.com.br/nossa/viagem/retina/'),
#  ('Na Estrada', 'https://www.uol.com.br/nossa/viagem/na-estrada/'),
#  ('Moda', 'https://uol.com.br/nossa/moda/'),
#  ('Meu estilo', 'https://www.uol.com.br/nossa/moda/meu-estilo/'),
#  ('Moodboard', 'https://www.uol.com.br/nossa/moda/moodboard/'),
#  ('Essa roupa tem história',
#   'https://www.uol.com.br/nossa/moda/essa-roupa-tem-historia/'),
#  ('Temporadas', 'https://www.uol.com.br/nossa/temporadas/'),
#  ('Japão', 'https://www.uol.com.br/nossa/japao/'),
#  ('Brasileiro', 'https://www.uol.com.br/nossa/brasileiro/sudeste'),
#  ('Festejo', 'https://www.uol.com.br/nossa/festejo/'),
#  ('Entornos', 'https://www.uol.com.br/nossa/entornos/'),
#  ('TAB  ', 'https://tab.uol.com.br/'),
#  ('Especiais', 'http://tab.uol.com.br/especiais/'),
#  ('Perfis', 'https://tab.uol.com.br/perfis/'),
#  ('Nas Ruas', 'https://tab.uol.com.br/nas-ruas/'),
#  ('Tendência', 'http://tab.uol.com.br/tendencia/'),
#  ('Colunas', 'https://tab.uol.com.br/blogs-e-colunas/'),
#  ('Últimas', 'https://tab.uol.com.br/ultimas/'),
#  ('Assista', 'https://tab.uol.com.br/videos/'),
#  ('Newsletter', 'https://noticias.uol.com.br/newsletters?tab'),
#  ('Start  ', 'https://www.uol.com.br/start/'),
#  ('Reviews', 'https://www.uol.com.br/start/reviews/'),
#  ('eSports', 'https://www.uol.com.br/start/esport/'),
#  ('Guias', 'https://www.uol.com.br/start/guia/'),
#  ('Curiosidades', 'https://www.uol.com.br/start/curiosidades/'),
#  ('Vídeos', 'https://www.uol.com.br/start/videos/'),
#  ('Colunas', 'https://www.uol.com.br/start/blogs-e-colunas/'),
#  ('Últimas notícias', 'https://www.uol.com.br/start/ultimas/'),
#  ('{{jogo.competicao}}{{jogo.time1.sigla}}{{jogo.placar1}}({{jogo.penalti1}}{{jogo.penalti2}}){{jogo.placar2}}{{jogo.time2.sigla}}',
#   'NA'),
#  ('{{jogo.competicao}}{{jogo.time1.sigla}}{{jogo.placar1}}({{jogo.penalti1}}{{jogo.penalti2}}){{jogo.placar2}}{{jogo.time2.sigla}}',
#   'NA'),
#  ('{{jogo.competicao}}{{jogo.time1.sigla}}{{jogo.placar1}}({{jogo.penalti1}}{{jogo.penalti2}}){{jogo.placar2}}{{jogo.time2.sigla}}',
#   'NA'),
#  ('Ver mais jogos', 'https://www.uol.com.br/esporte/futebol/central-de-jogos'),
#  (' Topo', 'NA'),
#  ('Futebol', 'https://www.uol.com.br/esporte/futebol/ultimas/'),
#  (' Times', 'NA'),
#  ('', '//www.uol.com.br/esporte/futebol/times/america-mg/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/athletico/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/atletico-go/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/atletico-mg/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/avai/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/botafogo/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/red-bull-bragantino/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/ceara/'),
#  ('', 'https://www.uol.com.br/esporte/ao-vivo/futebol/corinthians-agora/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/coritiba/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/cruzeiro/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/cuiaba/'),
#  ('', 'https://www.uol.com.br/esporte/ao-vivo/futebol/flamengo-agora/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/fluminense/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/fortaleza/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/goias/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/gremio/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/internacional/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/juventude/'),
#  ('', 'https://www.uol.com.br/esporte/ao-vivo/futebol/palmeiras-agora/'),
#  ('', 'https://www.uol.com.br/esporte/ao-vivo/futebol/santos-agora/'),
#  ('', 'https://www.uol.com.br/esporte/ao-vivo/futebol/sao-paulo-agora/'),
#  ('', '//www.uol.com.br/esporte/futebol/times/vasco/'),
#  ('', 'NA'),
#  ('Futebol ', 'https://www.uol.com.br/esporte/futebol/ultimas/'),
#  ('Futebol', 'https://www.uol.com.br/esporte/futebol/'),
#  ("      Lentidão e salário 'europeu' de Diego Costa explicam o não do Corinthians    ",
#   'https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/lentidao-e-salario-europeu-de-diego-costa-explicam-o-nao-do-corinthians.htm'),
#  ('      Por que o Flamengo puxa freio de mão e não repete agressividade no mercado    ',
#   'https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/por-que-o-flamengo-puxa-freio-de-mao-e-nao-repete-agressividade-no-mercado.htm'),
#  ("      Santos: Dracena e agente detalham 'renovação marcante' de Marcos Leonardo    ",
#   'https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/santos-dracena-e-agente-detalham-renovacao-marcante-de-marcos-leonardo.htm'),
#  ('{{comments.info.url}}', 'NA'),
#  ('', 'NA'),
#  ('Assine já',
#   'https://cadastro.uol.com.br/indexb.html?skinPath=uol&skin=cadastrounificado%2Fvisitor%2Fpf&promochild=PROMOPAYWALL&eos=yes&utm_source=Home%20UOL&utm_medium=midia%20interna&utm_campaign=comentarios-paywall&utm_term=comentarios-assinatura-paywall&utm_content=convers%C3%B5es-comentarios-paywall'),
#   'https://www.uol.com.br/esporte/futebol/ultimas-noticias/2022/01/22/real-madrid-e-mais-um-gigante-europeu-de-olho-em-endrick-segundo-jornal.htm'),
#  ('        Milton: O Timão está passando vergonha na busca por um camisa 9 22/01/2022 09h42 ',
#   'https://www.uol.com.br/esporte/colunas/milton-neves/2022/01/22/milton-o-timao-esta-passando-vergonha-na-busca-por-um-camisa-9.htm'),
#  ('        Ancelotti crava permanência de Hazard no Real Madrid 22/01/2022 09h23 ',
#   'https://www.uol.com.br/esporte/futebol/ultimas-noticias/gazeta-esportiva/2022/01/22/ancelotti-crava-permanencia-de-hazard-no-real-madrid.htm'),
#  ('  NFL 2021 - Divisional Round Chegamos ao fim de semana mais emocionante da temporada da NFL. Oito times disputando quatro vagas às finais de... 22/01/2022 09h06 ',
#   'https://www.uol.com.br/esporte/ultimas-noticias/enm/2022/01/22/nfl-2021---divisional-round.htm')]

# %% [markdown]
# ## Searching for a list of tags

# %%
# Your code here!
tags = soup.find_all(['h1', 'h2', 'h3'])

# %%
tags[2]
# Out:
# <h3 class="thumb-title"> Lentidão e salário 'europeu' de Diego Costa explicam o não do Corinthians  </h3>

# %%
results = [tag.text for tag in tags]
len(results)
# Out:
# 19

# %%
results
# Out:
# [' Futebol ',
#  '  Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu   ',
#  " Lentidão e salário 'europeu' de Diego Costa explicam o não do Corinthians  ",
#  ' Por que o Flamengo puxa freio de mão e não repete agressividade no mercado  ',
#  " Santos: Dracena e agente detalham 'renovação marcante' de Marcos Leonardo  ",
#  'Ocorreu um erro ao carregar os comentários.',
#  'Essa discussão está encerrada',
#  'Futebol',
#  'Arsenal x Burnley: onde assistir, horário e prováveis escalações do jogo do Campeonato Inglês',
#  'Ferj altera horário do clássico entre Flamengo e Fluminense, pelo Carioca',
#  "CR7 fala sobre momento em que se apaixonou por Georgina: 'Foi um clique'",
#  "São Paulo parabeniza Rogério Ceni: 'Nasceu para conquistar o mundo'",
#  'Que golaço! Na web, Gabigol promete encontro especial com torcedor do Flamengo',
#  'Morre Gianni Di Marzio, o homem que descobriu Maradona para o Napoli',
#  'Após votação nas redes, Íbis negocia para tirar do papel jogo contra clube inglês na Europa e estipula um prazo',
#  'Real Madrid é mais um gigante europeu de olho em Endrick, segundo jornal',
#  'Milton: O Timão está passando vergonha na busca por um camisa 9',
#  'Ancelotti crava permanência de Hazard no Real Madrid',
#  'NFL 2021 - Divisional Round']

# %%
tags = soup.find_all(['article'])
len(tags)
# Out:
# 1

# %%
tags[0].text
# Out:
# '    Em 1995, decisão na base entre Palmeiras x SP terminou em morte no Pacaembu            Briga entre as torcidas do Palmeiras e do São Paulo durante a final da Supercopa de Juniores de 1995 Imagem: Roberto Delduque/Folhapress      Thiago Braga Colaboração para o UOL, em São Paulo 22/01/2022 04h00    Acostumado a ter em seu gramado grandes jogadores, dribles desconcertantes e gols inesquecíveis, o estádio do Pacaembu teve uma manhã diferente no dia 20 de agosto de 1995. Palmeiras e São Paulo - que se enfrentam neste sábado (22), pela semifinal da Copa São Paulo de Futebol Júnior - decidiram em 1995 a Supercopa de Futebol Júnior, torneio que reunia os campeões e vices da Copinha. A comemoração do título do Palmeiras resultou em um dos confrontos mais violentos entre torcidas no país, com um morto e 102 feridos.Se nos dias atuais o Pacaembu está fechado para reforma, naquele domingo palmeirenses e tricolores lotaram as arquibancadas do estádio municipal. As equipes profissionais dos dois clubes estavam dominando o futebol brasileiro no início dos anos 90. E a decisão da Supercopa era um reflexo do bom momento de ambos.   Pela regra da prorrogação na morte súbita adotada naquela competição, o time que marcasse o gol seria campeão. Pouco mais de 21 anos após aquela final, o gol de Rogério, que decretou o título do Verdão, é um fato menor daquela decisão. O tento, aos 5 min da prorrogação, fez os torcedores alviverdes explodirem em comemoração. A alegria pelo título inédito incentivou os palestrinos a invadirem o gramado do Pacaembu. Alguns torcedores começaram a provocar os são-paulinos que ainda não haviam deixado o estádio. Foi o estopim para que o campo de jogo virasse um campo de guerra.Os tricolores derrubaram o alambrado do setor em que estavam, invadiram o tobogã, então em obras e, armados de paus, pedras e tudo mais que pudesse servir de arma, revidaram. A partir daí o gramado do Pacaembu virou cenário de guerra medieval.    Torcedor é ferido durante briga entre torcidas de Palmeiras e São Paulo Imagem: Roberto Delduque/Folhapress Os palmeirenses recuaram. Em maior número, contra-atacaram. O efetivo policial era reduzido por ser um jogo de juniores. Assim, o entulho encontrado no estádio virou arsenal na mão dos torcedores. Quem caía, era espancado impiedosamente. Uma das cenas mais impactantes é quando um torcedor recebe pauladas na cabeça e sai cambaleando até desabar no alambrado.Agredido inúmeras vezes, o são-paulino Márcio Gasparin da Silva, 16, sofreu múltiplos traumatismos cranianos. Morreu oito dias depois da briga no Pacaembu.O palmeirense Adalberto Benedito dos Santos foi responsabilizado pelo assassinato de Márcio. Em 1998, três anos após o confronto, Adalberto foi julgado e condenado a 12 anos de prisão pela morte de Márcio. Cumpriu aproximadamente quatro em reclusão, e conseguiu progressão para o regime semi-aberto.A família de Márcio entrou na Justiça contra a Prefeitura de São Paulo, mas o judiciário não concedeu a indenização pretendida e também não considerou o município culpado pela morte do adolescente.O caso também foi um marco para a regulamentação das torcidas no Estado. O Ministério Público de São Paulo decretou a extinção da Mancha Verde e da Independente, que ressurgiram após mudanças jurídicas e de nome. Na prática, culminou com a decisão de restringir apenas aos torcedores da equipe mandante a presença em clássicos em São Paulo. "Naquela época, o Ministério Público ainda não havia iniciado o controle das organizadas, mas o preço da tranquilidade é a eterna vigilância. O jogo requer atenção", falou ao UOL Fernando Capez, então promotor público que pediu a extinção das organizadas de São Paulo e Palmeiras.       As mais lidas agora         Lentidão e salário \'europeu\' de Diego Costa explicam o não do Corinthians             Por que o Flamengo puxa freio de mão e não repete agressividade no mercado             Santos: Dracena e agente detalham \'renovação marcante\' de Marcos Leonardo            ...

# %%
# Your code here!
tags = soup.find(['article'])

# %%
tags.text

# %% [markdown]
# # Voltamos 11h50
# # Another example

# %% [markdown]
# <ol>
#     <li> request the url </li>
#     <li> get its html </li>
#     <li> convert to soup </li>
#     <li> being a soup, we can look for tags </li>
# </ol>

# %%
# Your code here!
url = 'https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy'

# %%
# Your code here!
response = requests.get(url)
html = response.content

# %%
soup = BeautifulSoup(html)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of European countries by life expectancy - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"619b0cd6-6d47-40f3-8a40-c695c75cf52d","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_European_countries_by_life_expectancy","wgTitle":"List of European countries by life expectancy","wgCurRevisionId":1049636953,"wgRevisionId":1049636953,"wgArticleId":22175559,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Lists of countries in Europe","Life expectancy"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":
# "List_of_European_countries_by_life_expectancy","wgRelevantArticleId":22175559,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"skin":"vector","wgFlaggedRevsParams":{"tags":{"status":{"levels":-1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":10000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q6640221","wgGENewcomerTasksGuidanceEnabled":true,"wgGEAskQuestionEnabled":false,"wgGELinkRecommendationsFrontendEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":
# "ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp",
# "ext.centralauth.centralautologin","ext.popups","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1i9g4",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});});});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.38.0-wmf.18" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="List of European countries by life expectancy - Wikipedia" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//en.m.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=List_of_European_countries_by_life_expectancy&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="https://creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy" rel="canonical"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_European_countries_by_life_expectancy rootpage-List_of_European_countries_by_life_expectancy skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators">
#    </div>
#    <h1 class="firstHeading mw-first-heading" id="firstHeading">
#     List of European countries by life expectancy
#    </h1>
#    <div class="vector-body" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Jump to search
#     </a>
#     <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        Wikipedia list article
#       </div>
#       <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation">
#        <input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/>
#        <div class="toctitle" dir="ltr" lang="en">
#         <h2 id="mw-toc-heading">
#          Contents
#         </h2>
#         <span class="toctogglespan">
#          <label class="toctogglelabel" for="toctogglecheckbox">
#          </label>
#         </span>
#        </div>
#        <ul>
#         <li class="toclevel-1 tocsection-1">
#          <a href="#Map">
#           <span class="tocnumber">
#            1
#           </span>
#           <span class="toctext">
#            Map
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-2">
#          <a href="#Life_expectancy_by_country_(2016)">
#           <span class="tocnumber">
#            2
#           </span>
#           <span class="toctext">
#            Life expectancy by country (2016)
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-3">
#          <a href="#See_also">
#           <span class="tocnumber">
#            3
#           </span>
#           <span class="toctext">
#            See also
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-4">
#            <a href="#Plotted_maps">
#             <span class="tocnumber">
#              3.1
#             </span>
#             <span class="toctext">
#              Plotted maps
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-5">
#          <a href="#References">
#           <span class="tocnumber">
#            4
#           </span>
#           <span class="toctext">
#            References
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <h2>
#        <span class="mw-headline" id="Map">
#         Map
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=List_of_European_countries_by_life_expectancy&amp;action=edit&amp;section=1" title="Edit section: Map">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <p>
#        The map and table below cites
#        <a href="/wiki/Life_expectancy" title="Life expectancy">
#         life expectancy
#        </a>
#        per country from The World Bank's 2018 statistics.
#        <sup class="reference" id="cite_ref-:0_1-0">
#         <a href="#cite_note-:0-1">
#          [1]
#         </a>
#        </sup>
#        Hotter colours indicate lower life expectancy, colder colours indicate high life expectancy.
#       </p>
#       <div class="noresize" role="img" style="width: 700px; line-height: 1; text-align: center; background-color: #ffffff; position: relative;">
#        <a class="image" href="/wiki/File:Europe_polar_stereographic_Caucasus_Urals_boundary3.svg">
#         <img alt="" data-file-height="545" data-file-width="700" decoding="async" height="545" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Europe_polar_stereographic_Caucasus_Urals_boundary3.svg/700px-Europe_polar_stereographic_Caucasus_Urals_boundary3.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Europe_polar_stereographic_Caucasus_Urals_boundary3.svg/1050px-Europe_polar_stereographic_Caucasus_Urals_boundary3.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Europe_polar_stereographic_Caucasus_Urals_boundary3.svg/1400px-Europe_polar_stereographic_Caucasus_Urals_boundary3.svg.png 2x" width="700"/>
#        </a>
#        <div style="position:absolute; font-size:85%; left:424.5px; top:457.5px">
#         <a href="/wiki/Albania" title="Albania">
#          <span style="background:#ACD67B;color:white">
#           79
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:365px; top:384px">
#         <a href="/wiki/Austria" title="Austria">
#          <span style="background:#9DD69B;color:white">
#           82
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:449px; top:314px">
#         <a href="/wiki/Belarus" title="Belarus">
#          <span style="background:#D6CE75;color:white">
#           74
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:295px; top:335px">
#         <a href="/wiki/Belgium" title="Belgium">
#          <span style="background:#9DD69B;color:white">
#           81
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:337px; top:230px">
#         <a href="/wiki/Norway" title="Norway">
#          <span style="background:#9DD69B;color:white">
#           83
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:400px; top:328px">
#         <a href="/wiki/Poland" title="Poland">
#          <span style="background:#C5D675;color:white">
#           78
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:162px; top:426px">
#         <a href="/wiki/Portugal" title="Portugal">
#          <span style="background:#9DD69B;color:white">
#           82
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:452.5px; top:394.5px">
#         <a href="/wiki/Romania" title="Romania">
#          <span style="background:#D6CE75;color:white">
#           75
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:526px; top:258px">
#         <a href="/wiki/Russia" title="Russia">
#          <span style="background:#D6AE71;color:white">
#           73
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:424.5px; top:415.5px">
#         <a href="/wiki/Serbia" title="Serbia">
#          <span style="background:#C5D675;color:white">
#           76
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:400px; top:370px">
#         <a href="/wiki/Slovakia" title="Slovakia">
#          <span style="background:#C5D675;color:white">
#           77
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:376.9px; top:398px">
#         <a href="/wiki/Slovenia" title="Slovenia">
#          <span style="background:#9DD69B;color:white">
#           81
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:204px; top:447px">
#         <a href="/wiki/Spain" title="Spain">
#          <span style="background:#9DD69B;color:white">
#           83
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:372px; top:251px">
#         <a href="/wiki/Sweden" title="Sweden">
#          <span style="background:#9DD69B;color:white">
#           83
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:325.8px; top:384px">
#         <a href="/wiki/Switzerland" title="Switzerland">
#          <span style="background:#9DD69B;color:white">
#           83
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:547px; top:447px">
#         <a href="/wiki/Turkey" title="Turkey">
#          <span style="background:#D6CE75;color:white">
#           75
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:498px; top:356px">
#         <a href="/wiki/Ukraine" title="Ukraine">
#          <span style="background:#D6AE71;color:white">
#           73
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:253px; top:307px">
#         <a href="/wiki/United_Kingdom" title="United Kingdom">
#          <span style="background:#9DD69B;color:white">
#           82
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:375.5px; top:426px">
#         <a href="/wiki/Adriatic_Sea" title="Adriatic Sea">
#          <span style="color:#E2EBF5;">
#           <i>
#            Adriatic
#            <br/>
#            Sea
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:361.5px; top:13px">
#         <i>
#          <a href="/wiki/Arctic_Ocean" title="Arctic Ocean">
#           <span style="color:#E2EBF5;">
#            Arctic Ocean
#           </span>
#          </a>
#         </i>
#        </div>
#        <div style="position:absolute; font-size:85%; left:407px; top:104px">
#         <i>
#          <a href="/wiki/Barents_Sea" title="Barents Sea">
#           <span style="color:#E2EBF5;">
#            Barents Sea
#           </span>
#          </a>
#         </i>
#        </div>
#        <div style="position:absolute; font-size:85%; left:218px; top:377px">
#         <a href="/wiki/Bay_of_Biscay" title="Bay of Biscay">
#          <span style="color:#E2EBF5;">
#           <i>
#            Bay of
#            <br/>
#            Biscay
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:526px; top:412px">
#         <a href="/wiki/Black_Sea" title="Black Sea">
#          <span style="color:#E2EBF5;">
#           <i>
#            Black
#            <br/>
#            Sea
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:554px; top:384px">
#         <a href="/wiki/Sea_of_Azov" title="Sea of Azov">
#          <span style="color:#E2EBF5;">
#           <i>
#            Azov
#            <br/>
#            Sea
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:645px; top:344.1px">
#         <a href="/wiki/Caspian_Sea" title="Caspian Sea">
#          <span style="color:#E2EBF5;">
#           <i>
#            Caspian
#            <br/>
#            Sea
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:218px; top:311.2px">
#         <a href="/wiki/Celtic_Sea" title="Celtic Sea">
#          <span style="color:#E2EBF5;">
#           <i>
#            Celtic
#            <br/>
#            Sea
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:162px; top:125px">
#         <i>
#          <a href="/wiki/Greenland_Sea" title="Greenland Sea">
#           <span style="color:#E2EBF5;">
#            Greenland Sea
#           </span>
#          </a>
#         </i>
#        </div>
#        <div style="position:absolute; font-size:85%; left:78px; top:41px">
#         <i>
#          <a href="/wiki/Baffin_Bay" title="Baffin Bay">
#           <span style="color:#E2EBF5;">
#            Baffin Bay
#           </span>
#          </a>
#         </i>
#        </div>
#        <div style="position:absolute; font-size:85%; left:145.9px; top:468px">
#         <a class="mw-redirect" href="/wiki/Gulf_of_Cadiz" title="Gulf of Cadiz">
#          <span style="color:#E2EBF5;">
#           <i>
#            Gulf of
#            <br/>
#            Cadiz
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:288px; top:426px">
#         <a href="/wiki/Ligurian_Sea" title="Ligurian Sea">
#          <span style="color:#E2EBF5;">
#           <i>
#            Ligurian
#            <br/>
#            Sea
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:288px; top:482px">
#         <i>
#          <a href="/wiki/Mediterranean_Sea" title="Mediterranean Sea">
#           <span style="color:#E2EBF5;">
#            Mediterranean Sea
#           </span>
#          </a>
#         </i>
#        </div>
#        <div style="position:absolute; font-size:85%; left:120px; top:223px">
#         <a class="mw-redirect" href="/wiki/North_Atlantic_Ocean" title="North Atlantic Ocean">
#          <span style="color:#E2EBF5;">
#           <i>
#            North
#            <br/>
#            Atlantic
#            <br/>
#            Ocean
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:305.5px; top:279px">
#         <a href="/wiki/North_Sea" title="North Sea">
#          <span style="color:#E2EBF5;">
#           <i>
#            North
#            <br/>
#            Sea
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:295px; top:181px">
#         <a href="/wiki/Norwegian_Sea" title="Norwegian Sea">
#          <span style="color:#E2EBF5;">
#           <i>
#            Norwegian
#            <br/>
#            Sea
#           </i>
#          </span>
#         </a>
#        </div>
#        <div style="position:absolute; font-size:85%; left:186.5px; top:486.2px">
#         <i>
#          <a href="/wiki/Strait_of_Gibraltar" title="Strait of Gibraltar">
#           <span style="color:#E2EBF5;">
#            Strait of Gibraltar
#           </span>
#          </a>
#         </i>
#        </div>
#       </div>
#       <h2>
#        <span id="Life_expectancy_by_country_.282016.29">
#        </span>
#        <span class="mw-headline" id="Life_expectancy_by_country_(2016)">
#         Life expectancy by country (2016)
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=List_of_European_countries_by_life_expectancy&amp;action=edit&amp;section=2" title="Edit section: Life expectancy by country (2016)">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:402px;">
#         <a class="image" href="/wiki/File:Life_expectancy_in_Europe.png">
#          <img alt="" class="thumbimage" data-file-height="3186" data-file-width="3786" decoding="async" height="337" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Life_expectancy_in_Europe.png/400px-Life_expectancy_in_Europe.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/de/Life_expectancy_in_Europe.png/600px-Life_expectancy_in_Europe.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/de/Life_expectancy_in_Europe.png/800px-Life_expectancy_in_Europe.png 2x" width="400"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:Life_expectancy_in_Europe.png" title="Enlarge">
#           </a>
#          </div>
#          Life expectancy in years in European countries, 2016
#         </div>
#        </div>
#       </div>
#       <table class="sortable wikitable">
#        <tbody>
#         <tr bgcolor="#efefef">
#          <th>
#           Rank
#          </th>
#          <th>
#           Country
#          </th>
#          <th>
#           <a href="/wiki/List_of_countries_by_life_expectancy" title="List of countries by life expectancy">
#            Life expectancy
#           </a>
#           <sup class="reference" id="cite_ref-:0_1-1">
#            <a href="#cite_note-:0-1">
#             [1]
#            </a>
#           </sup>
#          </th>
#          <th>
#           Influenza vaccination rate, people aged 65 and over, 2016 (%)
#           <sup class="reference" id="cite_ref-2">
#            <a href="#cite_note-2">
#             [2]
#            </a>
#           </sup>
#          </th>
#         </tr>
#         <tr>
#          <td>
#           1
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="800" data-file-width="1000" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/19px-Flag_of_Monaco.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/29px-Flag_of_Monaco.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/38px-Flag_of_Monaco.svg.png 2x" width="19"/>
#           </span>
#           <a href="/wiki/Monaco" title="Monaco">
#            Monaco
#           </a>
#           <sup class="reference" id="cite_ref-3">
#            <a href="#cite_note-3">
#             [3]
#            </a>
#           </sup>
#          </td>
#          <td>
#           89.4
#          </td>
#          <td>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           2
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="800" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/20px-Flag_of_San_Marino.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/31px-Flag_of_San_Marino.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/40px-Flag_of_San_Marino.svg.png 2x" width="20"/>
#           </span>
#           <a href="/wiki/San_Marino" title="San Marino">
#            San Marino
#           </a>
#           <sup class="reference" id="cite_ref-4">
#            <a href="#cite_note-4">
#             [4]
#            </a>
#           </sup>
#          </td>
#          <td>
#           83.4
#          </td>
#          <td>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           3
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="512" data-file-width="512" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/16px-Flag_of_Switzerland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/24px-Flag_of_Switzerland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/32px-Flag_of_Switzerland.svg.png 2x" width="16"/>
#           </span>
#           <a href="/wiki/Switzerland" title="Switzerland">
#            Switzerland
#           </a>
#          </td>
#          <td>
#           83.0
#          </td>
#          <td>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           4
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/23px-Flag_of_Spain.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/35px-Flag_of_Spain.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/45px-Flag_of_Spain.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Spain" title="Spain">
#            Spain
#           </a>
#          </td>
#          <td>
#           82.8
#          </td>
#          <td>
#           56%
#          </td>
#         </tr>
#         <tr>
#          <td>
#           5
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/47/Flag_of_Liechtenstein.svg/23px-Flag_of_Liechtenstein.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/47/Flag_of_Liechtenstein.svg/35px-Flag_of_Liechtenstein.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/47/Flag_of_Liechtenstein.svg/46px-Flag_of_Liechtenstein.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Liechtenstein" title="Liechtenstein">
#            Liechtenstein
#           </a>
#          </td>
#          <td>
#           82.7
#          </td>
#          <td>
#           28%
#          </td>
#         </tr>
#         <tr>
#          <td>
#           6
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Italy" title="Italy">
#            Italy
#           </a>
#          </td>
#          <td>
#           82.7
#          </td>
#          <td>
#           50%
#          </td>
#         </tr>
#         <tr>
#          <td>
#           7
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="372" data-file-width="512" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/21px-Flag_of_Norway.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/32px-Flag_of_Norway.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Flag_of_Norway.svg/41px-Flag_of_Norway.svg.png 2x" width="21"/>
#           </span>
#           <a href="/wiki/Norway" title="Norway">
#            Norway
#           </a>
#          </td>
#          <td>
#           82.5
#          </td>
#          <td>
#           38%
#          </td>
#         </tr>
#         <tr>
#          <td>
#           8
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="900" data-file-width="1250" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Flag_of_Iceland.svg/21px-Flag_of_Iceland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Flag_of_Iceland.svg/32px-Flag_of_Iceland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Flag_of_Iceland.svg/42px-Flag_of_Iceland.svg.png 2x" width="21"/>
#           </span>
#           <a href="/wiki/Iceland" title="Iceland">
#            Iceland
#           </a>
#          </td>
#          <td>
#           82.5
#          </td>
#          <td>
#           47%
#          </td>
#         </tr>
#         <tr>
#          <td>
#           9
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/da/Flag_of_Luxembourg.svg/23px-Flag_of_Luxembourg.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/da/Flag_of_Luxembourg.svg/35px-Flag_of_Luxembourg.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/da/Flag_of_Luxembourg.svg/46px-Flag_of_Luxembourg.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Luxembourg" title="Luxembourg">
#            Luxembourg
#           </a>
#          </td>
#          <td>
#           82.3
#          </td>
#          <td>
#           38%
#          </td>
#         </tr>
#         <tr>
#          <td>
#

#          </td>
#         </tr>
#         <tr>
#          <td>
#           25
#          </td>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="700" data-file-width="980" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/21px-Flag_of_Albania.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/32px-Flag_of_Albania.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/42px-Flag_of_Albania.svg.png 2x" width="21"/>
#           </span>
#           <a href="/wiki/Albania" title="Albania">
# ...
#       <div>
#        <h3>
#         <label for="searchInput">
#          Search
#         </label>
#        </h3>
#        <form action="/w/index.php" class="vector-search-box-form" id="searchform">
#         <div class="vector-search-box-inner" data-search-loc="header-navigation" id="simpleSearch">
#          <input accesskey="f" aria-label="Search Wikipedia" autocapitalize="sentences" class="vector-search-box-input" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
#          <input name="title" type="hidden" value="Special:Search"/>
#          <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
#          <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="mw-panel">
#     <div id="p-logo" role="banner">
#      <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page">
#      </a>
#     </div>
#     <nav aria-labelledby="p-navigation-label" class="mw-portlet mw-portlet-navigation vector-menu vector-menu-portal portal" id="p-navigation" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-navigation-label">
#       <span class="vector-menu-heading-label">
#        Navigation
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="mw-list-item" id="n-mainpage-description">
#         <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">
#          <span>
#           Main page
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-contents">
#         <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">
#          <span>
#           Contents
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-currentevents">
#         <a href="/wiki/Portal:Current_events" title="Articles related to current events">
#          <span>
#           Current events
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-randompage">
#         <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]">
#          <span>
#           Random article
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-aboutsite">
#         <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works">
#          <span>
#           About Wikipedia
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-contactpage">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#          <span>
#           Contact us
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-sitesupport">
#         <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation">
#          <span>
#           Donate
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-interaction-label" class="mw-portlet mw-portlet-interaction vector-menu vector-menu-portal portal" id="p-interaction" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-interaction-label">
#       <span class="vector-menu-heading-label">
#        Contribute
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="mw-list-item" id="n-help">
#         <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">
#          <span>
#           Help
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-introduction">
#         <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia">
#          <span>
#           Learn to edit
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-portal">
#         <a href="/wiki/Wikipedia:Community_portal" title="The hub for editors">
#          <span>
#           Community portal
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-recentchanges">
#         <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">
#          <span>
#           Recent changes
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-upload">
#         <a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia">
#          <span>
#           Upload file
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-tb-label">
#       <span class="vector-menu-heading-label">
#        Tools
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="mw-list-item" id="t-whatlinkshere">
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/List_of_European_countries_by_life_expectancy" title="List of all English Wikipedia pages containing links to this page [j]">
#          <span>
#           What links here
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/List_of_European_countries_by_life_expectancy" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          <span>
#           Related changes
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          <span>
#           Upload file
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          <span>
#           Special pages
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-permalink">
#         <a href="/w/index.php?title=List_of_European_countries_by_life_expectancy&amp;oldid=1049636953" title="Permanent link to this revision of this page">
#          <span>
#           Permanent link
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-info">
#         <a href="/w/index.php?title=List_of_European_countries_by_life_expectancy&amp;action=info" title="More information about this page">
#          <span>
#           Page information
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-cite">
#         <a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_European_countries_by_life_expectancy&amp;id=1049636953&amp;wpFormIdentifier=titleform" title="Information on how to cite this page">
#          <span>
#           Cite this page
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-wikibase">
#         <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q6640221" title="Structured data on this page hosted by Wikidata [g]">
#          <span>
#           Wikidata item
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-coll-print_export-label">
#       <span class="vector-menu-heading-label">
#        Print/export
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="mw-list-item" id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=List_of_European_countries_by_life_expectancy&amp;action=show-download-screen" title="Download this page as a PDF file">
#          <span>
#           Download as PDF
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-print">
#         <a accesskey="p" href="/w/index.php?title=List_of_European_countries_by_life_expectancy&amp;printable=yes" title="Printable version of this page [p]">
#          <span>
#           Printable version
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-lang-label">
#       <span class="vector-menu-heading-label">
#        Languages
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="interlanguage-link interwiki-ru mw-list-item">
#         <a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D1%81%D1%82%D1%80%D0%B0%D0%BD_%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D1%8B_%D0%BF%D0%BE_%D0%BE%D0%B6%D0%B8%D0%B4%D0%B0%D0%B5%D0%BC%D0%BE%D0%B9_%D0%BF%D1%80%D0%BE%D0%B4%D0%BE%D0%BB%D0%B6%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%BE%D1%81%D1%82%D0%B8_%D0%B6%D0%B8%D0%B7%D0%BD%D0%B8" hreflang="ru" lang="ru" title="Список стран Европы по ожидаемой продолжительности жизни – Russian">
#          <span>
#           Русский
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uk mw-list-item">
#         <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BA%D1%80%D0%B0%D1%97%D0%BD_%D0%84%D0%B2%D1%80%D0%BE%D0%BF%D0%B8_%D0%B7%D0%B0_%D1%82%D1%80%D0%B8%D0%B2%D0%B0%D0%BB%D1%96%D1%81%D1%82%D1%8E_%D0%B6%D0%B8%D1%82%D1%82%D1%8F" hreflang="uk" lang="uk" title="Список країн Європи за тривалістю життя – Ukrainian">
#          <span>
#           Українська
#          </span>
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q6640221#sitelinks-wikipedia" title="Edit interlanguage links">
#          Edit links
#         </a>
#        </span>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 12 October 2021, at 23:39
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=List_of_European_countries_by_life_expectancy&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.810","walltime":"1.053","ppvisitednodes":{"value":8994,"limit":1000000},"postexpandincludesize":{"value":176140,"limit":2097152},"templateargumentsize":{"value":35572,"limit":2097152},"expansiondepth":{"value":15,"limit":40},"expensivefunctioncount":{"value":21,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":19304,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  790.105      1 -total"," 34.95%  276.135      9 Template:Navbox"," 22.86%  180.649      1 Template:Europe_topics_(small)"," 21.91%  173.092      1 Template:Region_topics"," 20.07%  158.589     44 Template:Flag"," 16.63%  131.378      4 Template:Cite_web"," 10.93%   86.361      1 Template:Short_description","  9.71%   76.735      1 Template:Quality_of_life_country_lists","  6.09%   48.086      1 Template:Pagetype","  4.70%   37.105     60 Template:Image_label_small"]},"scribunto":{"limitreport-timeusage":{"value":"0.257","limit":"10.000"},"limitreport-memusage":{"value":5205181,"limit":52428800}},"cachereport":{"origin":"mw1354","timestamp":"20220121233400","ttl":1814400,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"List of European countries by life expectancy","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_European_countries_by_life_expectancy","sameAs":"http:\/\/www.wikidata.org\/entity\/Q6640221","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q6640221","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2009-03-28T15:44:03Z","dateModified":"2021-10-12T23:39:03Z","headline":"Wikimedia list article"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":108,"wgHostname":"mw1387"});});
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## Extraindo a tabela ('table')

# %%
table_wiki_raw = soup.find('table', attrs={'class': 'sortable wikitable'})

# %%
type(table_wiki_raw)
# Out:
# bs4.element.Tag

# %%
print(table_wiki_raw)
# Out:
# <table class="sortable wikitable">
# <tbody><tr bgcolor="#efefef">
# <th>Rank
# </th>
# <th>Country</th>
# <th><a href="/wiki/List_of_countries_by_life_expectancy" title="List of countries by life expectancy">Life expectancy</a><sup class="reference" id="cite_ref-:0_1-1"><a href="#cite_note-:0-1">[1]</a></sup>
# </th>
# <th>Influenza vaccination rate, people aged 65 and over, 2016 (%)<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="800" data-file-width="1000" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/19px-Flag_of_Monaco.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/29px-Flag_of_Monaco.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/38px-Flag_of_Monaco.svg.png 2x" width="19"/> </span><a href="/wiki/Monaco" title="Monaco">Monaco</a><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
# </td>
# <td>89.4
# </td>
# <td>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="800" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/20px-Flag_of_San_Marino.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/31px-Flag_of_San_Marino.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/40px-Flag_of_San_Marino.svg.png 2x" width="20"/> </span><a href="/wiki/San_Marino" title="San Marino">San Marino</a><sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup>
# </td>
# <td>83.4
# </td>
# <td>
# </td></tr>
# <tr>
# <td>3
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="512" data-file-width="512" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/16px-Flag_of_Switzerland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/24px-Flag_of_Switzerland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg
.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Flag_of_Bulgaria.svg/46px-Flag_of_Bulgaria.svg.png 2x" width="23"/> </span><a href="/wiki/Bulgaria" title="Bulgaria">Bulgaria</a></td>
# <td>74.6
# </td>
# <td>
# </td></tr>
# <tr>
# <td>39
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/84/Flag_of_Latvia.svg/23px-Flag_of_Latvia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/84/Flag_of_Latvia.svg/35px-Flag_of_Latvia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/84/Flag_of_Latvia.svg/46px-Flag_of_Latvia.svg.png 2x" width="23"/> </span><a href="/wiki/Latvia" title="Latvia">Latvia</a></td>
# <td>74.5
# </td>
# <td>4%
# </td></tr>
# <tr>
# <td>40
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/11/Flag_of_Lithuania.svg/23px-Flag_of_Lithuania.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/11/Flag_of_Lithuania.svg/35px-Flag_of_Lithuania.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/11/Flag_of_Lithuania.svg/46px-Flag_of_Lithuania.svg.png 2x" width="23"/> </span><a href="/wiki/Lithuania" title="Lithuania">Lithuania</a></td>
# <td>74.3
# </td>
# <td>23%
# </td></tr>
# <tr>
# <td>41
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="450" data-file-width="900" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/Flag_of_Belarus.svg/23px-Flag_of_Belarus.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/85/Flag_of_Belarus.svg/35px-Flag_of_Belarus.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/85/Flag_of_Belarus.svg/46px-Flag_of_Belarus.svg.png 2x" width="23"/> </span><a href="/wiki/Belarus" title="Belarus">Belarus</a></td>
# <td>73.8
# </td>
# <td>
# </td></tr>
# <tr>
# <td>42
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="800" data-file-width="1200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Ukraine.svg/23px-Flag_of_Ukraine.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Ukraine.svg/35px-Flag_of_Ukraine.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Ukraine.svg/45px-Flag_of_Ukraine.svg.png 2x" width="23"/> </span><a href="/wiki/Ukraine" title="Ukraine">Ukraine</a></td>
# <td>72.1
# </td>
# <td>
# </td></tr>
# <tr>
# <td>43
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="900" data-file-width="1800" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Moldova.svg/23px-Flag_of_Moldova.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Moldova.svg/35px-Flag_of_Moldova.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Moldova.svg/46px-Flag_of_Moldova.svg.png 2x" width="23"/> </span><a href="/wiki/Moldova" title="Moldova">Moldova</a></td>
# <td>71.6
# </td>
# <td>
# </td></tr>
# <tr>
# <td>44
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/35px-Flag_of_Russia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/45px-Flag_of_Russia.svg.png 2x" width="23"/> </span><a href="/wiki/Russia" title="Russia">Russia</a></td>
# <td>71.6
# </td>
# <td>
# </td></tr>
# </tbody></table>

# %% [markdown]
# ## Extraindo o corpo da tabela ('tbody')

# %%
table_wiki = table_wiki_raw.find('tbody')

# %%
print(table_wiki)
# Out:
# <tbody><tr bgcolor="#efefef">
# <th>Rank
# </th>
# <th>Country</th>
# <th><a href="/wiki/List_of_countries_by_life_expectancy" title="List of countries by life expectancy">Life expectancy</a><sup class="reference" id="cite_ref-:0_1-1"><a href="#cite_note-:0-1">[1]</a></sup>
# </th>
# <th>Influenza vaccination rate, people aged 65 and over, 2016 (%)<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="800" data-file-width="1000" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/19px-Flag_of_Monaco.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/29px-Flag_of_Monaco.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/38px-Flag_of_Monaco.svg.png 2x" width="19"/> </span><a href="/wiki/Monaco" title="Monaco">Monaco</a><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
# </td>
# <td>89.4
# </td>
# <td>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="800" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/20px-Flag_of_San_Marino.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/31px-Flag_of_San_Marino.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/40px-Flag_of_San_Marino.svg.png 2x" width="20"/> </span><a href="/wiki/San_Marino" title="San Marino">San Marino</a><sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup>
# </td>
# <td>83.4
# </td>
# <td>
# </td></tr>
# <tr>
# <td>3
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="512" data-file-width="512" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/16px-Flag_of_Switzerland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Flag_of_Switzerland.svg/24px-Flag_of_Switzerland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f3/
.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Ukraine.svg/45px-Flag_of_Ukraine.svg.png 2x" width="23"/> </span><a href="/wiki/Ukraine" title="Ukraine">Ukraine</a></td>
# <td>72.1
# </td>
# <td>
# </td></tr>
# <tr>
# <td>43
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="900" data-file-width="1800" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Moldova.svg/23px-Flag_of_Moldova.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Moldova.svg/35px-Flag_of_Moldova.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Moldova.svg/46px-Flag_of_Moldova.svg.png 2x" width="23"/> </span><a href="/wiki/Moldova" title="Moldova">Moldova</a></td>
# <td>71.6
# </td>
# <td>
# </td></tr>
# <tr>
# <td>44
# </td>
# <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/35px-Flag_of_Russia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/45px-Flag_of_Russia.svg.png 2x" width="23"/> </span><a href="/wiki/Russia" title="Russia">Russia</a></td>
# <td>71.6
# </td>
# <td>
# </td></tr>
# </tbody>

# %%
type(table_wiki)
# Out:
# bs4.element.Tag

# %% [markdown]
# ### Extraindo as linhas da tabela ('tr')

# %%
table_rows = table_wiki.find_all('tr')

# %%
print(table_rows[1].prettify())
# Out:
# <tr>
#  <td>
#   1
#  </td>
#  <td>
#   <span class="flagicon">
#    <img alt="" class="thumbborder" data-file-height="800" data-file-width="1000" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/19px-Flag_of_Monaco.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/29px-Flag_of_Monaco.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/38px-Flag_of_Monaco.svg.png 2x" width="19"/>
#   </span>
#   <a href="/wiki/Monaco" title="Monaco">
#    Monaco
#   </a>
#   <sup class="reference" id="cite_ref-3">
#    <a href="#cite_note-3">
#     [3]
#    </a>
#   </sup>
#  </td>
#  <td>
#   89.4
#  </td>
#  <td>
#  </td>
# </tr>

# %%
type(table_rows[1])
# Out:
# bs4.element.Tag

# %% [markdown]
# ### Extraindo as colunas de cada linha ('td')

# %%
table_rows[1].find_all('td')
# Out:
# [<td>1
#  </td>,
#  <td><span class="flagicon"><img alt="" class="thumbborder" data-file-height="800" data-file-width="1000" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/19px-Flag_of_Monaco.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/29px-Flag_of_Monaco.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/38px-Flag_of_Monaco.svg.png 2x" width="19"/> </span><a href="/wiki/Monaco" title="Monaco">Monaco</a><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
#  </td>,
#  <td>89.4
#  </td>,
#  <td>
#  </td>]

# %%
first_row = table_rows[1].find_all('td')

# %%
first_row[2].text
# Out:
# '89.4\n'

# %%
[elemento.text.strip() for elemento in first_row]
# Out:
# ['1', 'Monaco[3]', '89.4', '']

# %% [markdown]
# ### Juntando tudo!

# %%
pd.DataFrame([[elemento.text.strip() for elemento in first_row.find_all('td')] for first_row in table_rows],
            columns = ['rank', 'pais', 'ev', 'vacc'])


# EXERCICIO
# Construir um DataFrame com os dados da tabela de Expectativa de Vida na Europa da Wikipedia
# BONUS - faça isso com um list comprehension!
# BONUS - contrua uma função que receba um link da Wikipedia com uma tabela e retorne um DataFrame (teste em outra tabela)
# Out:
#     rank                    pais    ev  vacc
# 0   None                    None  None  None
# 1      1               Monaco[3]  89.4
# 2      2           San Marino[4]  83.4
# 3      3             Switzerland  83.0
# 4      4                   Spain  82.8   56%
# 5      5           Liechtenstein  82.7   28%
# 6      6                   Italy  82.7   50%
# 7      7                  Norway  82.5   38%
# 8      8                 Iceland  82.5   47%
# 9      9              Luxembourg  82.3   38%
# 10    10                  France  82.3   50%
# 11    11                  Sweden  82.2   49%
# 12    12                   Malta  81.8
# 13    13                 Finland  81.8   47%
# 14    14                 Ireland  81.6   55%
# 15    15             Netherlands  81.5   65%
# 16    16                Portugal  81.1   58%
# 17    17                  Greece  81.0
# 18    18          United Kingdom  81.0   71%
# 19    19                 Belgium  81.0
# 20    20                 Austria  80.9
# 21    21                Slovenia  80.8   10%
# 22    22                 Denmark  80.7   41%
# 23    23                 Germany  80.6   35%
# 24    24                  Cyprus  80.5
# 25    25                 Albania  78.3
# 26    26          Czech Republic  78.3
# 27    27                 Croatia  78.0   21%
# 28    28                 Estonia  77.7    3%
# 29    29                  Poland  77.5
# 30    30              Montenegro  77.1   13%
# 31    31  Bosnia and Herzegovina  76.9
# 32    32                Slovakia  76.6   10%
# 33    33                  Turkey  75.8    7%
# 34    34         North Macedonia  75.7    6%
# 35    35                 Hungary  75.6   20%
# 36    36                  Serbia  75.2   11%
# 37    37                 Romania  75.0    8%
# 38    38                Bulgaria  74.6
# 39    39                  Latvia  74.5    4%
# 40    40               Lithuania  74.3   23%
# 41    41                 Belarus  73.8
# 42    42                 Ukraine  72.1
# 43    43                 Moldova  71.6
# 44    44                  Russia  71.6

# %%
table = []
for row in table_rows:
    row_tds = row.find_all('td')
    row_list = []
    
    for td in row_tds:
        row_list.append(td.text.strip())
        
    table.append(row_list)
# Out:
# [[],
#  ['1', 'Monaco[3]', '89.4', ''],
#  ['2', 'San Marino[4]', '83.4', ''],
#  ['3', 'Switzerland', '83.0', ''],
#  ['4', 'Spain', '82.8', '56%'],
#  ['5', 'Liechtenstein', '82.7', '28%'],
#  ['6', 'Italy', '82.7', '50%'],
#  ['7', 'Norway', '82.5', '38%'],
#  ['8', 'Iceland', '82.5', '47%'],
#  ['9', 'Luxembourg', '82.3', '38%'],
#  ['10', 'France', '82.3', '50%'],
#  ['11', 'Sweden', '82.2', '49%'],
#  ['12', 'Malta', '81.8', ''],
#  ['13', 'Finland', '81.8', '47%'],
#  ['14', 'Ireland', '81.6', '55%'],
#  ['15', 'Netherlands', '81.5', '65%'],
#  ['16', 'Portugal', '81.1', '58%'],
#  ['17', 'Greece', '81.0', ''],
#  ['18', 'United Kingdom', '81.0', '71%'],
#  ['19', 'Belgium', '81.0', ''],
#  ['20', 'Austria', '80.9', ''],
#  ['21', 'Slovenia', '80.8', '10%'],
#  ['22', 'Denmark', '80.7', '41%'],
#  ['23', 'Germany', '80.6', '35%'],
#  ['24', 'Cyprus', '80.5', ''],
#  ['25', 'Albania', '78.3', ''],
#  ['26', 'Czech Republic', '78.3', ''],
#  ['27', 'Croatia', '78.0', '21%'],
#  ['28', 'Estonia', '77.7', '3%'],
#  ['29', 'Poland', '77.5', ''],
#  ['30', 'Montenegro', '77.1', '13%'],
#  ['31', 'Bosnia and Herzegovina', '76.9', ''],
#  ['32', 'Slovakia', '76.6', '10%'],
#  ['33', 'Turkey', '75.8', '7%'],
#  ['34', 'North Macedonia', '75.7', '6%'],
#  ['35', 'Hungary', '75.6', '20%'],
#  ['36', 'Serbia', '75.2', '11%'],
#  ['37', 'Romania', '75.0', '8%'],
#  ['38', 'Bulgaria', '74.6', ''],
#  ['39', 'Latvia', '74.5', '4%'],
#  ['40', 'Lithuania', '74.3', '23%'],
#  ['41', 'Belarus', '73.8', ''],
#  ['42', 'Ukraine', '72.1', ''],
#  ['43', 'Moldova', '71.6', ''],
#  ['44', 'Russia', '71.6', '']]

# %% [markdown]
# # Creating a spider

# %% [markdown]
# ## Find the book name, price and stock availability as a pandas dataframe.

# %%
# Your code here!
url = 'https://books.toscrape.com/catalogue/page-1.html'
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)

# %%
articles = soup.find_all('article')
print(articles[0].prettify())

# %%
article_head = articles[0].find('h3')
print(article_head.prettify())

# %%
article_head.find('a')['title']

# %%
articles[0].find('h3').find('a')['title']

# %%
lista_titulos = [item.find('h3').find('a')['title'] for item in articles]

# %%
articles[0].find('div', attrs = {'class' : 'product_price'})

# %%
articles[0].find('div', attrs = {'class' : 'product_price'}).find('p', attrs = {'class' : 'price_color'})

# %%
lista_preco = [
    item.find('div', attrs={
        'class': 'product_price'
    }).find('p', attrs={
        'class': 'price_color'
    }).text for item in articles
]

# %%
articles[0].find('div', attrs = {'class' : 'product_price'}).find('p', attrs = {'class' : 'instock availability'}).text.strip()

# %%
stock_list = [
    item.find('div', attrs={
        'class': 'product_price'
    }).find('p', attrs={
        'class': 'instock availability'
    }).text.strip() for item in articles
]

# %%
# EXERCICIO
# Extrair as informações acima para as primeiras 10 páginas e guarda-las em um DataFrame

# %% [markdown]
# ## Percorrer artigos relacionados à outro artigo

# %%
url = "https://www.theguardian.com/world/2022/jan/22/one-canadian-killed-after-tourists-shot-at-mexican-beach-resort-hotel"
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html)

# %%
artigo = soup.find('article')
links_artigo = artigo.find_all('a', attrs={'data-link-name': 'in body link'})
len(links_artigo)

# %%
[link['href'] for link in links_artigo]

# %%
url_filho = links_artigo[2]['href']
response_filho = requests.get(url_filho)
html_filho = response_filho.content
soup_filho = BeautifulSoup(html_filho)
artigo_filho = soup_filho.find('article').text
print(artigo_filho)

# %%
lista_artigos = []
lista_links = [link['href'] for link in links_artigo]
for link in lista_links:
    if link.find('guardian') >= 0:
        try:
            response_filho = requests.get(link)
            html_filho = response_filho.content
            soup_filho = BeautifulSoup(html_filho)
            lista_artigos.append(soup_filho.find('article').text)
        except AttributeError:
            continue

# %%
# EXERCICIO
# Transforme o código acima em uma função que recebe um link de artigo do Guardian como argumento
# e retorna uma lista com o texto do artigo original e o texto de quaisquer artigos do Guardian
# linkados no texto do artigo original
# BONUS - crie uma função que faça isso em profundidade maior que um: além do artigo original e dos artigos
# filhos (artigos linkados no artigo original) trazer os artigos netos (artigos linkados nos artigos filhos)
# BONUS BONUS - contrua uma função capaz de extrair uma profundidade arbitraria de artigos (filhos, netos, bisnetos...) 
# a partir de um parametro 'depth' (0 = original, 1 = filhos, 2 = netos, 3 = bisnetos, etc)
